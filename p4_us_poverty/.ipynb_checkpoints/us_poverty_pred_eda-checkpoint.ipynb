# %% [markdown]
# ## Portfolio: US Counties Poverty Rate - Exploratory Data Analysis ##
# This is data science portfolio based on real dataset to predict poverty rate across the United States at the country level using socio-economic indicators. The dataset was compiled from wide range of sources and publicly made available by United States Department of Agriculture Economic Research Service (USDA ERS). It can be found here https://datasciencecapstone.org/competitions/3/county-poverty/page/10/.
#
# **Problem Statement:**
# In US, being poverty is defined as having an income below a federally defined poverty threshold. This represents US federal government's estimation of how many families are below in which their income levels do not meet any basic needs (i.e., food, shelter, clothing and other essential goods). Thus, our goal is to make predictions on poverty rates by counties within US in order to make recommendations for federal government agencies. This will help them to initiate and implement policies/support the families below officially defined poverty thresholds.
#
# The US poverty rate dataset contains 33 features in total. There are 30 numerical and 3 categorical features to predict one target variable (i.e., poverty_rate). There are 4 different kinds of information are available from this dataset which includes county's urbanization degree (development level), economic indicators, health indicators and demographic indicators.
#
# **Stakeholders:**
# * US federal policymakers
# * Counties' representatives
# * Other Not-For-Profit (NFP) organizations.

# %% [markdown]
# ## Part A. Load Dataset ##

# %%
# Import all libraries #
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import csv
from sklearn.utils import shuffle
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# Authorization #
__author__ = "Taesun Yoo"
__email__ = "yoots1988@gmail.com"

# %%
# --- 1. Write Out List of Functions --- #
def load_file(file):
    '''load input CSVs as a dataframe'''
    return pd.read_csv(file, encoding='latin1')


def convert_dt_as_date(df, var_name, date_format):
    '''convert the variable as specified date format'''
    df[var_name] = pd.to_datetime(df[var_name], format=date_format)
    return df[var_name]


def convert_dt_as_custom(df, var_name, dt_type):
    '''convert datatype on selected variables'''
    df[var_name] = df[var_name].astype(dt_type)
    return df[var_name]


def convert_dt_to_cat(df):
    '''convert data type to category'''
    for col in df.columns:
        if df[col].dtype.name == 'object':
            df[col] = df[col].astype('category')


def eda_encode_cat_var(df, col, num_var):
    '''encode the cat. variables by mean of a num. variable by each cat'''
    cat_dict={}
    cats = df[col].cat.categories.tolist()
    for cat in cats:
        cat_dict[cat] = df[df[col] == cat][num_var].mean()
    df[col] = df[col].map(cat_dict)


#def pandas_qcut(df, new_var, old_var, q):
#    ''' apply pd.qcut for equal size binning '''
#    df[new_var] = pd.qcut(df[old_var], q=q, duplicates='drop',
#                          precision=0, labels=None)
#    return df[new_var]


def estimate_width(df, var_name, interval_size):
    ''' estimate the width of continuous variable '''
    width = (max(df[var_name]) - min(df[var_name]))/interval_size
    df_estimate = pd.DataFrame([[min(df[var_name])-1, max(df[var_name])+1, round(width)]])
    df_estimate.columns = ['min', 'max', 'width']
    return df_estimate


def pandas_cut(df, new_var, old_var, bins, labels=None):
    ''' apply pd.cut for custom size binning '''
    df[new_var] = pd.cut(df[old_var], bins=bins, 
                          labels=labels, right=False)
    return df[new_var]


def check_value_counts(df, var_name):
    '''return grouped value counts'''
    grouped_counts = df[var_name].value_counts()
    return grouped_counts


def feature_replacement(X):
    ''' replace missing values based on specific data type of a column '''
    for col in X.columns:
        if X[col].dtype.name == 'object':
            mode = X[col].mode().iloc[0]
            X[col] = X[col].fillna(mode)
        elif X[col].dtype.name == 'float64':
            mean = X[col].mean()
            X[col] = X[col].fillna(mean)
        else:
            X[col].dtype.name == 'int64'
            median = X[col].median()
            X[col] = X[col].fillna(median)
            

def eda_missing(df):
    '''compute missing % on each var'''
    df_missing = pd.DataFrame(df.isnull().sum(), columns=['count'])
    df_missing['pct'] = (df_missing['count']/len(df)) * 100
    return df_missing


def eda_stat_num(df):
    ''' perform eda for numerical features '''
    df_stat_num = df.describe().T
    df_stat_num = df_stat_num[['count', 'min', 'mean', 'max', 'std', '25%', '50%', '75%']]
    df_stat_num = pd.DataFrame(df_stat_num)
    return df_stat_num


def eda_stat_cat(df):
    ''' perform eda for categorical features '''
    df_stat_cat = df.describe(include='category').T
    df_stat_cat = pd.DataFrame(df_stat_cat)
    return df_stat_cat


def eda_outliers(df):
    '''check outliers using the IQR method'''
    df['IQR'] = df['75%'] - df['25%']
    df['LB']  = df['25%'] - 1.5*df['IQR']
    df['UB']  = df['75%'] + 1.5*df['IQR']
    df = df.drop(['count','std','mean','25%','50%','75%','IQR'], axis=1)
    return df


def eda_agg_df_var(df, cat_var, kpi_dict):
    '''compute aggregated dataframe to calculate the KPIs'''
    df_agg = df.groupby(by=cat_var).agg(kpi_dict)
    return df_agg


def eda_grouped_df_var(df, cat_var):
    '''create a grouped dataframe by categorical variable'''
    df_grp = pd.DataFrame(df.groupby([cat_var])[cat_var].count())
    df_grp.columns = ['count']
    return df_grp


def plot_hist(df, var_1):
    '''plot a histogram'''
    plt.figure()
    print("skenewss is:", df[var_1].skew())
    df[var_1].hist(color='green')
    plt.title('Histogram of ' + var_1)
    plt.xlabel(var_1)
    plt.ylabel('counties')
    plt.show()


def plot_bar_chart(df, var_name_1):
    '''plot a bar chart'''
    plt.figure()
    var_count_1 = df[var_name_1].value_counts()
    sns.barplot(var_count_1.index,  var_count_1.values, alpha=0.9)
    plt.title('Frequency chart of ' + var_name_1)
    plt.ylabel('counties')
    plt.xlabel(var_name_1)
    plt.xticks(rotation=270)
    plt.show()

    
def plot_freq_chart(x,y,df,order):
    '''plot a frequency chart'''
    plt.figure(figsize=(8,8))
    sns.countplot(x=x, hue=y, data=df, order=order)
    plt.title('Bar chart: ' + x + ' of county group labels', fontsize=20)
    plt.xticks(rotation=270, fontsize=12)
    plt.yticks(fontsize=12)
    plt.xlabel(x, fontsize=12)
    plt.ylabel('counties', fontsize=12)
    plt.legend(loc='upper right', fontsize=20)
    plt.show()


def plot_pie_chart(df_1, var_name_1,
                   df_2, var_name_2):
    '''plot a pie chart of specified variables'''
    plt.figure(figsize=(15,15))
    # Sub-plot 1:
    plt.subplot(1,2,1)
    plt.pie(df_1, autopct='%.0f%%', wedgeprops={'edgecolor':'white'},
            textprops={'fontsize':15})
    plt.title('Pie Chart of '+ var_name_1)
    plt.legend(labels = df_1.index, loc='upper right')
    # Sub-plot 2:
    plt.subplot(1,2,2)
    plt.pie(df_2, autopct='%.0f%%', wedgeprops={'edgecolor':'white'},
            textprops={'fontsize':15})
    plt.title('Pie Chart of '+ var_name_2)
    plt.legend(labels = df_2.index, loc='upper right')
    plt.show()
    

def plot_box(df, num_var_1, cat_var_1,
             num_var_2, cat_var_2, 
             num_var_3, cat_var_3, hue=None):
    '''plot a box-whisker of specified variables'''
    plt.figure(figsize=(15,15))
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    # Sub-plot 1:
    plt.subplot(1,3,1)
    df.sort_values(by=[num_var_1], inplace=True)
    sns.set(style='whitegrid')
    sns.boxplot(cat_var_1, num_var_1, hue, df)
    plt.title('Box plot of ' + num_var_1 + ' by ' + cat_var_1)
    plt.xticks(rotation=270, fontsize=10)
    # Sub-plot 2:
    plt.subplot(1,3,2)
    df.sort_values(by=[num_var_2], inplace=True)
    sns.set(style='whitegrid')
    sns.boxplot(cat_var_2, num_var_2, hue, df)
    plt.title('Box plot of ' + num_var_2 + ' by ' + cat_var_2)
    plt.xticks(rotation=270, fontsize=10)
    # Sub-plot 3:
    plt.subplot(1,3,3)
    df.sort_values(by=[num_var_3], inplace=True)
    sns.set(style='whitegrid')
    sns.boxplot(cat_var_3, num_var_3, hue, df)
    plt.title('Box plot of ' + num_var_3 + ' by ' + cat_var_3)
    plt.xticks(rotation=270, fontsize=10)    

    
def plot_crosstab(df, cat_var_1, cat_var_2):
    '''plot a crosstab of two categorical variables'''
    table = pd.crosstab(df[cat_var_1], df[cat_var_2])
    return table


def plot_corr_matrix(df, list_vars):
    ''' plot a correlation matrix '''
    corr = df[list_vars].corr()
    # Create a mask
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(corr)] = True
    plt.figure(figsize=(12,12))
    sns.heatmap(corr, mask=mask, square=True, linewidths = .5,
                cmap=sns.diverging_palette(220,10,as_cmap=True),
                vmin = -1, vmax = 1, fmt=".2f",
                annot=True, annot_kws={'size':11})
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.show()


def plot_scatter(df, var_1, var_2, color, factor=None):
    '''Scatter plot of two continuous numeric features'''
    plt.figure(figsize=(8,8))
    plt.scatter(df[var_1]*factor, df[var_2], color=color)
    plt.title('Relationship between '+ var_1 + ' and ' + var_2)
    plt.xlabel(var_1)
    plt.ylabel(var_2)
    plt.show()

    
def compute_pearson_r(df, var_x, var_y):
    '''compute Pearson r correlation'''
    corr_mat = np.corrcoef(df[var_x],df[var_y])
    return corr_mat[0, 1]


def plot_linear_reg(df, var_x, var_y, 
                    pearson_r, color, label):
    '''plot a pair of linear regressions'''
    plt.figure(figsize=(10,10))
    plt.plot(df[var_x], df[var_y], 'r--', label='pearson_r =%.2f' % pearson_r,
             marker='.', linestyle='none', color=color)
    plt.margins(0.02)
    plt.legend(loc='upper left')
    plt.xlabel(var_x)
    plt.ylabel(var_y)
    plt.title(var_x + ' vs. ' + var_y + ' by ' + label)
    # Fit linear regression:
    a,b = np.polyfit(df[var_x], df[var_y], 1)
    x = np.array([min(df[var_x]), max(df[var_x])])
    y = a*x + b
    plt.plot(x,y)

# %%
# --- 2. Load the data --- #
# define input CSVs:
if __name__ == '__main__':
    eda_file = 'poverty_train.csv'

# load data:
df_eda = load_file(eda_file)

# check data types:
df_eda.info()

# define variable list:
var_label = 'poverty_rate'
var_id = 'row_id'
vars_cat = list(df_eda.select_dtypes(include='O').columns)
vars_num_disc = list(df_eda.select_dtypes(include='int64').columns)
vars_num_cont = list(df_eda.select_dtypes(include='float64').columns)

# concatenate the two lists:
vars_num = vars_num_disc + vars_num_cont

list_unwanted = {'row_id','poverty_rate'}

vars_num = [item for item in vars_num if item not in list_unwanted]

del(vars_num_disc, vars_num_cont)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3198 entries, 0 to 3197
# Data columns (total 35 columns):
# row_id                                              3198 non-null int64
# area__rucc                                          3198 non-null object
# area__urban_influence                               3198 non-null object
# econ__economic_typology                             3198 non-null object
# econ__pct_civilian_labor                            3198 non-null float64
# econ__pct_unemployment                              3198 non-null float64
# econ__pct_uninsured_adults                          3196 non-null float64
# econ__pct_uninsured_children                        3196 non-null float64
# demo__pct_female                                    3196 non-null float64
# demo__pct_below_18_years_of_age                     3196 non-null float64
# demo__pct_aged_65_years_and_older                   3196 non-null float64
# demo__pct_hispanic                                  3196 non-null float64
# demo__pct_non_hispanic_african_american             3196 non-null float64
# demo__pct_non_hispanic_white                        3196 non-null float64
# demo__pct_american_indian_or_alaskan_native         3196 non-null float64
# demo__pct_asian                                     3196 non-null float64
# demo__pct_adults_less_than_a_high_school_diploma    3198 non-null float64
# demo__pct_adults_with_high_school_diploma           3198 non-null float64
# demo__pct_adults_with_some_college                  3198 non-null float64
# demo__pct_adults_bachelors_or_higher                3198 non-null float64
# demo__birth_rate_per_1k                             3198 non-null int64
# demo__death_rate_per_1k                             3198 non-null int64
# health__pct_adult_obesity                           3196 non-null float64
# health__pct_adult_smoking                           2734 non-null float64
# health__pct_diabetes                                3196 non-null float64
# health__pct_low_birthweight                         3016 non-null float64
# health__pct_excessive_drinking                      2220 non-null float64
# health__pct_physical_inacticity                     3196 non-null float64
# health__air_pollution_particulate_matter            3170 non-null float64
# health__homicides_per_100k                          1231 non-null float64
# health__motor_vehicle_crash_deaths_per_100k         2781 non-null float64
# health__pop_per_dentist                             2954 non-null float64
# health__pop_per_primary_care_physician              2968 non-null float64
# yr                                                  3198 non-null object
# poverty_rate                                        3198 non-null float64
# dtypes: float64(28), int64(3), object(4)
# memory usage: 874.6+ KB

# %% [markdown]
# ## Part B. Exploratory Data Analysis ##
#
# #### US poverty rate by counties: training set ###
# Data exploration is conducted on a cleaned training set. The main goal of this phase is to explore any interesting relationships among features and identify which features are good predictors on poverty rate predictions.
#
# Following set of questions are asked:
# 1. Can I count something interesting?
# 2. Can I find some trends (increase or decrease and any anomalies)?
# 3. Can I plot a bar chart or a histogram?
# 4. Can I make a scatter plot?
#
# These set of guiding questions will help us to explore any insights and tell a compelling story about the US poverty dataset.

# %%
################################################
# Part 3 - Exploratory Data Analysis: Insights #
################################################
# compute top 10 rows:
df_eda.head(10)

# check any duplicates
df_eda.duplicated().sum()
# Out:
# 0

# %%
# create a missing % dataframe: before
df_missing_pre = eda_missing(df_eda)
df_missing_pre
# Out:
#                                                   count        pct
# row_id                                                0   0.000000
# area__rucc                                            0   0.000000
# area__urban_influence                                 0   0.000000
# econ__economic_typology                               0   0.000000
# econ__pct_civilian_labor                              0   0.000000
# econ__pct_unemployment                                0   0.000000
# econ__pct_uninsured_adults                            2   0.062539
# econ__pct_uninsured_children                          2   0.062539
# demo__pct_female                                      2   0.062539
# demo__pct_below_18_years_of_age                       2   0.062539
# demo__pct_aged_65_years_and_older                     2   0.062539
# demo__pct_hispanic                                    2   0.062539
# demo__pct_non_hispanic_african_american               2   0.062539
# demo__pct_non_hispanic_white                          2   0.062539
# demo__pct_american_indian_or_alaskan_native           2   0.062539
# demo__pct_asian                                       2   0.062539
# demo__pct_adults_less_than_a_high_school_diploma      0   0.000000
# demo__pct_adults_with_high_school_diploma             0   0.000000
# demo__pct_adults_with_some_college                    0   0.000000
# demo__pct_adults_bachelors_or_higher                  0   0.000000
# demo__birth_rate_per_1k                               0   0.000000
# demo__death_rate_per_1k                               0   0.000000
# health__pct_adult_obesity                             2   0.062539
# health__pct_adult_smoking                           464  14.509068
# health__pct_diabetes                                  2   0.062539
# health__pct_low_birthweight                         182   5.691057
# health__pct_excessive_drinking                      978  30.581614
# health__pct_physical_inacticity                       2   0.062539
# health__air_pollution_particulate_matter             28   0.875547
# health__homicides_per_100k                         1967  61.507192
# health__motor_vehicle_crash_deaths_per_100k         417  13.039400
# health__pop_per_dentist                             244   7.629769
# health__pop_per_primary_care_physician              230   7.191995
# yr                                                    0   0.000000
# poverty_rate                                          0   0.000000

# %% [markdown]
# ### Summary: Missing Data % ###
# a feature homicides per 100k misses about 61.5%% followed by % excessive drinking 30.6% and etc.

# %%
# feature replacement:
feature_replacement(df_eda)

# %%
# create a missing % dataframe: after
df_missing_post = eda_missing(df_eda)
df_missing_post
del(df_missing_pre, df_missing_post)

# %%
# ---3 perform summary statistics ---
# convert data type: object to category
convert_dt_to_cat(df_eda)

# numerical features:
df_stat_num = eda_stat_num(df_eda[vars_num])
df_stat_num
# Out:
#                                                    count         min  \
# demo__birth_rate_per_1k                           3198.0    4.000000
# demo__death_rate_per_1k                           3198.0    0.000000
# econ__pct_civilian_labor                          3198.0    0.217000
# econ__pct_unemployment                            3198.0    0.008000
# econ__pct_uninsured_adults                        3198.0    0.046000
# econ__pct_uninsured_children                      3198.0    0.009000
# demo__pct_female                                  3198.0    0.294000
# demo__pct_below_18_years_of_age                   3198.0    0.098000
# demo__pct_aged_65_years_and_older                 3198.0    0.043000
# demo__pct_hispanic                                3198.0    0.000000
# demo__pct_non_hispanic_african_american           3198.0    0.000000
# demo__pct_non_hispanic_white                      3198.0    0.060000
# demo__pct_american_indian_or_alaskan_native       3198.0    0.000000
# demo__pct_asian                                   3198.0    0.000000
# demo__pct_adults_less_than_a_high_school_diploma  3198.0    0.016129
# demo__pct_adults_with_high_school_diploma         3198.0    0.072821
# demo__pct_adults_with_some_college                3198.0    0.112821
# demo__pct_adults_bachelors_or_higher              3198.0    0.013986
# health__pct_adult_obesity                         3198.0    0.140000
# health__pct_adult_smoking                         3198.0    0.050000
# health__pct_diabetes                              3198.0    0.033000
# health__pct_low_birthweight                       3198.0    0.025000
# health__pct_excessive_drinking                    3198.0    0.038000
# health__pct_physical_inacticity                   3198.0    0.097000
# health__air_pollution_particulate_matter          3198.0    7.000000
# health__homicides_per_100k                        3198.0   -0.390000
# health__motor_vehicle_crash_deaths_per_100k       3198.0    3.090000
# health__pop_per_dentist                           3198.0  339.000000
# health__pop_per_primary_care_physician            3198.0  189.000000
#
#                                                          mean           max  \
# demo__birth_rate_per_1k                             11.676986     29.000000
# demo__death_rate_per_1k                             10.301126     27.000000
# econ__pct_civilian_labor                             0.467071      1.000000
# econ__pct_unemployment                               0.059610      0.240000
# econ__pct_uninsured_adults                           0.217534      0.495000
# econ__pct_uninsured_children                         0.085920      0.285000
# demo__pct_female                                     0.498781      0.576000
# demo__pct_below_18_years_of_age                      0.227763      0.417000
# demo__pct_aged_65_years_and_older                    0.170137      0.355000
# demo__pct_hispanic                                   0.090233      0.945000
# demo__pct_non_hispanic_african_american              0.091117      0.855000
# demo__pct_non_hispanic_white                         0.770207      0.998000
# demo__pct_american_indian_or_alaskan_native          0.024659      0.852000
# demo__pct_asian                                      0.013304      0.346000
# demo__pct_adults_less_than_a_high_school_diploma     0.148794      0.466867
# demo__pct_adults_with_high_school_diploma            0.350300      0.551689
# demo__pct_adults_with_some_college                   0.301366      0.474216
# demo__pct_adults_bachelors_or_higher                 0.199540      0.794872
# health__pct_adult_obesity                            0.307599      0.484000
# health__pct_adult_smoking                            0.213519      0.526000
# health__pct_diabetes                                 0.109287      0.197000
# health__pct_low_birthweight                          0.083534      0.232000
# health__pct_excessive_drinking                       0.164832      0.358000
# health__pct_physical_inacticity                      0.277309      0.443000
# health__air_pollution_particulate_matter            11.626498     15.000000
# health__homicides_per_100k                           5.950747     51.490000
# health__motor_vehicle_crash_deaths_per_100k         21.116077    110.450000
# health__pop_per_dentist                           3431.442789  28129.000000
# health__pop_per_primary_care_physician            2551.349730  23400.000000
#
#                                                           std          25%  \
# demo__birth_rate_per_1k                              2.739516    10.000000
# demo__death_rate_per_1k                              2.786143     8.000000
# econ__pct_civilian_labor                             0.074541     0.420000
# econ__pct_unemployment                               0.022850     0.044000
# econ__pct_uninsured_adults                           0.067351     0.166250
# econ__pct_uninsured_children                         0.039992     0.057000
# demo__pct_female                                     0.024243     0.493000
# demo__pct_below_18_years_of_age                      0.034280     0.207000
# demo__pct_aged_65_years_and_older                    0.043580     0.142000
# demo__pct_hispanic                                   0.142663     0.019000
# demo__pct_non_hispanic_african_american              0.147058     0.006000
# demo__pct_non_hispanic_white                         0.207838     0.648250
# demo__pct_american_indian_or_alaskan_native          0.084608     0.002000
# demo__pct_asian                                      0.025358     0.003000
# demo__pct_adults_less_than_a_high_school_diploma     0.068255     0.097468
# demo__pct_adults_with_high_school_diploma            0.070534     0.305915
# demo__pct_adults_with_some_college                   0.052498     0.265362
# demo__pct_adults_bachelors_or_higher                 0.089158     0.138840
# health__pct_adult_obesity                            0.043390     0.284000
# health__pct_adult_smoking                            0.058333     0.178000
# health__pct_diabetes                                 0.023189     0.094000
# health__pct_low_birthweight                          0.021736     0.069000
# health__pct_excessive_drinking                       0.041849     0.146000
# health__pct_physical_inacticity                      0.052931     0.243000
# health__air_pollution_particulate_matter             1.538147    10.000000
# health__homicides_per_100k                           3.140663     5.950747
# health__motor_vehicle_crash_deaths_per_100k          9.807138    14.555000
# health__pop_per_dentist                           2469.446559  1879.000000
# health__pop_per_primary_care_physician            2023.509112  1462.250000
#
#                                                           50%          75%
# demo__birth_rate_per_1k                             11.000000    13.000000
# demo__death_rate_per_1k                             10.000000    12.000000
# econ__pct_civilian_labor                             0.467000     0.514000
# econ__pct_unemployment                               0.057000     0.071000
# econ__pct_uninsured_adults                           0.216000     0.262000
# econ__pct_uninsured_children                         0.077000     0.105000
# demo__pct_female                                     0.503000     0.512000
# demo__pct_below_18_years_of_age                      0.226000     0.245000
# demo__pct_aged_65_years_and_older                    0.167000     0.194000
# demo__pct_hispanic                                   0.035000     0.088000
# demo__pct_non_hispanic_african_american              0.022000     0.096000
# demo__pct_non_hispanic_white                         0.854000     0.936000
# demo__pct_american_indian_or_alaskan_native          0.007000     0.014000
# demo__pct_asian                                      0.007000     0.013000
# demo__pct_adults_less_than_a_high_school_diploma     0.133501     0.195171
# demo__pct_adults_with_high_school_diploma            0.355701     0.399197
# demo__pct_adults_with_some_college                   0.301595     0.335972
# demo__pct_adults_bachelors_or_higher                 0.177247     0.233258
# health__pct_adult_obesity                            0.309000     0.334000
# health__pct_adult_smoking                            0.213519     0.242000
# health__pct_diabetes                                 0.109000     0.124000
# health__pct_low_birthweight                          0.081000     0.094000
# health__pct_excessive_drinking                       0.164832     0.182000
# health__pct_physical_inacticity                      0.280000     0.313000
# health__air_pollution_particulate_matter            12.000000    13.000000
# health__homicides_per_100k                           5.950747     5.950747
# health__motor_vehicle_crash_deaths_per_100k         21.116077    25.320000
# health__pop_per_dentist                           2860.000000  3889.750000
# health__pop_per_primary_care_physician            2090.000000  2749.000000

# %% [markdown]
# ### Summary: Numerical Features ###
# * % civilian labor: on average, about 46% of counties' population is in civilian labor force.
# * % adults less than a high school diploma: on average, 15% of counties' population is high school dropouts.
# * % uninsured adults: on average, about 21.7% of counties' adult population is uninsured.

# %%
# categorical features:
df_stat_cat = eda_stat_cat(df_eda[vars_cat])
df_stat_cat
# Out:
#                         count unique  \
# area__rucc               3198      9
# area__urban_influence    3198     12
# econ__economic_typology  3198      6
# yr                       3198      2
#
#                                                                        top  \
# area__rucc               Nonmetro - Urban population of 2,500 to 19,999...
# area__urban_influence    Small-in a metro area with fewer than 1 millio...
# econ__economic_typology                                     Nonspecialized
# yr                                                                       b
#
#                          freq
# area__rucc                608
# area__urban_influence     692
# econ__economic_typology  1266
# yr                       1599

# %% [markdown]
# ### Summary: Categorical Features ###
# * economic typology: majority of counties are non-specialized economy type.
# * urban degree concentration: majority of counties are nonmetro-ubran population between 2,500 to 19,999.

# %%
# ---4 detect outliers ---
# create a dataframe for IQR:
df_outliers = eda_outliers(df_stat_num)
df_outliers
# Out:
#                                                          min           max  \
# demo__birth_rate_per_1k                             4.000000     29.000000
# demo__death_rate_per_1k                             0.000000     27.000000
# econ__pct_civilian_labor                            0.217000      1.000000
# econ__pct_unemployment                              0.008000      0.240000
# econ__pct_uninsured_adults                          0.046000      0.495000
# econ__pct_uninsured_children                        0.009000      0.285000
# demo__pct_female                                    0.294000      0.576000
# demo__pct_below_18_years_of_age                     0.098000      0.417000
# demo__pct_aged_65_years_and_older                   0.043000      0.355000
# demo__pct_hispanic                                  0.000000      0.945000
# demo__pct_non_hispanic_african_american             0.000000      0.855000
# demo__pct_non_hispanic_white                        0.060000      0.998000
# demo__pct_american_indian_or_alaskan_native         0.000000      0.852000
# demo__pct_asian                                     0.000000      0.346000
# demo__pct_adults_less_than_a_high_school_diploma    0.016129      0.466867
# demo__pct_adults_with_high_school_diploma           0.072821      0.551689
# demo__pct_adults_with_some_college                  0.112821      0.474216
# demo__pct_adults_bachelors_or_higher                0.013986      0.794872
# health__pct_adult_obesity                           0.140000      0.484000
# health__pct_adult_smoking                           0.050000      0.526000
# health__pct_diabetes                                0.033000      0.197000
# health__pct_low_birthweight                         0.025000      0.232000
# health__pct_excessive_drinking                      0.038000      0.358000
# health__pct_physical_inacticity                     0.097000      0.443000
# health__air_pollution_particulate_matter            7.000000     15.000000
# health__homicides_per_100k                         -0.390000     51.490000
# health__motor_vehicle_crash_deaths_per_100k         3.090000    110.450000
# health__pop_per_dentist                           339.000000  28129.000000
# health__pop_per_primary_care_physician            189.000000  23400.000000
#
#                                                            LB           UB
# demo__birth_rate_per_1k                              5.500000    17.500000
# demo__death_rate_per_1k                              2.000000    18.000000
# econ__pct_civilian_labor                             0.279000     0.655000
# econ__pct_unemployment                               0.003500     0.111500
# econ__pct_uninsured_adults                           0.022625     0.405625
# econ__pct_uninsured_children                        -0.015000     0.177000
# demo__pct_female                                     0.464500     0.540500
# demo__pct_below_18_years_of_age                      0.150000     0.302000
# demo__pct_aged_65_years_and_older                    0.064000     0.272000
# demo__pct_hispanic                                  -0.084500     0.191500
# demo__pct_non_hispanic_african_american             -0.129000     0.231000
# demo__pct_non_hispanic_white                         0.216625     1.367625
# demo__pct_american_indian_or_alaskan_native         -0.016000     0.032000
# demo__pct_asian                                     -0.012000     0.028000
# demo__pct_adults_less_than_a_high_school_diploma    -0.049086     0.341725
# demo__pct_adults_with_high_school_diploma            0.165993     0.539119
# demo__pct_adults_with_some_college                   0.159446     0.441888
# demo__pct_adults_bachelors_or_higher                -0.002786     0.374884
# health__pct_adult_obesity                            0.209000     0.409000
# health__pct_adult_smoking                            0.082000     0.338000
# health__pct_diabetes                                 0.049000     0.169000
# health__pct_low_birthweight                          0.031500     0.131500
# health__pct_excessive_drinking                       0.092000     0.236000
# health__pct_physical_inacticity                      0.138000     0.418000
# health__air_pollution_particulate_matter             5.500000    17.500000
# health__homicides_per_100k                           5.950747     5.950747
# health__motor_vehicle_crash_deaths_per_100k         -1.592500    41.467500
# health__pop_per_dentist                          -1137.125000  6905.875000
# health__pop_per_primary_care_physician            -467.875000  4679.125000

# %%
# check outliers:
# lower bounds (LBs)
df_eda[df_eda.health__homicides_per_100k < 0]
# Out:
#       row_id                                         area__rucc  \
# 87       159  Metro - Counties in metro areas of fewer than ...
# 830     1622  Metro - Counties in metro areas of 1 million p...
# 954     1868  Metro - Counties in metro areas of 250,000 to ...
# 1282    2573  Metro - Counties in metro areas of 250,000 to ...
# 1402    2812  Metro - Counties in metro areas of 1 million p...
# 1994    3965  Metro - Counties in metro areas of 1 million p...
#
#                                   area__urban_influence  \
# 87    Small-in a metro area with fewer than 1 millio...
# 830   Large-in a metro area with at least 1 million ...
# 954   Small-in a metro area with fewer than 1 millio...
# 1282  Small-in a metro area with fewer than 1 millio...
# 1402  Large-in a metro area with at least 1 million ...
# 1994  Large-in a metro area with at least 1 million ...
#
#      econ__economic_typology  econ__pct_civilian_labor  \
# 87            Nonspecialized                     0.554
# 830           Nonspecialized                     0.532
# 954               Recreation                     0.520
# 1282              Recreation                     0.521
# 1402          Nonspecialized                     0.557
# 1994          Nonspecialized                     0.546
#
#       econ__pct_unemployment  econ__pct_uninsured_adults  \
# 87                     0.042                       0.126
# 830                    0.048                       0.113
# 954                    0.043                       0.103
# 1282                   0.048                       0.078
# 1402                   0.040                       0.076
# 1994                   0.030                       0.111
#
#       econ__pct_uninsured_children  demo__pct_female  \
# 87                           0.046             0.502
# 830                          0.044             0.508
# 954                          0.044             0.504
# 1282                         0.024             0.501
# 1402                         0.026             0.508
# 1994                         0.055             0.509
#
#       demo__pct_below_18_years_of_age  ...  health__pct_low_birthweight  \
# 87                              0.248  ...                        0.070
# 830                             0.237  ...                        0.079
# 954                             0.209  ...                        0.066
# 1282                            0.222  ...                        0.074
# 1402                            0.234  ...                        0.056
# 1994                            0.300  ...                        0.067
#
#       health__pct_excessive_drinking  health__pct_physical_inacticity  \
# 87                             0.275                            0.215
# 830                            0.173                            0.198
# 954                            0.202                            0.206
# 1282                           0.205                            0.225
# 1402                           0.242                            0.191
# 1994                           0.195                            0.191
#
#       health__air_pollution_particulate_matter  health__homicides_per_100k  \
# 87                                        11.0                       -0.09
# 830                                       11.0                       -0.39
# 954                                       11.0                       -0.34
# 1282                                      11.0                       -0.10
# 1402                                      12.0                       -0.11
# 1994                                      14.0                       -0.30
#
#       health__motor_vehicle_crash_deaths_per_100k  health__pop_per_dentist  \
# 87                                           9.99                   1219.0
# 830                                          4.12                    949.0
# 954                                          8.74                   1689.0
# 1282                                         7.63                   1680.0
# 1402                                         7.63                   1209.0
# 1994                                         5.49                   1360.0
#
#       health__pop_per_primary_care_physician  yr  poverty_rate
# 87                                    1209.0   b          10.8
# 830                                    980.0   b           4.6
# 954                                   1289.0   b           8.0
# 1282                                  1280.0   a           5.9
# 1402                                   729.0   b           5.7
# 1994                                   699.0   a           4.9
#
# [6 rows x 35 columns]

# %%
# upper bounds (UBs)
df_eda[df_eda.econ__pct_unemployment > 0.1115]
# Out:
#       row_id                                         area__rucc  \
# 12        21  Metro - Counties in metro areas of 250,000 to ...
# 52        92  Nonmetro - Completely rural or less than 2,500...
# 93       166  Nonmetro - Completely rural or less than 2,500...
# 116      208  Nonmetro - Completely rural or less than 2,500...
# 127      229  Metro - Counties in metro areas of fewer than ...
# ...      ...                                                ...
# 2949    5803  Nonmetro - Urban population of 2,500 to 19,999...
# 2987    5870  Nonmetro - Completely rural or less than 2,500...
# 3068    6037  Nonmetro - Urban population of 2,500 to 19,999...
# 3171    6236  Nonmetro - Urban population of 2,500 to 19,999...
# 3194    6273  Nonmetro - Completely rural or less than 2,500...
#
#                                   area__urban_influence  \
# 12    Small-in a metro area with fewer than 1 millio...
# 52    Noncore adjacent to micro area and does not co...
# 93    Noncore not adjacent to a metro/micro area and...
# 116   Noncore not adjacent to a metro/micro area and...
# 127   Small-in a metro area with fewer than 1 millio...
# ...                                                 ...
# 2949  Noncore adjacent to a small metro with town of...
# 2987          Micropolitan not adjacent to a metro area
# 3068        Micropolitan adjacent to a small metro area
# 3171  Noncore adjacent to micro area and contains a ...
# 3194  Noncore adjacent to a small metro and does not...
#
#                  econ__economic_typology  econ__pct_civilian_labor  \
# 12                        Nonspecialized                     0.446
# 52                            Recreation                     0.387
# 93    Federal/State government-dependent                     0.358
# 116                           Recreation                     0.783
# 127   Federal/State government-dependent                     0.437
# ...                                  ...                       ...
# 2949             Manufacturing-dependent                     0.298
# 2987                    Mining-dependent                     0.343
# 3068  Federal/State government-dependent                     0.458
# 3171                      Nonspecialized                     0.370
# 3194                      Nonspecialized                     0.344
#
#       econ__pct_unemployment  econ__pct_uninsured_adults  \
# 12                     0.116                    0.313000
# 52                     0.126                    0.196000
# 93                     0.113                    0.206000
# 116                    0.117                    0.217534
# 127                    0.231                    0.296000
# ...                      ...                         ...
# 2949                   0.118                    0.236000
# 2987                   0.114                    0.189000
# 3068                   0.186                    0.369000
# 3171                   0.119                    0.241000
# 3194                   0.117                    0.302000
#
#       econ__pct_uninsured_children  demo__pct_female  \
# 12                         0.09600          0.502000
# 52                         0.07600          0.482000
# 93                         0.07300          0.493000
# 116                        0.08592          0.498781
# 127                        0.09500          0.487000
# ...                            ...               ...
# 2949                       0.05900          0.465000
# 2987                       0.07200          0.493000
# 3068                       0.11100          0.499000
# 3171                       0.07800          0.524000
# 3194                       0.10400          0.511000
#
#       demo__pct_below_18_years_of_age  ...  health__pct_low_birthweight  \
# 12                           0.312000  ...                     0.061000
# 52                           0.133000  ...                     0.083534
# 93                           0.202000  ...                     0.047000
# 116                          0.227763  ...                     0.083534
# 127                          0.281000  ...                     0.062000
# ...                               ...  ...                          ...
# 2949                         0.206000  ...                     0.117000
# 2987                         0.204000  ...                     0.075000
# 3068                         0.273000  ...                     0.092000
# 3171                         0.207000  ...                     0.119000
# 3194                         0.197000  ...                     0.142000
#
#       health__pct_excessive_drinking  health__pct_physical_inacticity  \
# 12                          0.189000                         0.200000
# 52                          0.164832                         0.233000
# 93                          0.164832                         0.245000
# 116                         0.164832                         0.277309
# 127                         0.155000                         0.236000
# ...                              ...                              ...
# 2949                        0.176000                         0.358000
# 2987                        0.164832                         0.297000
# 3068                        0.158000                         0.236000
# 3171                        0.092000                         0.337000
# 3194                        0.164832                         0.339000
#
#       health__air_pollution_particulate_matter  health__homicides_per_100k  \
# 12                                   10.000000                    8.700000
# 52                                   10.000000                    5.950747
# 93                                   11.000000                    5.950747
# 116                                  11.626498                    5.950747
# 127                                   9.000000                    2.200000
# ...                                        ...                         ...
# 2949                                 13.000000                   14.550000
# 2987                                 13.000000                    5.950747
# 3068                                 10.000000                    9.650000
# 3171                                 13.000000                   11.340000
# 3194                                 13.000000                    5.950747
#
#       health__motor_vehicle_crash_deaths_per_100k  health__pop_per_dentist  \
# 12                                      16.870000              2139.000000
# 52                                      24.110000              2159.000000
# 93                                      24.460000              4320.000000
# 116                                     21.116077              3431.442789
# 127                                     12.650000              2989.000000
# ...                                           ...                      ...
# 2949                                    19.850000              5660.000000
# 2987                                    18.650000             16110.000000
# 3068                                    26.820000              3190.000000
# 3171                                    39.680000              2830.000000
# 3194                                    21.116077              3431.442789
#
#       health__pop_per_primary_care_physician  yr  poverty_rate
# 12                                2349.00000   a          27.4
# 52                                2190.00000   b          17.0
# 93                                2551.34973   b          20.0
# 116                               2551.34973   b           2.5
# 127                               4530.00000   a          24.2
# ...                                      ...  ..           ...
# 2949                              1690.00000   b          39.0
# 2987                              3139.00000   b          21.6
# 3068                              2099.00000   b          30.2
# 3171                              2659.00000   b          30.3
# 3194                              2551.34973   b          31.6
#
# [82 rows x 35 columns]

# %%
# ---5 aggregate dataframe and compute KPIs ---
# Define the dictionary for KPIs:
kpi_dict = {'row_id':'nunique', 'econ__pct_unemployment':'mean',
            'demo__pct_adults_less_than_a_high_school_diploma':'mean', 
            'demo__pct_below_18_years_of_age':'mean'}

df_agg_econ_type = eda_agg_df_var(df_eda, 'econ__economic_typology', kpi_dict)

# Print a summary KPI table by economic type:
df_agg_econ_type
# Out:
#                                     row_id  econ__pct_unemployment  \
# econ__economic_typology
# Farm-dependent                         482                0.043793
# Federal/State government-dependent     390                0.065769
# Manufacturing-dependent                494                0.061241
# Mining-dependent                       254                0.055217
# Nonspecialized                        1266                0.062585
# Recreation                             312                0.065272
#
#                                     demo__pct_adults_less_than_a_high_school_diploma  \
# econ__economic_typology
# Farm-dependent                                                              0.139554
# Federal/State government-dependent                                          0.154561
# Manufacturing-dependent                                                     0.162275
# Mining-dependent                                                            0.184931
# Nonspecialized                                                              0.148351
# Recreation                                                                  0.106889
#
#                                     demo__pct_below_18_years_of_age
# econ__economic_typology
# Farm-dependent                                             0.228346
# Federal/State government-dependent                         0.214644
# Manufacturing-dependent                                    0.234209
# Mining-dependent                                           0.239024
# Nonspecialized                                             0.233911
# Recreation                                                 0.198944

# %% [markdown]
# ### Summary: Counties by Economic Typology ###
# * majority of counties are nonspecialized economic type.
# * average % unemployment is the highest in federal/state government-dependent economic counties.
# * % adults less than a highschool diploma is the highest in mining-dependent economic counties.
# * % young adolescents population is the highest in mining-dependent economic counties.

# %% [markdown]
# ### Uni-variate: Histogram Plots ###

# %%
# ---6 visualize data: uni-variate ---
# plot a histogram:    
plot_hist(df_eda, 'econ__pct_civilian_labor')

plot_hist(df_eda, 'econ__pct_unemployment')

plot_hist(df_eda, 'demo__pct_adults_less_than_a_high_school_diploma')

plot_hist(df_eda, 'poverty_rate')
# Out:
# skenewss is: 0.6607878498736339
# skenewss is: 1.2833688519456188
# skenewss is: 0.8135428365034596
# skenewss is: 1.048357214328277

# %% [markdown]
# ### Summary: Economic Indicators ###
# 1. Labor: showed distribution is not quite normal. Majority of US counties have civilian labor more than 50%.
# 2. Unemployment rate: showed distribution skewed to right. Majority of US counties have unemployment rate at 5%.
# 3. % less than a highschool diploma: positively skewed distribution where mean is less than 20%.
# 4. Poverty rate: positively skewed distribution where mean is less than 20.

# %% [markdown]
# ### Uni-variate: Bar Charts ###

# %%
# plot a bar chart:
plot_bar_chart(df_eda, 'econ__economic_typology')

plot_bar_chart(df_eda, 'area__rucc')

# %% [markdown]
# ### Summary: Bar Charts ###
# Economic Typology:
# * Non-specialized economic type is top among the US counties.
# * Mining-dependent economic type is the lowest among the US counties.
#
# Area Urban Concentration:
# * The highest type is the nonmetro-urban where population size of 2,500 to 19,999.
# * The lowest type is the nonmetro-ubran where population size of 20,000 or more.

# %% [markdown]
# ### Frequency Charts ###

# %%
plot_freq_chart('area__urban_influence', 'econ__economic_typology', df_eda, None)

# %% [markdown]
# ### Uni-variate: Pie Charts ###

# %%
# grouped dataframe by a categorical feature:
df_grp_econ_type = eda_grouped_df_var(df_eda, 'econ__economic_typology')
df_grp_area_rucc = eda_grouped_df_var(df_eda, 'area__rucc')

# Plot pie chart(s) by categorical features:
plot_pie_chart(df_grp_econ_type, 'Economic Type',
               df_grp_area_rucc, 'Area Urban Degree')
# Out:
# C:\Users\yoots\Anaconda3\lib\site-packages\ipykernel_launcher.py:165: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
# C:\Users\yoots\Anaconda3\lib\site-packages\ipykernel_launcher.py:171: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %% [markdown]
# ### Summary: Pie Charts ###
# * Economic Type: 40% is nonspecialized followed by manufacturing, farm, federal/state goverment, etc.
# * Area Ubran Concentration: 19% of them is nonmetro to urban population of 2,500 to 19,999 close to metro area.

# %% [markdown]
# ### Bi-variate: Box-Whisker Plots ###

# %%
# ---7 visualize data: bi-variate ---
# plot a box-whisker:    
plot_box(df_eda, 'poverty_rate', 'econ__economic_typology',
        'econ__pct_unemployment', 'econ__economic_typology',
        'demo__pct_adults_less_than_a_high_school_diploma', 'econ__economic_typology')

# %% [markdown]
# ### Summary: Box-Whisker Plots by Categorical Variables ###
# 1. Poverty rate: is the highest in federal/state and lowest in farm-dependent economic type.
# 2. % Unemployment: is the highest in recreation and lowest in farm-dependent economic type.
# 3. % Adults less than a highschool diploma: is the highest in mining and lowest in recreation economic type.

# %% [markdown]
# ### Bi-variate: Correlation Matrix Plot ###

# %%
# create a dataframe:
df_eda_cm = df_eda.copy()

# check data type:
df_eda_cm.info()

# convert data type: object to category
convert_dt_to_cat(df_eda_cm)

# encode categorical variables using poverty_rate:
for col in df_eda_cm.columns:
    if df_eda_cm[col].dtype.name == 'category':
        eda_encode_cat_var(df_eda_cm, col, 'poverty_rate')

# Create a list of variables:
vars_list = list(df_eda_cm.columns)

# Delete a list of unwanted variables:
unwanted_list = {'row_id', 'area__rucc', 'area__urban_influence', 'econ__economic_typology'}

#vars_list = [item for item in vars_list if item not in unwanted_list]
vars_list = ['health__pct_excessive_drinking','health__pop_per_primary_care_physician',
            'health__pop_per_dentist','health__air_pollution_particulate_matter',
            'health__pct_adult_smoking','demo__pct_female',
            'econ__pct_unemployment','health__pct_low_birthweight',
            'econ__pct_civilian_labor','demo__birth_rate_per_1k',
            'demo__death_rate_per_1k','demo__pct_below_18_years_of_age',
            'health__pct_diabetes','econ__pct_uninsured_children',
            'demo__pct_asian','demo__pct_aged_65_years_and_older',
            'econ__pct_uninsured_adults','poverty_rate']

# plot a correlation matrix:
plot_corr_matrix(df_eda_cm, vars_list)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3198 entries, 1385 to 941
# Data columns (total 35 columns):
# row_id                                              3198 non-null int64
# area__rucc                                          3198 non-null category
# area__urban_influence                               3198 non-null category
# econ__economic_typology                             3198 non-null category
# econ__pct_civilian_labor                            3198 non-null float64
# econ__pct_unemployment                              3198 non-null float64
# econ__pct_uninsured_adults                          3198 non-null float64
# econ__pct_uninsured_children                        3198 non-null float64
# demo__pct_female                                    3198 non-null float64
# demo__pct_below_18_years_of_age                     3198 non-null float64
# demo__pct_aged_65_years_and_older                   3198 non-null float64
# demo__pct_hispanic                                  3198 non-null float64
# demo__pct_non_hispanic_african_american             3198 non-null float64
# demo__pct_non_hispanic_white                        3198 non-null float64
# demo__pct_american_indian_or_alaskan_native         3198 non-null float64
# demo__pct_asian                                     3198 non-null float64
# demo__pct_adults_less_than_a_high_school_diploma    3198 non-null float64
# demo__pct_adults_with_high_school_diploma           3198 non-null float64
# demo__pct_adults_with_some_college                  3198 non-null float64
# demo__pct_adults_bachelors_or_higher                3198 non-null float64
# demo__birth_rate_per_1k                             3198 non-null int64
# demo__death_rate_per_1k                             3198 non-null int64
# health__pct_adult_obesity                           3198 non-null float64
# health__pct_adult_smoking                           3198 non-null float64
# health__pct_diabetes                                3198 non-null float64
# health__pct_low_birthweight                         3198 non-null float64
# health__pct_excessive_drinking                      3198 non-null float64
# health__pct_physical_inacticity                     3198 non-null float64
# health__air_pollution_particulate_matter            3198 non-null float64
# health__homicides_per_100k                          3198 non-null float64
# health__motor_vehicle_crash_deaths_per_100k         3198 non-null float64
# health__pop_per_dentist                             3198 non-null float64
# health__pop_per_primary_care_physician              3198 non-null float64
# yr                                                  3198 non-null category
# poverty_rate                                        3198 non-null float64
# dtypes: category(4), float64(28), int64(3)
# memory usage: 813.1 KB

# %% [markdown]
# ### Summary: Correlation Matrix ###
# We can conclude from above with respect to the magnitude of Pearson correlation: % civilian labor is the most strongly correlated with poverty rate, followed by % unemployment, % low birth weight, % diabetes and % uninsured adults.
#
# Among the features, following trends are recongized:
# 1. Poverty rate and % civilian labor has the strong negative correlation (r=-0.67)
# 2. Poverty rate and % unemployment rate has the strong positive correlation (r=0.59)
# 3. Poverty rate and % uninsured adults has the strong positive correlation (r=0.54)

# %% [markdown]
# ### Bi-variate: Cross Tabulation ###

# %%
# plot a cross-tabulation:
plot_crosstab(df_eda, 'area__rucc', 'econ__economic_typology')
# Out:
# econ__economic_typology                             Farm-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...               6
# Metro - Counties in metro areas of 250,000 to 1...               8
# Metro - Counties in metro areas of fewer than 2...              36
# Nonmetro - Completely rural or less than 2,500 ...              70
# Nonmetro - Completely rural or less than 2,500 ...             248
# Nonmetro - Urban population of 2,500 to 19,999,...              52
# Nonmetro - Urban population of 2,500 to 19,999,...              60
# Nonmetro - Urban population of 20,000 or more, ...               0
# Nonmetro - Urban population of 20,000 or more, ...               2
#
# econ__economic_typology                             Federal/State government-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...                                  38
# Metro - Counties in metro areas of 250,000 to 1...                                  54
# Metro - Counties in metro areas of fewer than 2...                                  60
# Nonmetro - Completely rural or less than 2,500 ...                                  28
# Nonmetro - Completely rural or less than 2,500 ...                                  50
# Nonmetro - Urban population of 2,500 to 19,999,...                                  66
# Nonmetro - Urban population of 2,500 to 19,999,...                                  46
# Nonmetro - Urban population of 20,000 or more, ...                                  28
# Nonmetro - Urban population of 20,000 or more, ...                                  20
#
# econ__economic_typology                             Manufacturing-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...                       46
# Metro - Counties in metro areas of 250,000 to 1...                       54
# Metro - Counties in metro areas of fewer than 2...                       42
# Nonmetro - Completely rural or less than 2,500 ...                       38
# Nonmetro - Completely rural or less than 2,500 ...                       36
# Nonmetro - Urban population of 2,500 to 19,999,...                      160
# Nonmetro - Urban population of 2,500 to 19,999,...                       50
# Nonmetro - Urban population of 20,000 or more, ...                       48
# Nonmetro - Urban population of 20,000 or more, ...                       20
#
# econ__economic_typology                             Mining-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...                12
# Metro - Counties in metro areas of 250,000 to 1...                12
# Metro - Counties in metro areas of fewer than 2...                22
# Nonmetro - Completely rural or less than 2,500 ...                18
# Nonmetro - Completely rural or less than 2,500 ...                52
# Nonmetro - Urban population of 2,500 to 19,999,...                50
# Nonmetro - Urban population of 2,500 to 19,999,...                72
# Nonmetro - Urban population of 20,000 or more, ...                12
# Nonmetro - Urban population of 20,000 or more, ...                 4
#
# econ__economic_typology                             Nonspecialized  Recreation
# area__rucc
# Metro - Counties in metro areas of 1 million po...             292          42
# Metro - Counties in metro areas of 250,000 to 1...             206          36
# Metro - Counties in metro areas of fewer than 2...             140          22
# Nonmetro - Completely rural or less than 2,500 ...              56          28
# Nonmetro - Completely rural or less than 2,500 ...              52          46
# Nonmetro - Urban population of 2,500 to 19,999,...             232          48
# Nonmetro - Urban population of 2,500 to 19,999,...             142          48
# Nonmetro - Urban population of 20,000 or more, ...             102          32
# Nonmetro - Urban population of 20,000 or more, ...              44          10

# %% [markdown]
# ### Summary: Cross Tabulation ###
# 1. With respect to non-specialized: the largest number of counties were non-specialized and non-metro with population size of 2,500 to 19,999. Followed by non-specialized and metro counties with population over 1 million.
# 2. With respect to farm-dependent: most of counties were dependent on farming industries in non-metro with less than 2,500 population (rural area).
# 3. In mid-size non-metro with population of 2,500 to 19,999, most of counties were dependent on manufacturing and mining.
# 4. In small size non-metro with population of 2,500 to 19,999 were mostly dependent on federal/state government funding.

# %% [markdown]
# ### Bi-variate: Scatter Plot ###

# %%
#---- Plot a scatter plot: w numerical variables ----#
plot_scatter(df_eda, 'demo__pct_adults_less_than_a_high_school_diploma', 'poverty_rate', 'orange', 100)

# %% [markdown]
# ### Summary: Scatter Plot ###
# % adults less than a highschool diploma has a positive correlation with poverty rate.

# %% [markdown]
# ### Linear Regression Analyses ###

# %%
#---- Plot a linear regression plot: w numerical variables ----#
# Compute Pearson r for combination of X and Y:
r_labor_poverty = compute_pearson_r(df_eda, 'econ__pct_civilian_labor', 'poverty_rate')

r_uninsured_adults_poverty = compute_pearson_r(df_eda, 'econ__pct_uninsured_adults', 'poverty_rate')

r_birthweight_poverty = compute_pearson_r(df_eda, 'health__pct_low_birthweight', 'poverty_rate')

r_drinking_poverty = compute_pearson_r(df_eda, 'health__pct_excessive_drinking', 'poverty_rate')

# %%
# Plot a linear regression analysis:
plot_linear_reg(df_eda, 'econ__pct_civilian_labor', 'poverty_rate',
                r_labor_poverty, 'green', 'counties')
plt.show()

# %%
plot_linear_reg(df_eda, 'econ__pct_uninsured_adults', 'poverty_rate',
                r_uninsured_adults_poverty, 'blue', 'counties')
plt.show()

# %%
plot_linear_reg(df_eda, 'health__pct_low_birthweight', 'poverty_rate',
                r_birthweight_poverty, 'crimson', 'counties')
plt.show()

# %%
plot_linear_reg(df_eda, 'health__pct_excessive_drinking', 'poverty_rate',
                r_drinking_poverty, 'purple', 'counties')
plt.show()
