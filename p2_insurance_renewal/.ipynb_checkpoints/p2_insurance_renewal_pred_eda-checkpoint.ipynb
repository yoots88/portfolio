# %% [markdown]
# ## Capstone Project: Insurance Renewal Propensity - Exploratory Data Analysis ##
#
# This is a data science portfolio for solving the insurance use case. The dataset used in this project is sourced from the data science competition sponsored by the McKinsey analytics consulting firm.
# The competition link can be found here [contest page] (https://datahack.analyticsvidhya.com/contest/mckinsey-analytics-online-hackathon-4/).
#
# **Problem Statement:**
# an insurance company needs the data scientist's help in building a model to predict the propensity for paying renewal premium and build an incentive plan for its agents to maximize the total net revenue (i.e., incentives provided to collect renewal premiums) from their policyholders (clients).
#
# The insurance propensity dataset comes with information about the policyholders' demographics and aggregated past historical transaction data like # of premiums paid on time, # of premiums paid late, client sourcing channel etc.
#
# **Stakeholders:**
# * Insurance company senior management
# * Insurance company sales agents
# * Insurance policy holders - clients

# %% [markdown]
# ## Part A. Import Cleaned Dataset ##

# %%
# Import all libraries #
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import csv
from sklearn.utils import shuffle
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# Authorization #
__author__ = "Taesun Yoo"
__email__ = "yoots1988@gmail.com"

# %%
# --- 1. Write Out List of Functions --- #
def load_file(file):
    '''load input CSVs as a dataframe'''
    return pd.read_csv(file, encoding='latin1')


def convert_dt_as_date(df, var_name, date_format):
    '''convert the variable as specified date format'''
    df[var_name] = pd.to_datetime(df[var_name], format=date_format)
    return df[var_name]


def convert_dt_as_custom(df, var_name, dt_type):
    '''convert datatype on selected variables'''
    df[var_name] = df[var_name].astype(dt_type)
    return df[var_name]


def convert_dt_to_cat(df):
    '''convert data type to category'''
    for col in df.columns:
        if df[col].dtype.name == 'object':
            df[col] = df[col].astype('category')


def eda_encode_cat_var(df, col, num_var):
    '''encode the cat. variables by mean of a num. variable by each cat'''
    cat_dict={}
    cats = df[col].cat.categories.tolist()
    for cat in cats:
        cat_dict[cat] = df[df[col] == cat][num_var].mean()
    df[col] = df[col].map(cat_dict)


#def pandas_qcut(df, new_var, old_var, q):
#    ''' apply pd.qcut for equal size binning '''
#    df[new_var] = pd.qcut(df[old_var], q=q, duplicates='drop',
#                          precision=0, labels=None)
#    return df[new_var]


def estimate_width(df, var_name, interval_size):
    ''' estimate the width of continuous variable '''
    width = (max(df[var_name]) - min(df[var_name]))/interval_size
    df_estimate = pd.DataFrame([[min(df[var_name])-1, max(df[var_name])+1, round(width)]])
    df_estimate.columns = ['min', 'max', 'width']
    return df_estimate


def pandas_cut(df, new_var, old_var, bins, labels=None):
    ''' apply pd.cut for custom size binning '''
    df[new_var] = pd.cut(df[old_var], bins=bins, 
                          labels=labels, right=False)
    return df[new_var]


def check_value_counts(df, var_name):
    '''return grouped value counts'''
    grouped_counts = df[var_name].value_counts()
    return grouped_counts


def feature_replacement(X):
    ''' replace missing values based on specific data type of a column '''
    for col in X.columns:
        if X[col].dtype.name == 'object':
            mode = X[col].mode().iloc[0]
            X[col] = X[col].fillna(mode)
        elif X[col].dtype.name == 'float64':
            mean = X[col].mean()
            X[col] = X[col].fillna(mean)
        else:
            X[col].dtype.name == 'int64'
            median = X[col].median()
            X[col] = X[col].fillna(median)
            

def eda_missing(df):
    '''compute missing % on each var'''
    df_missing = pd.DataFrame(df.isnull().sum(), columns=['count'])
    df_missing['pct'] = (df_missing['count']/len(df)) * 100
    return df_missing


def eda_stat_num(df):
    ''' perform eda for numerical features '''
    df_stat_num = df.describe().T
    df_stat_num = df_stat_num[['count', 'min', 'mean', 'max', 'std', '25%', '50%', '75%']]
    df_stat_num = pd.DataFrame(df_stat_num)
    return df_stat_num


def eda_stat_cat(df):
    ''' perform eda for categorical features '''
    df_stat_cat = df.describe(include='category').T
    df_stat_cat = pd.DataFrame(df_stat_cat)
    return df_stat_cat


def eda_outliers(df):
    '''check outliers using the IQR method'''
    df['IQR'] = df['75%'] - df['25%']
    df['LB']  = df['25%'] - 1.5*df['IQR']
    df['UB']  = df['75%'] + 1.5*df['IQR']
    df = df.drop(['count','std','mean','25%','50%','75%','IQR'], axis=1)
    return df


def eda_agg_df_var(df, cat_var, kpi_dict):
    '''compute aggregated dataframe to calculate the KPIs'''
    df_agg = df.groupby(by=cat_var).agg(kpi_dict)
    return df_agg


def eda_grouped_df_var(df, cat_var):
    '''create a grouped dataframe by categorical variable'''
    df_grp = pd.DataFrame(df.groupby([cat_var])[cat_var].count())
    df_grp.columns = ['count']
    return df_grp


def plot_hist(df, var_1):
    '''plot a histogram'''
    plt.figure()
    print("skenewss is:", df[var_1].skew())
    df[var_1].hist(color='green')
    plt.title('Histogram of ' + var_1)
    plt.xlabel(var_1)
    plt.ylabel('clients')
    plt.show()


def plot_bar_chart(df, var_name_1):
    '''plot a bar chart'''
    plt.figure()
    var_count_1 = df[var_name_1].value_counts()
    sns.barplot(var_count_1.index,  var_count_1.values, alpha=0.9)
    plt.title('Frequency chart of ' + var_name_1)
    plt.ylabel('clients')
    plt.xlabel(var_name_1)
    plt.show()

    
def plot_freq_chart(x,y,df,order):
    '''plot a frequency chart'''
    plt.figure(figsize=(8,8))
    sns.countplot(x=x, hue=y, data=df, order=order)
    plt.title('Bar chart: ' + x + ' of client group labels', fontsize=20)
    plt.xticks(rotation=270, fontsize=12)
    plt.yticks(fontsize=12)
    plt.xlabel(x, fontsize=12)
    plt.ylabel('patients', fontsize=12)
    plt.legend(loc='upper right', fontsize=20)
    plt.show()


def plot_pie_chart(df_1, var_name_1,
                   df_2, var_name_2):
    '''plot a pie chart of specified variables'''
    plt.figure(figsize=(15,15))
    # Sub-plot 1:
    plt.subplot(1,2,1)
    plt.pie(df_1, autopct='%.0f%%', wedgeprops={'edgecolor':'white'},
            textprops={'fontsize':15})
    plt.title('Pie Chart of '+ var_name_1)
    plt.legend(labels = df_1.index, loc='upper right')
    # Sub-plot 2:
    plt.subplot(1,2,2)
    plt.pie(df_2, autopct='%.0f%%', wedgeprops={'edgecolor':'white'},
            textprops={'fontsize':15})
    plt.title('Pie Chart of '+ var_name_2)
    plt.legend(labels = df_2.index, loc='upper right')
    plt.show()
    

def plot_box(df, num_var_1, cat_var_1,
             num_var_2, cat_var_2, 
             num_var_3, cat_var_3, hue=None):
    '''plot a box-whisker of specified variables'''
    plt.figure(figsize=(15,15))
    plt.subplots_adjust(hspace=0.5, wspace=0.5)
    # Sub-plot 1:
    plt.subplot(1,3,1)
    df.sort_values(by=[num_var_1], inplace=True)
    sns.set(style='whitegrid')
    sns.boxplot(cat_var_1, num_var_1, hue, df)
    plt.title('Box plot of ' + num_var_1 + ' by ' + cat_var_1)
    plt.xticks(rotation=270, fontsize=10)
    # Sub-plot 2:
    plt.subplot(1,3,2)
    df.sort_values(by=[num_var_2], inplace=True)
    sns.set(style='whitegrid')
    sns.boxplot(cat_var_2, num_var_2, hue, df)
    plt.title('Box plot of ' + num_var_2 + ' by ' + cat_var_2)
    plt.xticks(rotation=270, fontsize=10)
    # Sub-plot 3:
    plt.subplot(1,3,3)
    df.sort_values(by=[num_var_3], inplace=True)
    sns.set(style='whitegrid')
    sns.boxplot(cat_var_3, num_var_3, hue, df)
    plt.title('Box plot of ' + num_var_3 + ' by ' + cat_var_3)
    plt.xticks(rotation=270, fontsize=10)    

    
def plot_crosstab(df, cat_var_1, cat_var_2):
    '''plot a crosstab of two categorical variables'''
    table = pd.crosstab(df[cat_var_1], df[cat_var_2])
    return table


def plot_corr_matrix(df, list_vars):
    ''' plot a correlation matrix '''
    corr = df[list_vars].corr()
    # Create a mask
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(corr)] = True
    plt.figure(figsize=(12,12))
    sns.heatmap(corr, mask=mask, square=True, linewidths = .5,
                cmap=sns.diverging_palette(220,10,as_cmap=True),
                vmin = -1, vmax = 1, fmt=".2f",
                annot=True, annot_kws={'size':15})
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.show()


def plot_scatter(df, var_1, var_2, color, factor=None):
    '''Scatter plot of two continuous numeric features'''
    plt.figure(figsize=(8,8))
    plt.scatter(df[var_1], df[var_2], color=color)
    plt.title('Relationship between '+ var_1 + ' and ' + var_2)
    plt.xlabel(var_1)
    plt.ylabel(var_2)
    plt.show()

    
def compute_pearson_r(df, var_x, var_y):
    '''compute Pearson r correlation'''
    corr_mat = np.corrcoef(df[var_x],df[var_y])
    return corr_mat[0, 1]


def plot_linear_reg(df, var_x, var_y, 
                    pearson_r, color, label):
    '''plot a pair of linear regressions'''
    plt.figure(figsize=(10,10))
    plt.plot(df[var_x], df[var_y], 'r--', label='pearson_r =%.2f' % pearson_r,
             marker='.', linestyle='none', color=color)
    plt.margins(0.02)
    plt.legend(loc='upper left')
    plt.xlabel(var_x)
    plt.ylabel(var_y)
    plt.title(var_x + ' vs. ' + var_y + ' by ' + label)
    # Fit linear regression:
    a,b = np.polyfit(df[var_x], df[var_y], 1)
    x = np.array([min(df[var_x]), max(df[var_x])])
    y = a*x + b
    plt.plot(x,y)

# %%
# --- 2. Load the data --- #
# define input CSVs:
if __name__ == '__main__':
    eda_file = 'insurance_train.csv'

# load data:
df_eda = load_file(eda_file)

# map column names to lowercase:
df_eda.columns = map(str.lower, df_eda.columns)

# check data types:
df_eda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79853 entries, 0 to 79852
# Data columns (total 13 columns):
# id                                  79853 non-null int64
# perc_premium_paid_by_cash_credit    79853 non-null float64
# age_in_days                         79853 non-null int64
# income                              79853 non-null int64
# count_3-6_months_late               79756 non-null float64
# count_6-12_months_late              79756 non-null float64
# count_more_than_12_months_late      79756 non-null float64
# application_underwriting_score      76879 non-null float64
# no_of_premiums_paid                 79853 non-null int64
# sourcing_channel                    79853 non-null object
# residence_area_type                 79853 non-null object
# premium                             79853 non-null int64
# renewal                             79853 non-null int64
# dtypes: float64(5), int64(6), object(2)
# memory usage: 7.9+ MB

# %% [markdown]
# ### Feature Engineering ###
# Create a new feature from existing feature(s)

# %%
# feature engineering:
# create age from age_in_days
df_eda['age'] = df_eda['age_in_days']/365.25
df_eda['age'] = df_eda['age'].astype('int64')

# drop age_in_days:
df_eda.drop('age_in_days', axis=1, inplace=True) 

# define variables:
vars_cat = list(df_eda.select_dtypes(include='object').columns)
vars_num_disc = list(df_eda.select_dtypes(include='int64'))
vars_num_cont = list(df_eda.select_dtypes(include='float64'))

# concatenate a list:
vars_num = vars_num_disc + vars_num_cont

# delete a list of unwanted variables:
unwanted_list = {'id', 'renewal'}
vars_num = [var for var in vars_num if var not in unwanted_list]

var_label = 'renewal'
var_id = 'id'

# %% [markdown]
# ## Part B. Exploratory Data Analysis ##
#
# ### Dataset Name: Training Set ###
# Data exploration is conducted on a cleaned training set. The main goal of this phase is to explore any interesting relationships among features and identify which features are good predictors on poverty rate predictions.
#
# Following set of questions are asked:
# 1. Can I count something interesting?
# 2. Can I find some trends (increase or decrease and any anomalies)?
# 3. Can I plot a bar chart or a histogram?
# 4. Can I make a scatter plot?
#
# These set of guiding questions will help us to explore any insights and tell a compelling story about the US poverty dataset.

# %%
# compute top 10 rows:
df_eda.head(10)

# check duplicates:
df_eda.duplicated().sum()
# Out:
# 0

# %%
# create a missing % dataframe:
df_missing_pre = eda_missing(df_eda)
df_missing_pre
# Out:
#                                   count       pct
# id                                    0  0.000000
# perc_premium_paid_by_cash_credit      0  0.000000
# income                                0  0.000000
# count_3-6_months_late                97  0.121473
# count_6-12_months_late               97  0.121473
# count_more_than_12_months_late       97  0.121473
# application_underwriting_score     2974  3.724343
# no_of_premiums_paid                   0  0.000000
# sourcing_channel                      0  0.000000
# residence_area_type                   0  0.000000
# premium                               0  0.000000
# renewal                               0  0.000000
# age                                   0  0.000000

# %% [markdown]
# ### Summary: Missing Values % ###
# Above table shows that missing value % on each feature. app_underwriting_score misses about 3.7%.

# %%
# compute feature impuation by data types:
feature_replacement(df_eda)

# %%
# create a missing % dataframe:
df_missing_post = eda_missing(df_eda)
df_missing_post
# Out:
#                                   count  pct
# id                                    0  0.0
# perc_premium_paid_by_cash_credit      0  0.0
# income                                0  0.0
# count_3-6_months_late                 0  0.0
# count_6-12_months_late                0  0.0
# count_more_than_12_months_late        0  0.0
# application_underwriting_score        0  0.0
# no_of_premiums_paid                   0  0.0
# sourcing_channel                      0  0.0
# residence_area_type                   0  0.0
# premium                               0  0.0
# renewal                               0  0.0
# age                                   0  0.0

# %%
# convert data type: object to category
convert_dt_to_cat(df_eda)

# %%
# numerical features:
df_stat_num = eda_stat_num(df_eda[vars_num])
df_stat_num
# Out:
#                                     count      min           mean  \
# income                            79853.0  24030.0  208847.171177
# no_of_premiums_paid               79853.0      2.0      10.863887
# premium                           79853.0   1200.0   10924.507533
# age                               79853.0     20.0      50.898714
# perc_premium_paid_by_cash_credit  79853.0      0.0       0.314288
# count_3-6_months_late             79853.0      0.0       0.248671
# count_6-12_months_late            79853.0      0.0       0.078188
# count_more_than_12_months_late    79853.0      0.0       0.060008
# application_underwriting_score    79853.0     91.9      99.067291
#
#                                           max            std         25%  \
# income                            90262600.00  496582.597257  108010.000
# no_of_premiums_paid                     60.00       5.170687       7.000
# premium                              60000.00    9401.676542    5400.000
# age                                    102.00      14.030212      40.000
# perc_premium_paid_by_cash_credit         1.00       0.334915       0.034
# count_3-6_months_late                   13.00       0.691048       0.000
# count_6-12_months_late                  17.00       0.436242       0.000
# count_more_than_12_months_late          11.00       0.311833       0.000
# application_underwriting_score          99.89       0.725892      98.830
#
#                                          50%         75%
# income                            166560.000  252090.000
# no_of_premiums_paid                   10.000      14.000
# premium                             7500.000   13800.000
# age                                   50.000      61.000
# perc_premium_paid_by_cash_credit       0.167       0.538
# count_3-6_months_late                  0.000       0.000
# count_6-12_months_late                 0.000       0.000
# count_more_than_12_months_late         0.000       0.000
# application_underwriting_score        99.180      99.520

# %% [markdown]
# ### Summary: Numerical Features ###
# * age: mean is around 51
# * premium: mean is around ~ 11K
# * income: mean is around ~209K
# * % premium paid by cash credit: mean is 31%

# %%
# categorical features:
df_stat_cat = eda_stat_cat(df_eda[vars_cat])
df_stat_cat
# Out:
#                      count unique    top   freq
# sourcing_channel     79853      5      A  43134
# residence_area_type  79853      2  Urban  48183

# %% [markdown]
# ### Summary: Categorical Features ###
# * sourcing channel: majority of clients are sourced from channel A
# * residence area type: majority of clients are from Urban

# %%
# ---4 detect outliers ---
# create a dataframe for IQR:
df_outliers = eda_outliers(df_stat_num)
df_outliers

# check outliers:
# lower bounds (LBs)
df_eda[df_eda.application_underwriting_score < 97.795]

# upper bounds (UBs)
df_eda[df_eda.income > 468210]
# Out:
#           id  perc_premium_paid_by_cash_credit   income  \
# 69     97679                             0.480   494050
# 92     34577                             0.163   900030
# 131    66151                             0.113   509070
# 141    94682                             0.108   510070
# 163    90621                             0.559   495070
# ...      ...                               ...      ...
# 79753  22565                             0.055  2158630
# 79792  74003                             0.039  1050120
# 79815  72094                             0.478   750120
# 79817   4719                             0.871   501120
# 79840  23546                             0.034   500070
#
#        count_3-6_months_late  count_6-12_months_late  \
# 69                       0.0                     0.0
# 92                       0.0                     0.0
# 131                      0.0                     0.0
# 141                      0.0                     0.0
# 163                      1.0                     0.0
# ...                      ...                     ...
# 79753                    0.0                     0.0
# 79792                    0.0                     0.0
# 79815                    0.0                     0.0
# 79817                    0.0                     0.0
# 79840                    0.0                     0.0
#
#        count_more_than_12_months_late  application_underwriting_score  \
# 69                                0.0                           98.89
# 92                                0.0                           99.66
# 131                               0.0                           99.26
# 141                               0.0                           98.62
# 163                               0.0                           99.10
# ...                               ...                             ...
# 79753                             0.0                           99.84
# 79792                             0.0                           99.80
# 79815                             0.0                           99.59
# 79817                             0.0                           99.05
# 79840                             0.0                           99.42
#
#        no_of_premiums_paid sourcing_channel residence_area_type  premium  \
# 69                      20                B               Urban    24300
# 92                      12                A               Rural    39000
# 131                     22                C               Urban    24300
# 141                     12                A               Urban     5400
# 163                     11                B               Urban    22200
# ...                    ...              ...                 ...      ...
# 79753                   10                A               Rural    20100
# 79792                    6                A               Urban    47400
# 79815                   23                B               Rural    51600
# 79817                   18                D               Urban    26400
# 79840                   10                E               Rural    49500
#
#        renewal  age
# 69           1   72
# 92           1   60
# 131          1   51
# 141          1   63
# 163          1   38
# ...        ...  ...
# 79753        1   62
# 79792        1   41
# 79815        1   60
# 79817        1   50
# 79840        1   47
#
# [3428 rows x 13 columns]

# %% [markdown]
# ### Feature Discretization ###
# We are going to convert a few of selected continuous numerical features into meaningful categorical groups.
# First, we start by defining an appropriate bin size based on range of each numerical feature (i.e., min. and max. values)
# Second, label them appropriately in ordinal manner which applies to some features.

# %%
# define bin_size and labels:
# age_group:
estimate_width(df_eda, 'age', 4)
bins_age = [19, 40, 60, 80, 103]
labels_age = ['Age 20-40s', 'Age 40-60s', 'Age 60-80s', 'Age +80']

# premium_group:
estimate_width(df_eda, 'premium', 4)
bins_premium = [1199, 15900, 30600, 45300, 60001]

# income_group: extremely right skewed
estimate_width(df_eda, 'income', 4)
bins_income = [24000, 69000, 114000, 159000, 
               204000, 294000, 339000, 384000,
               429000, 474000, 90262601]

# num_prem_paid_group:
estimate_width(df_eda, 'no_of_premiums_paid', 10)
bins_prem_paid = [0, 6, 12, 18, 24, 30, 36, 42, 48, 54, 61]

# cnt_3_6_mo_late_group:
estimate_width(df_eda, 'count_3-6_months_late', 4)
bins_cnt_3_6_mo = [0, 3, 6, 9, 12, 15]

# cnt_6_12_mo_late_group:
estimate_width(df_eda, 'count_6-12_months_late', 4)
bins_cnt_6_12_mo = [0, 4, 8, 12, 16, 20]

# cnt_over_12_mo_late_group:
estimate_width(df_eda, 'count_more_than_12_months_late', 4)
bins_cnt_over_12_mo = [0, 3, 6, 9, 12, 15]

# feature discretization:
df_eda['age_group'] = pandas_cut(df_eda, 'age_group', 'age', bins=bins_age, labels=labels_age)
df_eda['premium_group'] = pandas_cut(df_eda, 'premium_group', 'premium', bins=bins_premium)
df_eda['income_group'] = pandas_cut(df_eda, 'income_group', 'income', bins=bins_income)
df_eda['num_prem_paid_group'] = pandas_cut(df_eda, 'num_prem_paid_group', 
                                           'no_of_premiums_paid', bins=bins_prem_paid)
df_eda['cnt_3_6_mo_late_group'] = pandas_cut(df_eda, 'cnt_3_6_mo_late_group', 
                                             'count_3-6_months_late', bins=bins_cnt_3_6_mo)
df_eda['cnt_6_12_mo_late_group'] = pandas_cut(df_eda, 'cnt_6_12_mo_late_group', 
                                              'count_6-12_months_late', bins=bins_cnt_6_12_mo)
df_eda['cnt_over_12_mo_late_group'] = pandas_cut(df_eda, 'cnt_over_12_mo_late_group', 
                                                 'count_more_than_12_months_late', bins=bins_cnt_over_12_mo)

# check engineered categorical groups:
check_value_counts(df_eda, 'age_group')
check_value_counts(df_eda, 'premium_group')
check_value_counts(df_eda, 'income_group')
check_value_counts(df_eda, 'num_prem_paid_group')
check_value_counts(df_eda, 'cnt_3_6_mo_late_group')
check_value_counts(df_eda, 'cnt_6_12_mo_late_group')
check_value_counts(df_eda, 'cnt_over_12_mo_late_group')
# Out:
# [0, 3)      79629
# [3, 6)        212
# [6, 9)         11
# [9, 12)         1
# [12, 15)        0
# Name: cnt_over_12_mo_late_group, dtype: int64

# %%
# ---5 aggregate dataframe and compute KPIs ---
# Define the dictionary for KPIs:
kpi_dict = {'id':'nunique', 'age':'mean', 'income':'mean', 
            'premium':'mean', 'no_of_premiums_paid': 'mean',
            'count_3-6_months_late':'mean', 'count_6-12_months_late':'mean',
            'perc_premium_paid_by_cash_credit':'mean', 'application_underwriting_score':'mean'}

df_agg_renewal = eda_agg_df_var(df_eda, 'renewal', kpi_dict)

# Print a summary KPI table by Renewal Status:
df_agg_renewal
# Out:
#             id        age         income       premium  no_of_premiums_paid  \
# renewal
# 0         4998  45.735894  177058.799520   9599.519808            10.410364
# 1        74855  51.243431  210969.651727  11012.975753            10.894169
#
#          count_3-6_months_late  count_6-12_months_late  \
# renewal
# 0                     0.910548                0.558562
# 1                     0.204478                0.046114
#
#          perc_premium_paid_by_cash_credit  application_underwriting_score
# renewal
# 0                                0.626626                       98.878141
# 1                                0.293433                       99.079921

# %% [markdown]
# ### Summary: Renewal Status ###
# Comparison between non-renewed vs. renewed client groups:
# * mean age of non-renewed client group is younger and % of premium paid by cash credit is higher.
# * Also average income and average premium paid amount are lower than renewed client group.

# %% [markdown]
# ### Uni-variate: Histogram Plots ###

# %%
# plot a histogram:    
plot_hist(df_eda, 'age')

plot_hist(df_eda, 'premium')

plot_hist(df_eda, 'perc_premium_paid_by_cash_credit')

plot_hist(df_eda, 'application_underwriting_score')
# Out:
# skenewss is: 0.2400264858282591
# skenewss is: 2.198178310141652
# skenewss is: 0.8929224698429875
# skenewss is: -2.8088987249994264

# %% [markdown]
# ### Summary: Histograms ###
# * Age: close to normal distribution with mean is around 51.
# * Premium: positively skewed with majority of clients paid premium lower than 15K.
# * % Premium Paid by Cash Credit: positively skewed with majority of clients less than 15%
# * Underwriting Score: negatively skewed with majority of clients above score 99.

# %% [markdown]
# ### Uni-variate: Bar Charts ###

# %%
# plot a bar chart:
plot_bar_chart(df_eda, 'sourcing_channel')

plot_bar_chart(df_eda, 'residence_area_type')

# %% [markdown]
# ### Summary: Bar Charts ###
# * Sourcing Channel: majority of clients sourced from Channel A followed by B, C, D and E.
# * Residence Area Type: majority of clients reside in Urban area.

# %% [markdown]
# ### Frequency Charts ###

# %%
# plot a frequency chart:
plot_freq_chart('age_group', 'renewal', df_eda, None)

plot_freq_chart('income_group', 'renewal', df_eda, None)

plot_freq_chart('premium_group', 'renewal', df_eda, None)

# %% [markdown]
# ### Summary: Frequency Chart 1 ###
# * Age Group: majority of client age group is around 40 to 60s.
# * Income Group: majority of client income group is around 204K.
# * Premium Group: majority of client premium paid group is around 16K.

# %%
plot_freq_chart('num_prem_paid_group', 'renewal', df_eda, None)

plot_freq_chart('cnt_3_6_mo_late_group', 'renewal', df_eda, None)

# %% [markdown]
# ### Summary: Frequency Chart 2 ###
# * No. of Premium Paids Group: majority of client # of paid group is around 6 to 12 times.
# * No. of Premium Paid late by 3 to 6 month: majority of clients paid late around 0 to 3 times.

# %% [markdown]
# ### Uni-variate: Pie Charts ###

# %%
# grouped dataframe by a categorical feature:
df_grp_renewal = eda_grouped_df_var(df_eda, 'renewal')
df_grp_residence_type = eda_grouped_df_var(df_eda, 'residence_area_type')
df_grp_age_group = eda_grouped_df_var(df_eda, 'age_group')
df_grp_sourcing_channel = eda_grouped_df_var(df_eda, 'sourcing_channel')

# Plot pie chart(s) by categorical features:
plot_pie_chart(df_grp_renewal, 'Renewal',
               df_grp_residence_type, 'Residence Type')

plot_pie_chart(df_grp_age_group, 'Age Group',
               df_grp_sourcing_channel, 'Sourcing Channel')
# Out:
# C:\Users\yoots\Anaconda3\lib\site-packages\ipykernel_launcher.py:164: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
# C:\Users\yoots\Anaconda3\lib\site-packages\ipykernel_launcher.py:170: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.

# %% [markdown]
# ### Summary: Pie Chart ###
# * Renewal Status: 94 % of clients renewed their policies.
# * Residence Type: 60% of clients reside in Urban area.
# * Age Group: about 50% of clients from 40-60s followed by 60-80s, 20-40s and +80.
# * Sourcing Channel: 54% of clients from Channel A followed by B, C, D, E

# %% [markdown]
# ### Bi-variate: Box-Whisker Plots ###

# %%
# plot a box-whisker:    
plot_box(df_eda, 'age', 'renewal',
        'premium', 'renewal',
        'perc_premium_paid_by_cash_credit', 'renewal')

# %% [markdown]
# ### Summary: Box-Whisker Plot ###
# * Age: mean age of renewed client group is higher than non-renewed group.
# * Premium: mean premiumd paid amout of renewed client group is higher than non-renewed group.
# * % Premiumd Paid by Cash Credit: non-renewed group has higher usage of cash credit than renewed group.

# %% [markdown]
# ### Bi-variate: Correlation Matrix Plot ###

# %%
# create a dataframe:
df_eda_cm = df_eda.copy()

# check data type:
df_eda_cm.info()

# convert data type: object to category
convert_dt_to_cat(df_eda_cm)

# encode categorical variables using age:
for col in df_eda_cm.columns:
    if df_eda_cm[col].dtype.name == 'category':
        eda_encode_cat_var(df_eda_cm, col, 'age')

# Create a list of variables:
vars_list = list(df_eda_cm.columns)

# Delete a list of unwanted variables:
unwanted_list = {'sourcing_channel', 'residence_area_type', 
                 'age_group', 'premium_group', 'num_prem_paid_group',
                 'cnt_3_6_mo_late_group', 'cnt_6_12_mo_late_group', 
                 'cnt_over_12_mo_late_group', 'id'}

vars_list = [item for item in vars_list if item not in unwanted_list]

# plot a correlation matrix:
plot_corr_matrix(df_eda_cm, vars_list)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79853 entries, 18662 to 38441
# Data columns (total 20 columns):
# id                                  79853 non-null int64
# perc_premium_paid_by_cash_credit    79853 non-null float64
# income                              79853 non-null int64
# count_3-6_months_late               79853 non-null float64
# count_6-12_months_late              79853 non-null float64
# count_more_than_12_months_late      79853 non-null float64
# application_underwriting_score      79853 non-null float64
# no_of_premiums_paid                 79853 non-null int64
# sourcing_channel                    79853 non-null category
# residence_area_type                 79853 non-null category
# premium                             79853 non-null int64
# renewal                             79853 non-null int64
# age                                 79853 non-null int64
# age_group                           79853 non-null category
# premium_group                       79853 non-null category
# income_group                        79853 non-null category
# num_prem_paid_group                 79853 non-null category
# cnt_3_6_mo_late_group               79853 non-null category
# cnt_6_12_mo_late_group              79853 non-null category
# cnt_over_12_mo_late_group           79853 non-null category
# dtypes: category(9), float64(5), int64(6)
# memory usage: 8.0 MB

# %% [markdown]
# ### Summary: Correlation Matrix Plot ###
# 1. Renewal status shows negative moderate correlation with count premium paid 6-12 months late (r=-0.28)
# 2. Renewal status shows negative weak correlation with % premium paid by cash credit (r=-0.24).
# 3. Premium shows positive moderate correlation with income (r=0.30)
# 4. Age shows negative weak correlation with % premium paid by cash credit (r=-0.26)

# %% [markdown]
# ### Bi-variate: Cross Tabulation ###

# %%
# plot a cross-tabulation:
plot_crosstab(df_eda, 'age_group', 'renewal')
# Out:
# renewal        0      1
# age_group
# Age 20-40s  1636  16603
# Age 40-60s  2676  36669
# Age 60-80s   639  19584
# Age +80       47   1999

# %%
plot_crosstab(df_eda, 'sourcing_channel', 'renewal')
# Out:
# renewal              0      1
# sourcing_channel
# A                 2349  40785
# B                 1066  15446
# C                  903  11136
# D                  634   6925
# E                   46    563

# %% [markdown]
# ### Summary: Cross Tabulation ###
# 1. renewal and age group: shows that age +80 group have the lowest # of clients in both groups. Majority of clients are from age 40-60s in both renewed and non-renewed client groups.
# 2. renewal and sourcing channel: shows that channel E group has the lowest # of clients in both groups. Majority of clients are from Channel A.

# %% [markdown]
# ### Linear Regression Analyses ###

# %%
#---- Plot a linear regression plot: w numerical variables ----#
# Compute Pearson r for combination of X and Y:
r_age_num_prem_paid= compute_pearson_r(df_eda, 'age', 'no_of_premiums_paid')

r_age_pct_paid_cash_credit = compute_pearson_r(df_eda, 'age', 'perc_premium_paid_by_cash_credit')

r_income_premium = compute_pearson_r(df_eda, 'income', 'premium')

r_prem_paid_app_score = compute_pearson_r(df_eda, 'no_of_premiums_paid', 'application_underwriting_score')

# %%
# Plot a linear regression analysis:
plot_linear_reg(df_eda, 'age', 'no_of_premiums_paid',
                r_age_num_prem_paid, 'green', 'clients')
plt.show()

# %% [markdown]
# ### Summary: age vs. # of premiums paid ###
# There is a positively weak correlation between age and # of premiums paid (r=0.18). It seems that older clients are likely to pay premiums more frequently than younger clients.

# %%
# Plot a linear regression analysis:
plot_linear_reg(df_eda, 'age', 'perc_premium_paid_by_cash_credit',
                r_age_pct_paid_cash_credit, 'blue', 'clients')
plt.show()

# %% [markdown]
# ### Summary: age vs. % of premiums paid by cash credit ###
# There is a negatively weak correlation between age and % premiums paid by cash credit (r=-0.26). It seems that older clients are less likely to paid their premiums by cash credit than younger clients.

# %%
# Plot a linear regression analysis:
plot_linear_reg(df_eda, 'income', 'premium',
                r_income_premium, 'purple', 'clients')
plt.show()

# %% [markdown]
# ### Summary: income vs.  premium paid amount ###
# There is a positively moderate correlation between income and premium (r=0.30). It seems that higher the income, higher the premium paid amount.

# %%
# Plot a linear regression analysis:
plot_linear_reg(df_eda, 'no_of_premiums_paid', 'application_underwriting_score',
                r_prem_paid_app_score, 'orange', 'clients')
plt.show()

# %% [markdown]
# ### Summary: # of premiums paid vs. application underwriting score ###
# There is a negatively weak correlation between # of premiums paid and underwriting score (r=-0.26). It seems that higher # of payments, the application underwriting score is tend to be lower.
