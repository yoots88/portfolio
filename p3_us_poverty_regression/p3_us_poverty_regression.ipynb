# %% [markdown]
# ## Portfolio: US Counties Poverty Rate Regression Modeling ##
# This is data science portfolio based on real dataset to predict povert rate acorss the United States at the country level using socio-economic indicators. The dataset was compiled from wide range of sources and publicly made available by United States Department of Agriculture Economic Research Service (USDA ERS). It can be found here https://datasciencecapstone.org/competitions/3/county-poverty/page/10/.
#
# ** Problem Statement: **
# In US, being poverty is defined as having an income below a federally defined poverty threshold. This represents US federal government's estimation of how many families are below in which their income levels do not meet any basic needs (i.e., food, shelter, clothing and other essential goods). Thus, our goal is to make predictions on poverty rates by counties within US in order to make recommendations for federal government agencies. This will help them to initiate and implement policies/support the families below officially defined poverty thresholds.
#
# The US poverty rate dataset contains 33 features in total. There are 30 numerical and 3 categorical features to predict one target variable (i.e., poverty_rate). There are 4 different kinds of information are available from this dataset which includes county's urbanization degree (development level), economic indicators, health indicators and demographic indicators.
#
# ** Stakeholders: **
# US federal policy makers, counties' representatives and other Not-For-Profit (NFP) organizations.
#
# ** Goal: **
# To make accurate predictions on US counties' poverty rate with minimum root-mean-squared-errors (RMSEs).
#
# ** Results: **
# L1 regularized model support to narrow down choosing 13 useful features for model training.
#
# The best model was poynomial regression with values of **RMSE: 2.99** and **R^2: 0.798** on a test set
#
# ** Risks: ** With visual inspection from residual and quantile plots, there were some errors for making accurate predictions. Especially, from lower and upper range of poverty rate of counties were deviated a lot from predictions.
#
# ** Mitigation: **
# Review these identified errors and outliers with subject matter experts before making any implementation or policy changes to improve poverty rates across US counties.
#
# ** Future Work: **
# 1. Model improvements: feasibility of testing other ensemble models, stacking and neural network.
# 2. Data collection/refinement: integrate with other financial and job market related data sources
#     * Household income by counties
#     * Job market trends by counties
#     * KPIs related to accessibility for basic needs (i.e., food, housing, etc.)
#
# ** Recommendation for clients: **
# 1. ** Increase acceessibility to education for minor ethnicities. ** US counties with high % of African American population tend to have high % of no secondary school diploma. Thus, trend showed that these counties have higher poverty rates compared to high % of Caucasian population counties.
#
# 2. ** Support economic development plan for nonmetro counties with no specialized industires. ** A lot of nonmetro counties with population less than 2,000 had no specialized industries to support their own economies. Thus, it is important for federal and state government agencies to support them establish their own specialized industries (i.e., tourism, agricultural and etc.).
#
# 3. ** Maintain good transportation infrastructure and urban planning for nonmetro counties. ** Combined effects of large population size and adjacency to metro area showed lower poverty rates. Usually, the bigger and well developed urban counties tend to have huge pool of job openings. Thus, lower poverty rates were observed in comparison to counties located far from metro area.

# %% [markdown]
# ## Part A. Data Wrangling ##
# Original dataset was loaded onto Python as a dataframe. Dataset presented with a couple of problems such as missing data and outliers. Thus, data cleaning and transformation processes were performed in a following order: feature imputation --> handling outliers --> format metadata types --> feature transformation (i.e., feature encoding).

# %%
# Import all libraries #
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
from sklearn.preprocessing import Imputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import sklearn.metrics as skm
import scipy.stats as sp
import pylab 

#############################################
# Load training dataset for US poverty rate #
#############################################
df = pd.read_csv('PP_train.csv')

######################
# Data Quality Check #
######################
# Missing value dataframe:
PP_missing = df.isnull().sum()
PP_missing = pd.DataFrame(PP_missing)
# Rename column as missing value counts:
PP_missing.columns = ['counts']

# Compute missing value percent:
PP_missing['missing_pct'] = PP_missing['counts']/len(df)
PP_missing = PP_missing.sort_values(by='missing_pct', ascending=False)
PP_missing['missing_pct']
# Out:
# C:\Users\yoots\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# health__homicides_per_100k                          0.615072
# health__pct_excessive_drinking                      0.305816
# health__pct_adult_smoking                           0.145091
# health__motor_vehicle_crash_deaths_per_100k         0.130394
# health__pop_per_dentist                             0.076298
# health__pop_per_primary_care_physician              0.071920
# health__pct_low_birthweight                         0.056911
# health__air_pollution_particulate_matter            0.008755
# demo__pct_hispanic                                  0.000625
# demo__pct_american_indian_or_alaskan_native         0.000625
# health__pct_diabetes                                0.000625
# health__pct_physical_inacticity                     0.000625
# demo__pct_asian                                     0.000625
# health__pct_adult_obesity                           0.000625
# demo__pct_non_hispanic_white                        0.000625
# demo__pct_non_hispanic_african_american             0.000625
# demo__pct_aged_65_years_and_older                   0.000625
# demo__pct_below_18_years_of_age                     0.000625
# demo__pct_female                                    0.000625
# econ__pct_uninsured_children                        0.000625
# econ__pct_uninsured_adults                          0.000625
# yr                                                  0.000000
# row_id                                              0.000000
# demo__pct_adults_with_high_school_diploma           0.000000
# demo__death_rate_per_1k                             0.000000
# demo__birth_rate_per_1k                             0.000000
# demo__pct_adults_bachelors_or_higher                0.000000
# demo__pct_adults_with_some_college                  0.000000
# area__rucc                                          0.000000
# demo__pct_adults_less_than_a_high_school_diploma    0.000000
# econ__pct_unemployment                              0.000000
# econ__pct_civilian_labor                            0.000000
# econ__economic_typology                             0.000000
# area__urban_influence                               0.000000
# poverty_rate                                        0.000000
# Name: missing_pct, dtype: float64

# %% [markdown]
# #### Compute Summary Statistics: Pre Data Cleaning ####

# %%
# Print summary statistics: poverty_rate
df.describe().T
# Out:
#                                                    count         mean  \
# row_id                                            3198.0  3156.692620
# econ__pct_civilian_labor                          3198.0     0.467071
# econ__pct_unemployment                            3198.0     0.059610
# econ__pct_uninsured_adults                        3196.0     0.217534
# econ__pct_uninsured_children                      3196.0     0.085920
# demo__pct_female                                  3196.0     0.498781
# demo__pct_below_18_years_of_age                   3196.0     0.227763
# demo__pct_aged_65_years_and_older                 3196.0     0.170137
# demo__pct_hispanic                                3196.0     0.090233
# demo__pct_non_hispanic_african_american           3196.0     0.091117
# demo__pct_non_hispanic_white                      3196.0     0.770207
# demo__pct_american_indian_or_alaskan_native       3196.0     0.024659
# demo__pct_asian                                   3196.0     0.013304
# demo__pct_adults_less_than_a_high_school_diploma  3198.0     0.148794
# demo__pct_adults_with_high_school_diploma         3198.0     0.350300
# demo__pct_adults_with_some_college                3198.0     0.301366
# demo__pct_adults_bachelors_or_higher              3198.0     0.199540
# demo__birth_rate_per_1k                           3198.0    11.676986
# demo__death_rate_per_1k                           3198.0    10.301126
# health__pct_adult_obesity                         3196.0     0.307599
# health__pct_adult_smoking                         2734.0     0.213519
# health__pct_diabetes                              3196.0     0.109287
# health__pct_low_birthweight                       3016.0     0.083534
# health__pct_excessive_drinking                    2220.0     0.164832
# health__pct_physical_inacticity                   3196.0     0.277309
# health__air_pollution_particulate_matter          3170.0    11.626498
# health__homicides_per_100k                        1231.0     5.950747
# health__motor_vehicle_crash_deaths_per_100k       2781.0    21.116077
# health__pop_per_dentist                           2954.0  3431.442789
# health__pop_per_primary_care_physician            2968.0  2551.349730
# poverty_rate                                      3198.0    16.817136
#
#                                                           std         min  \
# row_id                                            1823.959278    0.000000
# econ__pct_civilian_labor                             0.074541    0.217000
# econ__pct_unemployment                               0.022850    0.008000
# econ__pct_uninsured_adults                           0.067372    0.046000
# econ__pct_uninsured_children                         0.040005    0.009000
# demo__pct_female                                     0.024251    0.294000
# demo__pct_below_18_years_of_age                      0.034291    0.098000
# demo__pct_aged_65_years_and_older                    0.043594    0.043000
# demo__pct_hispanic                                   0.142707    0.000000
# demo__pct_non_hispanic_african_american              0.147104    0.000000
# demo__pct_non_hispanic_white                         0.207903    0.060000
# demo__pct_american_indian_or_alaskan_native          0.084634    0.000000
# demo__pct_asian                                      0.025366    0.000000
# demo__pct_adults_less_than_a_high_school_diploma     0.068255    0.016129
# demo__pct_adults_with_high_school_diploma            0.070534    0.072821
# demo__pct_adults_with_some_college                   0.052498    0.112821
# demo__pct_adults_bachelors_or_higher                 0.089158    0.013986
# demo__birth_rate_per_1k                              2.739516    4.000000
# demo__death_rate_per_1k                              2.786143    0.000000
# health__pct_adult_obesity                            0.043404    0.140000
# health__pct_adult_smoking                            0.063090    0.050000
# health__pct_diabetes                                 0.023197    0.033000
# health__pct_low_birthweight                          0.022382    0.025000
# health__pct_excessive_drinking                       0.050232    0.038000
# health__pct_physical_inacticity                      0.052947    0.097000
# health__air_pollution_particulate_matter             1.544928    7.000000
# health__homicides_per_100k                           5.063374   -0.390000
# health__motor_vehicle_crash_deaths_per_100k         10.516984    3.090000
# health__pop_per_dentist                           2569.444414  339.000000
# health__pop_per_primary_care_physician            2100.475931  189.000000
# poverty_rate                                         6.697969    2.500000
#
#                                                           25%          50%  \
# row_id                                            1561.750000  3198.500000
# econ__pct_civilian_labor                             0.420000     0.467000
# econ__pct_unemployment                               0.044000     0.057000
# econ__pct_uninsured_adults                           0.166000     0.216000
# econ__pct_uninsured_children                         0.057000     0.077000
# demo__pct_female                                     0.493000     0.503000
# demo__pct_below_18_years_of_age                      0.207000     0.226000
# demo__pct_aged_65_years_and_older                    0.142000     0.167000
# demo__pct_hispanic                                   0.019000     0.035000
# demo__pct_non_hispanic_african_american              0.006000     0.022000
# demo__pct_non_hispanic_white                         0.648000     0.854000
# demo__pct_american_indian_or_alaskan_native          0.002000     0.007000
# demo__pct_asian                                      0.003000     0.007000
# demo__pct_adults_less_than_a_high_school_diploma     0.097468     0.133501
# demo__pct_adults_with_high_school_diploma            0.305915     0.355701
# demo__pct_adults_with_some_college                   0.265362     0.301595
# demo__pct_adults_bachelors_or_higher                 0.138840     0.177247
# demo__birth_rate_per_1k                             10.000000    11.000000
# demo__death_rate_per_1k                              8.000000    10.000000
# health__pct_adult_obesity                            0.284000     0.309000
# health__pct_adult_smoking                            0.171000     0.211000
# health__pct_diabetes                                 0.094000     0.109000
# health__pct_low_birthweight                          0.068000     0.080000
# health__pct_excessive_drinking                       0.129000     0.164000
# health__pct_physical_inacticity                      0.243000     0.280000
# health__air_pollution_particulate_matter            10.000000    12.000000
# health__homicides_per_100k                           2.660000     4.840000
# health__motor_vehicle_crash_deaths_per_100k         13.460000    19.630000
# health__pop_per_dentist                           1812.250000  2690.000000
# health__pop_per_primary_care_physician            1419.000000  1999.000000
# poverty_rate                                        12.000000    15.800000
#
#                                                           75%           max
# row_id                                            4723.750000   6277.000000
# econ__pct_civilian_labor                             0.514000      1.000000
# econ__pct_unemployment                               0.071000      0.240000
# econ__pct_uninsured_adults                           0.262000      0.495000
# econ__pct_uninsured_children                         0.105000      0.285000
# demo__pct_female                                     0.512000      0.576000
# demo__pct_below_18_years_of_age                      0.245250      0.417000
# demo__pct_aged_65_years_and_older                    0.194000      0.355000
# demo__pct_hispanic                                   0.088000      0.945000
# demo__pct_non_hispanic_african_american              0.096250      0.855000
# demo__pct_non_hispanic_white                         0.936000      0.998000
# demo__pct_american_indian_or_alaskan_native          0.014000      0.852000
# demo__pct_asian                                      0.013000      0.346000
# demo__pct_adults_less_than_a_high_school_diploma     0.195171      0.466867
# demo__pct_adults_with_high_school_diploma            0.399197      0.551689
# demo__pct_adults_with_some_college                   0.335972      0.474216
# demo__pct_adults_bachelors_or_higher                 0.233258      0.794872
# demo__birth_rate_per_1k                             13.000000     29.000000
# demo__death_rate_per_1k                             12.000000     27.000000
# health__pct_adult_obesity                            0.334000      0.484000
# health__pct_adult_smoking                            0.249750      0.526000
# health__pct_diabetes                                 0.124000      0.197000
# health__pct_low_birthweight                          0.095000      0.232000
# health__pct_excessive_drinking                       0.196000      0.358000
# health__pct_physical_inacticity                      0.313000      0.443000
# health__air_pollution_particulate_matter            13.000000     15.000000
# health__homicides_per_100k                           7.825000     51.490000
# health__motor_vehicle_crash_deaths_per_100k         26.470000    110.450000
# health__pop_per_dentist                           4089.750000  28129.000000
# health__pop_per_primary_care_physician            2859.000000  23400.000000
# poverty_rate                                        20.300000     47.400000

# %% [markdown]
# #### Data Quality Check #1: drop negative value observation(s) ####

# %%
# Print indexes where negative values occurred on 'health_homicides_per_100k':
df[df['health__homicides_per_100k'] < 0].index

# Drop negative value observations:
df = df.drop(df.index[[87, 830, 954, 1282, 1402, 1994]])

# Check number of observations where less than 0 on 'health_homicides_per_100k':
np.bincount(df['health__homicides_per_100k'] < 0)
# Out:
# array([3192], dtype=int64)

# %% [markdown]
# #### Data Quality Check #2: drop any feature(s) where missing values > 50% (threshold) ####

# %%
# Drop a feature missing more than 50%:
df = df.drop(['health__homicides_per_100k'], axis=1)
# Check data types and missing values:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3192 entries, 0 to 3197
# Data columns (total 34 columns):
# row_id                                              3192 non-null int64
# area__rucc                                          3192 non-null object
# area__urban_influence                               3192 non-null object
# econ__economic_typology                             3192 non-null object
# econ__pct_civilian_labor                            3192 non-null float64
# econ__pct_unemployment                              3192 non-null float64
# econ__pct_uninsured_adults                          3190 non-null float64
# econ__pct_uninsured_children                        3190 non-null float64
# demo__pct_female                                    3190 non-null float64
# demo__pct_below_18_years_of_age                     3190 non-null float64
# demo__pct_aged_65_years_and_older                   3190 non-null float64
# demo__pct_hispanic                                  3190 non-null float64
# demo__pct_non_hispanic_african_american             3190 non-null float64
# demo__pct_non_hispanic_white                        3190 non-null float64
# demo__pct_american_indian_or_alaskan_native         3190 non-null float64
# demo__pct_asian                                     3190 non-null float64
# demo__pct_adults_less_than_a_high_school_diploma    3192 non-null float64
# demo__pct_adults_with_high_school_diploma           3192 non-null float64
# demo__pct_adults_with_some_college                  3192 non-null float64
# demo__pct_adults_bachelors_or_higher                3192 non-null float64
# demo__birth_rate_per_1k                             3192 non-null int64
# demo__death_rate_per_1k                             3192 non-null int64
# health__pct_adult_obesity                           3190 non-null float64
# health__pct_adult_smoking                           2728 non-null float64
# health__pct_diabetes                                3190 non-null float64
# health__pct_low_birthweight                         3010 non-null float64
# health__pct_excessive_drinking                      2214 non-null float64
# health__pct_physical_inacticity                     3190 non-null float64
# health__air_pollution_particulate_matter            3164 non-null float64
# health__motor_vehicle_crash_deaths_per_100k         2775 non-null float64
# health__pop_per_dentist                             2948 non-null float64
# health__pop_per_primary_care_physician              2962 non-null float64
# yr                                                  3192 non-null object
# poverty_rate                                        3192 non-null float64
# dtypes: float64(27), int64(3), object(4)
# memory usage: 872.8+ KB

# %%
# Compute summary statistics: 
df_stat = df.describe().T
df_stat = df_stat[['count', 'min', 'max', 'mean', 'std', '25%', '50%', '75%']]
df_stat = df_stat.sort_values(by='count', ascending=True)
df_stat
# Out:
#                                                    count         min  \
# health__pct_excessive_drinking                    2214.0    0.038000
# health__pct_adult_smoking                         2728.0    0.050000
# health__motor_vehicle_crash_deaths_per_100k       2775.0    3.090000
# health__pop_per_dentist                           2948.0  339.000000
# health__pop_per_primary_care_physician            2962.0  189.000000
# health__pct_low_birthweight                       3010.0    0.025000
# health__air_pollution_particulate_matter          3164.0    7.000000
# health__pct_diabetes                              3190.0    0.033000
# health__pct_physical_inacticity                   3190.0    0.097000
# demo__pct_asian                                   3190.0    0.000000
# demo__pct_american_indian_or_alaskan_native       3190.0    0.000000
# demo__pct_non_hispanic_white                      3190.0    0.060000
# demo__pct_non_hispanic_african_american           3190.0    0.000000
# demo__pct_hispanic                                3190.0    0.000000
# demo__pct_aged_65_years_and_older                 3190.0    0.043000
# demo__pct_below_18_years_of_age                   3190.0    0.098000
# demo__pct_female                                  3190.0    0.294000
# econ__pct_uninsured_children                      3190.0    0.009000
# econ__pct_uninsured_adults                        3190.0    0.046000
# health__pct_adult_obesity                         3190.0    0.140000
# row_id                                            3192.0    0.000000
# demo__pct_adults_with_high_school_diploma         3192.0    0.072821
# demo__birth_rate_per_1k                           3192.0    4.000000
# demo__pct_adults_bachelors_or_higher              3192.0    0.013986
# demo__pct_adults_with_some_college                3192.0    0.112821
# demo__pct_adults_less_than_a_high_school_diploma  3192.0    0.016129
# econ__pct_unemployment                            3192.0    0.008000
# econ__pct_civilian_labor                          3192.0    0.217000
# demo__death_rate_per_1k                           3192.0    0.000000
# poverty_rate                                      3192.0    2.500000
#
#                                                            max         mean  \
# health__pct_excessive_drinking                        0.358000     0.164696
# health__pct_adult_smoking                             0.526000     0.213649
# health__motor_vehicle_crash_deaths_per_100k         110.450000    21.146022
# health__pop_per_dentist                           28129.000000  3435.677069
# health__pop_per_primary_care_physician            23400.000000  2554.429440
# health__pct_low_birthweight                           0.232000     0.083564
# health__air_pollution_particulate_matter             15.000000    11.626422
# health__pct_diabetes                                  0.197000     0.109339
# health__pct_physical_inacticity                       0.443000     0.277446
# demo__pct_asian                                       0.346000     0.013255
# demo__pct_american_indian_or_alaskan_native           0.852000     0.024695
# demo__pct_non_hispanic_white                          0.998000     0.770010
# demo__pct_non_hispanic_african_american               0.855000     0.091250
# demo__pct_hispanic                                    0.945000     0.090309
# demo__pct_aged_65_years_and_older                     0.355000     0.170197
# demo__pct_below_18_years_of_age                       0.417000     0.227737
# demo__pct_female                                      0.576000     0.498768
# econ__pct_uninsured_children                          0.285000     0.086007
# econ__pct_uninsured_adults                            0.495000     0.217753
# health__pct_adult_obesity                             0.484000     0.307703
# row_id                                             6277.000000  3158.553885
# demo__pct_adults_with_high_school_diploma             0.551689     0.350495
# demo__birth_rate_per_1k                              29.000000    11.679198
# demo__pct_adults_bachelors_or_higher                  0.794872     0.199122
# demo__pct_adults_with_some_college                    0.474216     0.301406
# demo__pct_adults_less_than_a_high_school_diploma      0.466867     0.148976
# econ__pct_unemployment                                0.240000     0.059644
# econ__pct_civilian_labor                              1.000000     0.466937
# demo__death_rate_per_1k                              27.000000    10.307018
# poverty_rate                                         47.400000    16.836247
#
#                                                           std          25%  \
# health__pct_excessive_drinking                       0.050201     0.129000
# health__pct_adult_smoking                            0.063092     0.171000
# health__motor_vehicle_crash_deaths_per_100k         10.508196    13.500000
# health__pop_per_dentist                           2570.313782  1819.750000
# health__pop_per_primary_care_physician            2101.457358  1422.250000
# health__pct_low_birthweight                          0.022392     0.068000
# health__air_pollution_particulate_matter             1.545641    10.000000
# health__pct_diabetes                                 0.023185     0.094000
# health__pct_physical_inacticity                      0.052900     0.243000
# demo__pct_asian                                      0.025340     0.003000
# demo__pct_american_indian_or_alaskan_native          0.084709     0.002000
# demo__pct_non_hispanic_white                         0.208032     0.648000
# demo__pct_non_hispanic_african_american              0.147209     0.006000
# demo__pct_hispanic                                   0.142822     0.019000
# demo__pct_aged_65_years_and_older                    0.043603     0.142000
# demo__pct_below_18_years_of_age                      0.034295     0.206250
# demo__pct_female                                     0.024272     0.493000
# econ__pct_uninsured_children                         0.039989     0.057000
# econ__pct_uninsured_adults                           0.067241     0.167000
# health__pct_adult_obesity                            0.043357     0.284000
# row_id                                            1824.460464  1560.750000
# demo__pct_adults_with_high_school_diploma            0.070421     0.306175
# demo__birth_rate_per_1k                              2.741186    10.000000
# demo__pct_adults_bachelors_or_higher                 0.088631     0.138804
# demo__pct_adults_with_some_college                   0.052511     0.265392
# demo__pct_adults_less_than_a_high_school_diploma     0.068187     0.097604
# econ__pct_unemployment                               0.022857     0.044000
# econ__pct_civilian_labor                             0.074544     0.419000
# demo__death_rate_per_1k                              2.785057     8.000000
# poverty_rate                                         6.689073    12.000000
#
#                                                           50%          75%
# health__pct_excessive_drinking                       0.164000     0.196000
# health__pct_adult_smoking                            0.211000     0.250000
# health__motor_vehicle_crash_deaths_per_100k         19.640000    26.490000
# health__pop_per_dentist                           2694.500000  4092.500000
# health__pop_per_primary_care_physician            1999.500000  2859.000000
# health__pct_low_birthweight                          0.080000     0.095000
# health__air_pollution_particulate_matter            12.000000    13.000000
# health__pct_diabetes                                 0.109000     0.124000
# health__pct_physical_inacticity                      0.280000     0.313000
# demo__pct_asian                                      0.007000     0.013000
# demo__pct_american_indian_or_alaskan_native          0.007000     0.014000
# demo__pct_non_hispanic_white                         0.854000     0.936000
# demo__pct_non_hispanic_african_american              0.022000     0.097000
# demo__pct_hispanic                                   0.035000     0.088000
# demo__pct_aged_65_years_and_older                    0.167000     0.194000
# demo__pct_below_18_years_of_age                      0.226000     0.245000
# demo__pct_female                                     0.503000     0.512000
# econ__pct_uninsured_children                         0.077000     0.105000
# econ__pct_uninsured_adults                           0.216000     0.262000
# health__pct_adult_obesity                            0.309000     0.334000
# row_id                                            3200.500000  4725.250000
# demo__pct_adults_with_high_school_diploma            0.355822     0.399399
# demo__birth_rate_per_1k                             11.000000    13.000000
# demo__pct_adults_bachelors_or_higher                 0.177183     0.232767
# demo__pct_adults_with_some_college                   0.301595     0.335982
# demo__pct_adults_less_than_a_high_school_diploma     0.133838     0.195225
# econ__pct_unemployment                               0.057000     0.071000
# econ__pct_civilian_labor                             0.467000     0.513000
# demo__death_rate_per_1k                             10.000000    12.000000
# poverty_rate                                        15.800000    20.300000

# %% [markdown]
# #### Data Quality Check #3: handling outliers for accurate regression modeling ####
#
# Outliers are the values that might potentialy skew the results on our modeling. In order to maximize the performance of classification model(s), it is required to handle outliers first. In a training set, there are 30 numerical features and a outlier detection dataframe was created. In general, it was easy to identify there were outlier(s) in "distance" and "avg. income". The maximum value on each of feature is greater than the upper bound value computed IQR method.
#
# Outliers were required to be managed properly on these numerical features. In a training set, there were 10 independent features (i.e., continuous). These included “avg_income”, “distance” and etc. Interquartile range (IQR) method applied here. For example, if any value of a feature sits below lower and above upper bounds of IQR, these observations will be removed from dataset.
#
# IQR is defined as: **IQR = Q3 – Q1** in which Q3 is 75th percentile and Q1 is 25th percentile of a feature. **Lower bound (LB) equals to Q1 – (1.5 x IQR)** and **upper bound (UB) equals to Q3 + (1.5 x IQR).**
#
# From above definition, summary table was computed on all three numerical features.

# %%
# Compute IQR, LB, UB:
df_stat['IQR'] = df_stat['75%'] - df_stat['25%']
df_stat['LB'] = df_stat['25%'] - 1.5*df_stat['IQR']
df_stat['UB'] = df_stat['75%'] + 1.5*df_stat['IQR']

# Create poverty_rate outliers dataframe:
PP_outliers = df_stat[['LB', 'min', 'UB', 'max']]
PP_outliers
# Out:
#                                                            LB         min  \
# health__pct_excessive_drinking                       0.028500    0.038000
# health__pct_adult_smoking                            0.052500    0.050000
# health__motor_vehicle_crash_deaths_per_100k         -5.985000    3.090000
# health__pop_per_dentist                          -1589.375000  339.000000
# health__pop_per_primary_care_physician            -732.875000  189.000000
# health__pct_low_birthweight                          0.027500    0.025000
# health__air_pollution_particulate_matter             5.500000    7.000000
# health__pct_diabetes                                 0.049000    0.033000
# health__pct_physical_inacticity                      0.138000    0.097000
# demo__pct_asian                                     -0.012000    0.000000
# demo__pct_american_indian_or_alaskan_native         -0.016000    0.000000
# demo__pct_non_hispanic_white                         0.216000    0.060000
# demo__pct_non_hispanic_african_american             -0.130500    0.000000
# demo__pct_hispanic                                  -0.084500    0.000000
# demo__pct_aged_65_years_and_older                    0.064000    0.043000
# demo__pct_below_18_years_of_age                      0.148125    0.098000
# demo__pct_female                                     0.464500    0.294000
# econ__pct_uninsured_children                        -0.015000    0.009000
# econ__pct_uninsured_adults                           0.024500    0.046000
# health__pct_adult_obesity                            0.209000    0.140000
# row_id                                           -3186.000000    0.000000
# demo__pct_adults_with_high_school_diploma            0.166339    0.072821
# demo__birth_rate_per_1k                              5.500000    4.000000
# demo__pct_adults_bachelors_or_higher                -0.002140    0.013986
# demo__pct_adults_with_some_college                   0.159508    0.112821
# demo__pct_adults_less_than_a_high_school_diploma    -0.048829    0.016129
# econ__pct_unemployment                               0.003500    0.008000
# econ__pct_civilian_labor                             0.278000    0.217000
# demo__death_rate_per_1k                              2.000000    0.000000
# poverty_rate                                        -0.450000    2.500000
#
#                                                            UB           max
# health__pct_excessive_drinking                       0.296500      0.358000
# health__pct_adult_smoking                            0.368500      0.526000
# health__motor_vehicle_crash_deaths_per_100k         45.975000    110.450000
# health__pop_per_dentist                           7501.625000  28129.000000
# health__pop_per_primary_care_physician            5014.125000  23400.000000
# health__pct_low_birthweight                          0.135500      0.232000
# health__air_pollution_particulate_matter            17.500000     15.000000
# health__pct_diabetes                                 0.169000      0.197000
# health__pct_physical_inacticity                      0.418000      0.443000
# demo__pct_asian                                      0.028000      0.346000
# demo__pct_american_indian_or_alaskan_native          0.032000      0.852000
# demo__pct_non_hispanic_white                         1.368000      0.998000
# demo__pct_non_hispanic_african_american              0.233500      0.855000
# demo__pct_hispanic                                   0.191500      0.945000
# demo__pct_aged_65_years_and_older                    0.272000      0.355000
# demo__pct_below_18_years_of_age                      0.303125      0.417000
# demo__pct_female                                     0.540500      0.576000
# econ__pct_uninsured_children                         0.177000      0.285000
# econ__pct_uninsured_adults                           0.404500      0.495000
# health__pct_adult_obesity                            0.409000      0.484000
# row_id                                            9472.000000   6277.000000
# demo__pct_adults_with_high_school_diploma            0.539234      0.551689
# demo__birth_rate_per_1k                             17.500000     29.000000
# demo__pct_adults_bachelors_or_higher                 0.373711      0.794872
# demo__pct_adults_with_some_college                   0.441867      0.474216
# demo__pct_adults_less_than_a_high_school_diploma     0.341657      0.466867
# econ__pct_unemployment                               0.111500      0.240000
# econ__pct_civilian_labor                             0.654000      1.000000
# demo__death_rate_per_1k                             18.000000     27.000000
# poverty_rate                                        32.750000     47.400000

# %%
# Check # of features with outliers from LowerBound P.O.V:
print(np.count_nonzero(PP_outliers['LB'] > PP_outliers['min']))
print(PP_outliers['LB'] > PP_outliers['min'])

# Check # of features with outliers from UpperBound P.O.V:
print(np.count_nonzero(PP_outliers['UB'] < PP_outliers['max']))
print(PP_outliers['UB'] < PP_outliers['max'])
# Out:
# 14
# health__pct_excessive_drinking                      False
# health__pct_adult_smoking                            True
# health__motor_vehicle_crash_deaths_per_100k         False
# health__pop_per_dentist                             False
# health__pop_per_primary_care_physician              False
# health__pct_low_birthweight                          True
# health__air_pollution_particulate_matter            False
# health__pct_diabetes                                 True
# health__pct_physical_inacticity                      True
# demo__pct_asian                                     False
# demo__pct_american_indian_or_alaskan_native         False
# demo__pct_non_hispanic_white                         True
# demo__pct_non_hispanic_african_american             False
# demo__pct_hispanic                                  False
# demo__pct_aged_65_years_and_older                    True
# demo__pct_below_18_years_of_age                      True
# demo__pct_female                                     True
# econ__pct_uninsured_children                        False
# econ__pct_uninsured_adults                          False
# health__pct_adult_obesity                            True
# row_id                                              False
# demo__pct_adults_with_high_school_diploma            True
# demo__birth_rate_per_1k                              True
# demo__pct_adults_bachelors_or_higher                False
# demo__pct_adults_with_some_college                   True
# demo__pct_adults_less_than_a_high_school_diploma    False
# econ__pct_unemployment                              False
# econ__pct_civilian_labor                             True
# demo__death_rate_per_1k                              True
# poverty_rate                                        False
# dtype: bool
# 27
# health__pct_excessive_drinking                       True
# health__pct_adult_smoking                            True
# health__motor_vehicle_crash_deaths_per_100k          True
# health__pop_per_dentist                              True
# health__pop_per_primary_care_physician               True
# health__pct_low_birthweight                          True
# health__air_pollution_particulate_matter            False
# health__pct_diabetes                                 True
# health__pct_physical_inacticity                      True
# demo__pct_asian                                      True
# demo__pct_american_indian_or_alaskan_native          True
# demo__pct_non_hispanic_white                        False
# demo__pct_non_hispanic_african_american              True
# demo__pct_hispanic                                   True
# demo__pct_aged_65_years_and_older                    True
# demo__pct_below_18_years_of_age                      True
# demo__pct_female                                     True
# econ__pct_uninsured_children                         True
# econ__pct_uninsured_adults                           True
# health__pct_adult_obesity                            True
# row_id                                              False
# demo__pct_adults_with_high_school_diploma            True
# demo__birth_rate_per_1k                              True
# demo__pct_adults_bachelors_or_higher                 True
# demo__pct_adults_with_some_college                   True
# demo__pct_adults_less_than_a_high_school_diploma     True
# econ__pct_unemployment                               True
# econ__pct_civilian_labor                             True
# demo__death_rate_per_1k                              True
# poverty_rate                                         True
# dtype: bool

# %% [markdown]
# #### Remove Outliers ####
# Test how many observations are treated as outliers based on LB or UB perspective. This is very critical since while removing outliers, we want to maintain balanced sample size for building an accurate regression model.

# %%
# Test removal of outliers from LowerBound and UpperBound P.O.Vs#
# UpperBound P.O.V:
print(df[df['health__pct_excessive_drinking'] > PP_outliers.loc['health__pct_excessive_drinking']['UB']].index.shape)
print(df[df['health__pct_adult_smoking'] > PP_outliers.loc['health__pct_adult_smoking']['UB']].index.shape)
print(df[df['health__motor_vehicle_crash_deaths_per_100k'] > PP_outliers.loc['health__motor_vehicle_crash_deaths_per_100k']['UB']].index.shape)
print(df[df['health__pop_per_dentist'] > PP_outliers.loc['health__pop_per_dentist']['UB']].index.shape)
print(df[df['health__pop_per_primary_care_physician'] > PP_outliers.loc['health__pop_per_primary_care_physician']['UB']].index.shape)

# LowerBound P.O.V:
print(df[df['health__pct_adult_smoking'] < PP_outliers.loc['health__pct_adult_smoking']['LB']].index.shape)
print(df[df['health__pct_low_birthweight'] < PP_outliers.loc['health__pct_low_birthweight']['LB']].index.shape)

# Drop UB outliers from primary_care_physician: 242 rows
df = df.drop(df[df['health__pop_per_primary_care_physician'] > PP_outliers.loc['health__pop_per_primary_care_physician']['UB']].index)
# Out:
# (13,)
# (49,)
# (69,)
# (196,)
# (242,)
# (1,)
# (1,)

# %% [markdown]
# #### Feature Encoding ####
# Feature encoding is a process where feature are encoded into right format. There are two types of feature encoding: ordinal and nominal feature encoding. Ordinal feature encoding is a type of encoding where feature actually contains information about "order" like increase or decrease in value (i.e., score level, date, etc). Whereas nominal feature encoding is a type of encoding where feature contains a class of label like gender (i.e., male or female).
#
# **Ordinal feature encoding:** area_rucc and area_urban_influence.
# area_rucc is a feature where it has a order classified by population size of counties by degree of urbanization. Thus, area_rucc gets mapped into numerical values. Same goes for area_urban_influence where it has a natural order by size of counties and proximity to metro and micropolitan areas. For checking format of data consistency, we will print transformed features.

# %%
# Define manual mapping for area__rucc:
###############################################################################
urban_deg_map ={'Nonmetro - Completely rural or less than 2,500 urban population, not adjacent to a metro area': 1,
        'Nonmetro - Completely rural or less than 2,500 urban population, adjacent to a metro area': 1,
        'Nonmetro - Urban population of 2,500 to 19,999, not adjacent to a metro area': 2,
        'Nonmetro - Urban population of 2,500 to 19,999, adjacent to a metro area': 2,
        'Nonmetro - Urban population of 20,000 or more, not adjacent to a metro area': 3,
        'Nonmetro - Urban population of 20,000 or more, adjacent to a metro area': 3,
        'Metro - Counties in metro areas of fewer than 250,000 population': 4,
        'Metro - Counties in metro areas of 250,000 to 1 million population': 5,
        'Metro - Counties in metro areas of 1 million population or more': 6}

# Use deg_urban_map to transform the area__rucc into ordinal integers:
df['area__rucc'] = df['area__rucc'].map(urban_deg_map)
print(df['area__rucc'].head())

# Transform integer value back to original string
###############################################################################
inv_urban_deg_map = {v:k for k, v in urban_deg_map.items()}
#df['area__rucc'] = df['area__rucc'].map(inv_urban_deg_map)

# Define manual mapping for area__urban_influence:
###############################################################################
urban_size_map ={'Noncore adjacent to a small metro and does not contain a town of at least 2,500 residents': 1,
               'Noncore adjacent to a small metro with town of at least 2,500 residents': 2,
               'Noncore not adjacent to a metro/micro area and does not contain a town of at least 2,500 residents': 3,
               'Noncore not adjacent to a metro/micro area and contains a town of 2,500  or more residents': 4,
               'Noncore adjacent to micro area and contains a town of 2,500-19,999 residents': 5,
               'Noncore adjacent to a large metro area': 6,
               'Micropolitan not adjacent to a metro area': 7,
               'Micropolitan adjacent to a small metro area': 8,
               'Micropolitan adjacent to a large metro area': 9,
               'Small-in a metro area with fewer than 1 million residents': 10,
               'Large-in a metro area with at least 1 million residents or more': 11}

# Use deg_urban_map to transform the area__rucc into ordinal integers:
df['area__urban_influence'] = df['area__urban_influence'].map(urban_size_map)
print(df['area__urban_influence'].head())

# Transform integer value back to original string
###############################################################################
inv_urban_size_map = {v:k for k, v in urban_size_map.items()}
#df['area__urban_influence'] = df['area__urban_influence'].map(inv_urban_size_map)

# Define manual mapping for yr:
###############################################################################
yr_map ={'a':'year 1', 'b':'year 2'}

# User yr_map to transform yr feature into ordinal strings:
df['yr'] = df['yr'].map(yr_map)
print(df['yr'].head())
# Out:
# 1    2
# 2    1
# 3    2
# 4    6
# 5    2
# Name: area__rucc, dtype: int64
# 1     9.0
# 2     5.0
# 3     5.0
# 4    11.0
# 5     7.0
# Name: area__urban_influence, dtype: float64
# 1    year 2
# 2    year 2
# 3    year 2
# 4    year 1
# 5    year 1
# Name: yr, dtype: object

# %% [markdown]
# ####  Data Quality Check #4: Feature Imputation ####
# Let's compute feature imputation to replace missing values by following:
# * Mode: area__urban_influence
# * Mean: health_pct_adult_smoking, excessive_drinking, ... ,health_pct_air_pollution (idx: 6-15, 22-29)
# * Median: health_pop_dentist and health_pop_primary_care will be replaced (idx: 30, 31)

# %%
# Replacement via Mode #
########################
# area__urban_influence:
###############################################################################
df_urban_size_cnt = df['area__urban_influence'].value_counts().sort_values(ascending=False)
print(df_urban_size_cnt)
# counts=623, Mode = 10

# Replacement by mode: categorical features
df['area__urban_influence'] = df['area__urban_influence'].fillna(10)

# Split data into input features and target variable #
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# check input features:
print(X.head(), X.tail())

# check target variable: poverty_rate
print(y.head(), y.tail())

# Feature Imputation #
######################
# Imputation by mean: numeric features
# column indexes: 6-15, 22-29
imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
imputer = imputer.fit(X.iloc[:, 6:16])
X.iloc[:, 6:16] = imputer.transform(X.iloc[:, 6:16])

imputer = Imputer(missing_values='NaN', strategy='mean', axis=0)
imputer = imputer.fit(X.iloc[:, 22:30])
X.iloc[:, 22:30] = imputer.transform(X.iloc[:, 22:30])

# Imputation by median: numeric features
# column indexes: 30-31 (health_pop_dentist & primary_care_physician)
imputer = Imputer(missing_values='NaN', strategy='median', axis=0)
imputer = imputer.fit(X.iloc[:, 30:32]) # NOTE: index shift by 1 due to removing 'health_pct_homicides_per_100k'
X.iloc[:, 30:32] = imputer.transform(X.iloc[:, 30:32])
# Out:
# 10.0    623
# 11.0    405
# 2.0     309
# 8.0     255
# 7.0     245
# 3.0     205
# 5.0     187
# 1.0     143
# 6.0     139
# 9.0     122
# 4.0     122
# Name: area__urban_influence, dtype: int64
#    row_id  area__rucc  area__urban_influence  \
# 1       2           2                    9.0
# 2       4           1                    5.0
# 3       5           2                    5.0
# 4       8           6                   11.0
# 5       9           2                    7.0
#
#               econ__economic_typology  econ__pct_civilian_labor  \
# 1             Manufacturing-dependent                     0.503
# 2  Federal/State government-dependent                     0.471
# 3  Federal/State government-dependent                     0.578
# 4                      Nonspecialized                     0.530
# 5                      Nonspecialized                     0.481
#
#    econ__pct_unemployment  econ__pct_uninsured_adults  \
# 1                   0.057                       0.171
# 2                   0.070                       0.297
# 3                   0.049                       0.231
# 4                   0.046                       0.262
# 5                   0.065                       0.158
#
#    econ__pct_uninsured_children  demo__pct_female  \
# 1                         0.065             0.503
# 2                         0.122             0.497
# 3                         0.107             0.474
# 4                         0.067             0.513
# 5                         0.041             0.513
#
#    demo__pct_below_18_years_of_age   ...    health__pct_adult_smoking  \
# 1                            0.243   ...                        0.222
# 2                            0.250   ...                          NaN
# 3                            0.194   ...                        0.293
# 4                            0.206   ...                        0.165
# 5                            0.222   ...                        0.268
#
#    health__pct_diabetes  health__pct_low_birthweight  \
# 1                 0.123                        0.080
# 2                 0.092                        0.079
# 3                 0.084                        0.100
# 4                 0.080                        0.086
# 5                 0.112                        0.055
#
#    health__pct_excessive_drinking  health__pct_physical_inacticity  \
# 1                           0.177                            0.350
# 2                             NaN                            0.259
# 3                           0.174                            0.249
# 4                           0.178                            0.253
# 5                             NaN                            0.302
#
#    health__air_pollution_particulate_matter  \
# 1                                      14.0
# 2                                      10.0
# 3                                      11.0
# 4                                      11.0
# 5                                      11.0
#
#    health__motor_vehicle_crash_deaths_per_100k  health__pop_per_dentist  \
# 1                                        23.81                   3060.0
# 2                                          NaN                    690.0
# 3                                        23.11                   1430.0
# 4                                         3.68                   1700.0
# 5                                        20.14                   4649.0
#
#    health__pop_per_primary_care_physician      yr
# 1                                  1749.0  year 2
# 2                                     NaN  year 2
# 3                                  1160.0  year 2
# 4                                  1870.0  year 1
# 5                                  3139.0  year 1
#
# [5 rows x 33 columns]       row_id  area__rucc  area__urban_influence econ__economic_typology  \
# 3193    6270           5                   10.0          Nonspecialized
# 3194    6273           1                    1.0          Nonspecialized
# 3195    6275           6                   11.0          Nonspecialized
# 3196    6276           1                    3.0          Farm-dependent
# 3197    6277           1                    3.0          Farm-dependent
#
#       econ__pct_civilian_labor  econ__pct_unemployment  \
# 3193                     0.391                   0.079
# 3194                     0.344                   0.117
# 3195                     0.458                   0.044
# 3196                     0.549                   0.023
# 3197                     0.503                   0.044
#
#       econ__pct_uninsured_adults  econ__pct_uninsured_children  \
# 3193                       0.279                         0.099
# 3194                       0.302                         0.104
# 3195                       0.162                         0.060
# 3196                       0.217                         0.100
# 3197                       0.246                         0.136
#
#       demo__pct_female  demo__pct_below_18_years_of_age   ...    \
# 3193             0.499                            0.256   ...
# 3194             0.511                            0.197   ...
# 3195             0.474                            0.230   ...
# 3196             0.504                            0.195   ...
# 3197             0.501                            0.247   ...
#
#       health__pct_adult_smoking  health__pct_diabetes  \
# 3193                      0.223                 0.082
# 3194                        NaN                 0.160
# 3195                      0.209                 0.117
# 3196                      0.148                 0.080
# 3197                      0.274                 0.122
#
#       health__pct_low_birthweight  health__pct_excessive_drinking  \
# 3193                        0.075                           0.114
# 3194                        0.142                             NaN
# 3195                        0.082                           0.146
# 3196                          NaN                           0.212
# 3197                        0.093                             NaN
#
#       health__pct_physical_inacticity  \
# 3193                            0.247
# 3194                            0.339
# 3195                            0.318
# 3196                            0.303
# 3197                            0.380
#
#       health__air_pollution_particulate_matter  \
# 3193                                       9.0
# 3194                                      13.0
# 3195                                      13.0
# 3196                                      12.0
# 3197                                       9.0
#
#       health__motor_vehicle_crash_deaths_per_100k  health__pop_per_dentist  \
# 3193                                        22.47                   6010.0
# 3194                                          NaN                      NaN
# 3195                                        16.24                   3119.0
# 3196                                          NaN                   2079.0
# 3197                                          NaN                      NaN
#
#       health__pop_per_primary_care_physician      yr
# 3193                                  3349.0  year 2
# 3194                                     NaN  year 2
# 3195                                  2339.0  year 1
# 3196                                   689.0  year 2
# 3197                                  3799.0  year 2
#
# [5 rows x 33 columns]
# 1    17.3
# 2    24.4
# 3    16.4
# 4    17.4
# 5    12.2
# Name: poverty_rate, dtype: float64 3193    24.8
# 3194    31.6
# 3195    12.1
# 3196    14.1
# 3197    15.1
# Name: poverty_rate, dtype: float64

# %%
# create a cleaned df #
#######################
# concatenated cleaned inputs and output label:
df_cleaned = pd.concat([X, y], axis=1)

# check any missing values on cleaned df:
print(df_cleaned.isnull().sum())

# convert data types for correct metadata:
df_cleaned['row_id'] = df_cleaned['row_id'].astype(int)
df_cleaned['area__rucc'] = df_cleaned['area__rucc'].astype('category')
df_cleaned['area__urban_influence'] = df_cleaned['area__urban_influence'].astype('category')
df_cleaned['econ__economic_typology'] = df_cleaned['econ__economic_typology'].astype('category')
df_cleaned['yr'] = df_cleaned['yr'].astype('category')

# check cleaned dataframe: data types
df_cleaned.dtypes
# Out:
# row_id                                              0
# area__rucc                                          0
# area__urban_influence                               0
# econ__economic_typology                             0
# econ__pct_civilian_labor                            0
# econ__pct_unemployment                              0
# econ__pct_uninsured_adults                          0
# econ__pct_uninsured_children                        0
# demo__pct_female                                    0
# demo__pct_below_18_years_of_age                     0
# demo__pct_aged_65_years_and_older                   0
# demo__pct_hispanic                                  0
# demo__pct_non_hispanic_african_american             0
# demo__pct_non_hispanic_white                        0
# demo__pct_american_indian_or_alaskan_native         0
# demo__pct_asian                                     0
# demo__pct_adults_less_than_a_high_school_diploma    0
# demo__pct_adults_with_high_school_diploma           0
# demo__pct_adults_with_some_college                  0
# demo__pct_adults_bachelors_or_higher                0
# demo__birth_rate_per_1k                             0
# demo__death_rate_per_1k                             0
# health__pct_adult_obesity                           0
# health__pct_adult_smoking                           0
# health__pct_diabetes                                0
# health__pct_low_birthweight                         0
# health__pct_excessive_drinking                      0
# health__pct_physical_inacticity                     0
# health__air_pollution_particulate_matter            0
# health__motor_vehicle_crash_deaths_per_100k         0
# health__pop_per_dentist                             0
# health__pop_per_primary_care_physician              0
# yr                                                  0
# poverty_rate                                        0
# dtype: int64
# row_id                                                 int32
# area__rucc                                          category
# area__urban_influence                               category
# econ__economic_typology                             category
# econ__pct_civilian_labor                             float64
# econ__pct_unemployment                               float64
# econ__pct_uninsured_adults                           float64
# econ__pct_uninsured_children                         float64
# demo__pct_female                                     float64
# demo__pct_below_18_years_of_age                      float64
# demo__pct_aged_65_years_and_older                    float64
# demo__pct_hispanic                                   float64
# demo__pct_non_hispanic_african_american              float64
# demo__pct_non_hispanic_white                         float64
# demo__pct_american_indian_or_alaskan_native          float64
# demo__pct_asian                                      float64
# demo__pct_adults_less_than_a_high_school_diploma     float64
# demo__pct_adults_with_high_school_diploma            float64
# demo__pct_adults_with_some_college                   float64
# demo__pct_adults_bachelors_or_higher                 float64
# demo__birth_rate_per_1k                                int64
# demo__death_rate_per_1k                                int64
# health__pct_adult_obesity                            float64
# health__pct_adult_smoking                            float64
# health__pct_diabetes                                 float64
# health__pct_low_birthweight                          float64
# health__pct_excessive_drinking                       float64
# health__pct_physical_inacticity                      float64
# health__air_pollution_particulate_matter             float64
# health__motor_vehicle_crash_deaths_per_100k          float64
# health__pop_per_dentist                              float64
# health__pop_per_primary_care_physician               float64
# yr                                                  category
# poverty_rate                                         float64
# dtype: object

# %% [markdown]
# ## Part B. Exploratory Data Analysis ##
#
# #### US poverty rate by counties: training set ###
# Data exploration is conducted on cleaned trainng set. The main goal of this phase is to explore any interesting relationships among features and identify which feature are good predictors on povert rate predictions.
#
# Following set of questions are asked:
# 1. Can I count something interesting?
# 2. Can I find some trends (increase or decrease and any anomalies)?
# 3. Can I plot a bar chart or a histogram?
# 4. Can I make a scatter plot?
#
# These set of guiding questions will help us to explore any insights and tells a compelling story about the US poverty dataset.

# %%
# Copy dataframe for EDA:
df_EDA = df_cleaned.copy()

# Feature engineering: to create categorical feature simplify metro vs. non-metro.
# using a feature ['area__rucc']
# {1,2,3:'non-metro'}, {4,5,6:'metro'}
county_class_bins = [0,3,6]
county_class_labels = ['Nonmetro','Metro']

# Stratification: generate county class labels
df_EDA['county_class'] = pd.cut(np.array(df['area__rucc']), bins=county_class_bins, labels=county_class_labels)

# Convert ordinal features back to categorical strings:
df_EDA['area__rucc'] = df_EDA['area__rucc'].map(inv_urban_deg_map)
df_EDA['area__urban_influence'] = df_EDA['area__urban_influence'].map(inv_urban_size_map)

# %%
# Perform summary statistics
df_EDA = df_EDA.drop(['row_id'],axis=1)
PP_summary = df_EDA.describe().T
PP_summary = PP_summary[['count','min','max','mean','std','25%','50%','75%']]

# Print summary stat:
PP_summary
# Out:
#                                                    count         min  \
# econ__pct_civilian_labor                          2950.0    0.217000
# econ__pct_unemployment                            2950.0    0.008000
# econ__pct_uninsured_adults                        2950.0    0.046000
# econ__pct_uninsured_children                      2950.0    0.009000
# demo__pct_female                                  2950.0    0.294000
# demo__pct_below_18_years_of_age                   2950.0    0.098000
# demo__pct_aged_65_years_and_older                 2950.0    0.043000
# demo__pct_hispanic                                2950.0    0.000000
# demo__pct_non_hispanic_african_american           2950.0    0.000000
# demo__pct_non_hispanic_white                      2950.0    0.060000
# demo__pct_american_indian_or_alaskan_native       2950.0    0.000000
# demo__pct_asian                                   2950.0    0.000000
# demo__pct_adults_less_than_a_high_school_diploma  2950.0    0.016129
# demo__pct_adults_with_high_school_diploma         2950.0    0.072821
# demo__pct_adults_with_some_college                2950.0    0.112821
# demo__pct_adults_bachelors_or_higher              2950.0    0.013986
# demo__birth_rate_per_1k                           2950.0    4.000000
# demo__death_rate_per_1k                           2950.0    0.000000
# health__pct_adult_obesity                         2950.0    0.140000
# health__pct_adult_smoking                         2950.0    0.050000
# health__pct_diabetes                              2950.0    0.033000
# health__pct_low_birthweight                       2950.0    0.025000
# health__pct_excessive_drinking                    2950.0    0.038000
# health__pct_physical_inacticity                   2950.0    0.097000
# health__air_pollution_particulate_matter          2950.0    7.000000
# health__motor_vehicle_crash_deaths_per_100k       2950.0    3.090000
# health__pop_per_dentist                           2950.0  339.000000
# health__pop_per_primary_care_physician            2950.0  189.000000
# poverty_rate                                      2950.0    2.500000
#
#                                                            max         mean  \
# econ__pct_civilian_labor                              1.000000     0.469643
# econ__pct_unemployment                                0.240000     0.059085
# econ__pct_uninsured_adults                            0.495000     0.215766
# econ__pct_uninsured_children                          0.285000     0.085349
# demo__pct_female                                      0.576000     0.499267
# demo__pct_below_18_years_of_age                       0.417000     0.227467
# demo__pct_aged_65_years_and_older                     0.355000     0.170494
# demo__pct_hispanic                                    0.945000     0.091107
# demo__pct_non_hispanic_african_american               0.855000     0.086890
# demo__pct_non_hispanic_white                          0.998000     0.771953
# demo__pct_american_indian_or_alaskan_native           0.852000     0.025571
# demo__pct_asian                                       0.346000     0.013825
# demo__pct_adults_less_than_a_high_school_diploma      0.410516     0.145540
# demo__pct_adults_with_high_school_diploma             0.551689     0.347534
# demo__pct_adults_with_some_college                    0.474216     0.302842
# demo__pct_adults_bachelors_or_higher                  0.794872     0.204083
# demo__birth_rate_per_1k                              29.000000    11.704068
# demo__death_rate_per_1k                              27.000000    10.298644
# health__pct_adult_obesity                             0.484000     0.306226
# health__pct_adult_smoking                             0.526000     0.211265
# health__pct_diabetes                                  0.192000     0.108552
# health__pct_low_birthweight                           0.232000     0.083114
# health__pct_excessive_drinking                        0.358000     0.164918
# health__pct_physical_inacticity                       0.443000     0.275513
# health__air_pollution_particulate_matter             15.000000    11.609172
# health__motor_vehicle_crash_deaths_per_100k         110.450000    20.614888
# health__pop_per_dentist                           25310.000000  3129.872542
# health__pop_per_primary_care_physician             4999.000000  2046.497966
# poverty_rate                                         47.400000    16.643763
#
#                                                           std          25%  \
# econ__pct_civilian_labor                             0.074493     0.422000
# econ__pct_unemployment                               0.023040     0.043000
# econ__pct_uninsured_adults                           0.067288     0.164000
# econ__pct_uninsured_children                         0.040207     0.056000
# demo__pct_female                                     0.023772     0.493000
# demo__pct_below_18_years_of_age                      0.034536     0.206000
# demo__pct_aged_65_years_and_older                    0.044095     0.142000
# demo__pct_hispanic                                   0.142299     0.019000
# demo__pct_non_hispanic_african_american              0.143789     0.006000
# demo__pct_non_hispanic_white                         0.207415     0.651000
# demo__pct_american_indian_or_alaskan_native          0.087571     0.002000
# demo__pct_asian                                      0.026201     0.003000
# demo__pct_adults_less_than_a_high_school_diploma     0.066735     0.095227
# demo__pct_adults_with_high_school_diploma            0.070770     0.301811
# demo__pct_adults_with_some_college                   0.052644     0.267137
# demo__pct_adults_bachelors_or_higher                 0.089609     0.143785
# demo__birth_rate_per_1k                              2.760513    10.000000
# demo__death_rate_per_1k                              2.809414     8.000000
# health__pct_adult_obesity                            0.043716     0.283000
# health__pct_adult_smoking                            0.057731     0.177000
# health__pct_diabetes                                 0.023160     0.093000
# health__pct_low_birthweight                          0.021543     0.069000
# health__pct_excessive_drinking                       0.042682     0.145000
# health__pct_physical_inacticity                      0.053224     0.240250
# health__air_pollution_particulate_matter             1.538879    10.000000
# health__motor_vehicle_crash_deaths_per_100k          9.748084    14.170000
# health__pop_per_dentist                           2142.233966  1829.000000
# health__pop_per_primary_care_physician             878.168974  1420.000000
# poverty_rate                                         6.622411    11.900000
#
#                                                           50%          75%
# econ__pct_civilian_labor                             0.470000     0.515000
# econ__pct_unemployment                               0.056000     0.071000
# econ__pct_uninsured_adults                           0.213000     0.261000
# econ__pct_uninsured_children                         0.076500     0.105000
# demo__pct_female                                     0.504000     0.512000
# demo__pct_below_18_years_of_age                      0.226000     0.245000
# demo__pct_aged_65_years_and_older                    0.167000     0.195000
# demo__pct_hispanic                                   0.036000     0.090000
# demo__pct_non_hispanic_african_american              0.020000     0.089000
# demo__pct_non_hispanic_white                         0.856000     0.937000
# demo__pct_american_indian_or_alaskan_native          0.007000     0.014000
# demo__pct_asian                                      0.007000     0.014000
# demo__pct_adults_less_than_a_high_school_diploma     0.130081     0.190345
# demo__pct_adults_with_high_school_diploma            0.352119     0.396226
# demo__pct_adults_with_some_college                   0.303258     0.337253
# demo__pct_adults_bachelors_or_higher                 0.181278     0.239831
# demo__birth_rate_per_1k                             11.000000    13.000000
# demo__death_rate_per_1k                             10.000000    12.000000
# health__pct_adult_obesity                            0.307000     0.333000
# health__pct_adult_smoking                            0.211265     0.240000
# health__pct_diabetes                                 0.108000     0.123000
# health__pct_low_birthweight                          0.081000     0.093000
# health__pct_excessive_drinking                       0.164918     0.183000
# health__pct_physical_inacticity                      0.277000     0.312000
# health__air_pollution_particulate_matter            12.000000    13.000000
# health__motor_vehicle_crash_deaths_per_100k         20.614888    24.497500
# health__pop_per_dentist                           2579.000000  3666.750000
# health__pop_per_primary_care_physician            1899.000000  2479.000000
# poverty_rate                                        15.600000    20.000000

# %% [markdown]
# ### B0. Correlation Matrix: US Poverty Rate dataset ###

# %%
# Correlation matrix plot # 
###########################
# Drop categorical features
df_CM = df_EDA.drop(['area__rucc','area__urban_influence','econ__economic_typology', 'yr'], axis=1)
# Compute Correlation Matrix:
corr = df_CM.corr()
# Create a mask to filter matrix: diagonally
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# CM Plot:
f, ax = plt.subplots(figsize=(11, 11))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.set(font_scale=1.1)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            annot=True, square=True, linewidths=.5,
            annot_kws={'size':7}, cbar_kws={"shrink": .6})
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# **Summary: Correlation Matrix Plot**
#
# In summary, positive correlations were observed between % unemployment rate, % diabetes, % low birthweight and etc. against poverty rate in US. On contrary, negative correlations were observed between % civilian labor, % Caucasian and % education with bachelor or higher against poverty rate in US.
#
# Order of "Pearson's r" magintude from positive to negative correlation against poverty rate:
# % unemployment rate > % low birthweight> % uninsured adults ... % excessive drinking > % education level > % civilian labor.

# %%
# Compute the correlation of each feature against poverty rate: order of magnitude
PV_CM = df_CM.corr().sort_values(by=['poverty_rate'], ascending=False)['poverty_rate']
print(PV_CM)
# Out:
# poverty_rate                                        1.000000
# demo__pct_adults_less_than_a_high_school_diploma    0.675136
# econ__pct_unemployment                              0.592800
# health__pct_low_birthweight                         0.539099
# health__pct_diabetes                                0.535235
# econ__pct_uninsured_adults                          0.534755
# demo__pct_non_hispanic_african_american             0.500255
# health__pct_adult_obesity                           0.435364
# health__pct_physical_inacticity                     0.427547
# health__motor_vehicle_crash_deaths_per_100k         0.386330
# health__pct_adult_smoking                           0.371977
# health__pop_per_dentist                             0.261272
# demo__pct_american_indian_or_alaskan_native         0.251668
# demo__death_rate_per_1k                             0.241783
# demo__pct_adults_with_high_school_diploma           0.202645
# health__pop_per_primary_care_physician              0.183519
# demo__birth_rate_per_1k                             0.138641
# demo__pct_hispanic                                  0.104924
# econ__pct_uninsured_children                        0.091486
# health__air_pollution_particulate_matter            0.053821
# demo__pct_below_18_years_of_age                     0.051921
# demo__pct_female                                   -0.036361
# demo__pct_aged_65_years_and_older                  -0.091576
# demo__pct_asian                                    -0.158959
# health__pct_excessive_drinking                     -0.276883
# demo__pct_adults_with_some_college                 -0.350954
# demo__pct_adults_bachelors_or_higher               -0.456653
# demo__pct_non_hispanic_white                       -0.497749
# econ__pct_civilian_labor                           -0.661861
# Name: poverty_rate, dtype: float64

# %%
# Filter correlations between features above Pearson r > 0.5:
for x in corr.columns:
    for y in corr.columns:
        if x < y and corr[x][y] > abs(0.5):
            print(x, y, corr[x][y])
# Out:
# econ__pct_unemployment poverty_rate 0.592800222037
# econ__pct_uninsured_adults econ__pct_uninsured_children 0.718099343339
# econ__pct_uninsured_adults poverty_rate 0.534755186644
# demo__pct_non_hispanic_african_american health__pct_low_birthweight 0.665954748683
# demo__pct_non_hispanic_african_american poverty_rate 0.50025490483
# demo__pct_adults_less_than_a_high_school_diploma econ__pct_uninsured_adults 0.654816667494
# demo__pct_adults_less_than_a_high_school_diploma poverty_rate 0.675135720869
# demo__pct_adults_with_high_school_diploma health__pct_physical_inacticity 0.561804592373
# demo__pct_adults_bachelors_or_higher demo__pct_asian 0.512649577809
# demo__birth_rate_per_1k demo__pct_below_18_years_of_age 0.728319003863
# demo__death_rate_per_1k demo__pct_aged_65_years_and_older 0.636877744988
# health__pct_adult_obesity health__pct_diabetes 0.70200620115
# health__pct_adult_obesity health__pct_physical_inacticity 0.683630000161
# health__pct_diabetes health__pct_physical_inacticity 0.673664799688
# health__pct_diabetes poverty_rate 0.535234733328
# health__pct_low_birthweight poverty_rate 0.539099053155

# %% [markdown]
# ### B1. Univariate Analysis: continuous numeric features (scale) ###

# %%
##############################################################################
# Univariate analysis: continuous features [scale]
##############################################################################
# fig 1: normal vs. log scale pct_unemployment # 
# Plot: normal pct_unemployment rate
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.subplot(1, 2, 1)
plt.hist(df_EDA.econ__pct_unemployment, color='orange', bins=15)
plt.title('Unemployment Rate')
plt.xlabel('Unemployment Rate')
plt.ylabel('Number of US counties')

# Plot: log scale pct_unemployment rate
plt.subplot(1, 2, 2)
plt.hist(np.log(df_EDA.econ__pct_unemployment), color='orange', bins=15)
plt.title('Log Unemployment Rate')
plt.xlabel('Log Unemployment Rate')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Effect of Log Transformation **
#
# Histogram on the left with normal scale showed that distribution is skewed to right. Meaning that unemployment rate is relatively lower within most of US counties. Histogram on right showed log scale of unemployment rate distribution. Thus, applying log scale, distribution of unemployment rate became closer to normal distribution.

# %% [markdown]
# ** Histogram Analyses: Economic Indicators **

# %%
# econ__pct_civilian_labor: 
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.subplot(2, 2, 1)
plt.hist(df_EDA.econ__pct_civilian_labor, color='red', bins=15)
plt.title('Distribution of Civilian Labor %')
plt.xlabel('Civilian Labor %')
plt.ylabel('Number of US counties')

# econ__pct_unemployment:
plt.subplot(2, 2, 2)
plt.hist(df_EDA.econ__pct_unemployment, color='blue', bins=15)
plt.title('Distribution of Unemployment Rate')
plt.xlabel('Unemployment Rate %')
plt.ylabel('Number of US counties')

# econ__pct_uninsured_children: 
plt.subplot(2, 2, 3)
plt.hist(df_EDA.econ__pct_uninsured_children, color='cyan', bins=15)
plt.title('Distribution of Uninsured Children %')
plt.xlabel('Uninsured Children %')
plt.ylabel('Number of US counties')

# econ__pct_uninsured_adults: 
plt.subplot(2, 2, 4)
plt.hist(df_EDA.econ__pct_uninsured_adults, color='purple', bins=15)
plt.title('Distribution of Uninsured Adults %')
plt.xlabel('Uninsured Adults %')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Economic Indicators **
# 1. Labor: showed distribution is not quite normal. Majority of US counties have civilian labor more than 50%.
# 2. Unemployment rate: showed distribution skewed to right. Majority of US counties have unemployment rate at 5%.
# 3. Uninsured children: showed distribution skewed to right. Majority of US counties have uninsured children less than 10%.
# 4. Uninsured adults: showed distribution closer to normal. Majority of US counties have uninsured adults more than 20%.

# %% [markdown]
# ** Histogram Analyses: Health Indicators [Group 1] **

# %%
# health__pct_adult_obesity: 
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.subplot(2, 2, 1)
plt.hist(df_EDA.health__pct_adult_obesity, color='red', bins=15)
plt.title('Distribution of Adult Obesity %')
plt.xlabel('Adult Obesity %')
plt.ylabel('Number of US counties')

# health__pct_adult_smoking:
plt.subplot(2, 2, 2)
plt.hist(df_EDA.health__pct_adult_smoking, color='blue', bins=15)
plt.title('Distribution of Adult Smoking %')
plt.xlabel('Adult Smoking %')
plt.ylabel('Number of US counties')

# health__pct_diabetes: 
plt.subplot(2, 2, 3)
plt.hist(df_EDA.health__pct_diabetes, color='cyan', bins=15)
plt.title('Distribution of Diabetes %')
plt.xlabel('Diabetes %')
plt.ylabel('Number of US counties')

# health__pct_excessive_drinking: 
plt.subplot(2, 2, 4)
plt.hist(df_EDA.health__pct_excessive_drinking, color='purple', bins=15)
plt.title('Distribution of Excessive Drinking %')
plt.xlabel('Excessive Drinking %')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Health Indicators Group 1 **
# 1. Obesity: showed distribution closes to normal. Majority of US counties have adult obesity greater than 30%.
# 2. Adult smoking: showed distribution skewed to right. More than half of US counties smoking less than 25%.
# 3. Diabetes: showed distribution closes to normal. Majority of US counties have diabetes less than 10%.
# 4. Excessive drinking: showed distribution skewed to right. Majority of US counties have excessive drinking less than 15%.

# %% [markdown]
# ** Histogram Analyses: Health Indicators [Group 2] **

# %%
# health__pct_low_birthweight: 
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.subplot(2, 2, 1)
plt.hist(df_EDA.health__pct_low_birthweight, color='red', bins=15)
plt.title('Distribution of Low Birthweight %')
plt.xlabel('Low Birthweight %')
plt.ylabel('Number of US counties')

# health__pct_physical_inacticity:
plt.subplot(2, 2, 2)
plt.hist(df_EDA.health__pct_physical_inacticity, color='blue', bins=15)
plt.title('Distribution of Physical Inactivty %')
plt.xlabel('Exercise Level %')
plt.ylabel('Number of US counties')

# health__pop_per_dentist: 
plt.subplot(2, 2, 3)
plt.hist(df_EDA.health__pop_per_dentist, color='cyan', bins=15)
plt.title('Distribution of Dentists')
plt.xlabel('Dentists per Population')
plt.ylabel('Number of US counties')

# health__pop_per_primary_care_physician: 
plt.subplot(2, 2, 4)
plt.hist(df_EDA.health__pop_per_primary_care_physician, color='purple', bins=15)
plt.title('Distribution of Family Doctors')
plt.xlabel('Family Doctors per Population')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Health Indicators Group 2 **
# 1. Low birthweight: showed distribution skewed to right. Majority of US counties have low birthweight less than 10%.
# 2. Exercise level: showed distribution closes to normal. More than half of US counties exercise level greater than 30%.
# 3. Dentists per population: showed distribution skewed to right. Majority of US counties have dentists less than 5000 per population.
# 4. Doctors per population: showed distribution skewed to right. Majority of US counties have family doctors less than 2000 per population.

# %% [markdown]
# ** Histogram Analyses: Demographic Indicators [Gender/Age] **

# %%
# demo__pct_female: 
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.7, wspace=0.5)
plt.subplot(3, 1, 1)
plt.hist(df_EDA.demo__pct_female, color='red', bins=40)
plt.title('Distribution of Female Population %')
plt.xlabel('Female %')
plt.ylabel('Number of US counties')

# demo__pct_below_18_years_of_age:
plt.subplot(3, 1, 2)
plt.hist(df_EDA.demo__pct_below_18_years_of_age, color='blue', bins=40)
plt.title('Distribution of Adolescents Population %')
plt.xlabel('Adolescents %')
plt.ylabel('Number of US counties')

# demo__pct_aged_65_years_and_older: 
plt.subplot(3, 1, 3)
plt.hist(df_EDA.demo__pct_aged_65_years_and_older, color='cyan', bins=40)
plt.title('Distribution of Senior Population %')
plt.xlabel('Seniors %')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Age/Gender Demographic Indicators **
# 1. % Female: showed distribution slightly skewed to left. Majority of US counties had greater than 50% of female.
# 2. % Adolescents: showed normal distribution. Majority of US counties had greather than 23% of adolescent population.
# 3. % Seniors: showed normal distribution. Majority of US counties had greather than 17% of adolescent population.

# %% [markdown]
# ** Histogram Analyses: Demographic Indicators [Education] **

# %%
# demo__pct_adults_less_than_a_high_school_diploma: 
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.subplot(2, 2, 1)
plt.hist(df_EDA.demo__pct_adults_less_than_a_high_school_diploma, color='red', bins=30)
plt.title('Distribution of Less than High School Educ. %')
plt.xlabel('Adults Less than High School Diploma %')
plt.ylabel('Number of US counties')

# demo__pct_adults_with_high_school_diploma:
plt.subplot(2, 2, 2)
plt.hist(df_EDA.demo__pct_adults_with_high_school_diploma, color='blue', bins=30)
plt.title('Distribution of With High School Educ. %')
plt.xlabel('Adults with High School Diploma %')
plt.ylabel('Number of US counties')

# demo__pct_adults_with_some_college: 
plt.subplot(2, 2, 3)
plt.hist(df_EDA.demo__pct_adults_with_some_college, color='cyan', bins=30)
plt.title('Distribution of With Some College Educ. %')
plt.xlabel('Adults with Some College %')
plt.ylabel('Number of US counties')

# demo__pct_adults_bachelors_or_higher: 
plt.subplot(2, 2, 4)
plt.hist(df_EDA.demo__pct_adults_bachelors_or_higher, color='purple', bins=30)
plt.title('Distribution of With Bachelors Degree %')
plt.xlabel('Adults with Bachelors/Higher %')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Demographic Indicators [Education] **
# 1. No high school diploma: showed distribution skewed to right. Majority of US counties have adults with no high school diploma less than 15%.
# 2. With high school diploma: showed distribution closes to normal. More than half of US counties have high school diploma greater than 30%.
# 3. With some college: showed distribution closes to normal. Majority of US counties have adults with some college education greater than 30%.
# 4. With university degree: showed distribution skewed to right. Majority of US counties have university degree less than 20%.

# %% [markdown]
# ** Histogram Analyses: Demographic Indicators [Ethnicity] **

# %%
# demo__pct_non_hispanic_white: 
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.5, wspace=0.5)
plt.subplot(3, 2, 1)
plt.hist(df_EDA.demo__pct_non_hispanic_white, color='red', bins=30 )
plt.title('Distribution of Caucasian %')
plt.xlabel('Caucasian %')
plt.ylabel('Number of US counties')

# demo__pct_non_hispanic_african_american:
plt.subplot(3, 2, 2)
plt.hist(df_EDA.demo__pct_non_hispanic_african_american, color='blue', bins=20)
plt.title('Distribution of African American %')
plt.xlabel('African American %')
plt.ylabel('Number of US counties')

# demo__pct_hispanic: 
plt.subplot(3, 2, 3)
plt.hist(df_EDA.demo__pct_hispanic, color='cyan', bins=20)
plt.title('Distribution of Hispanic %')
plt.xlabel('Hispanic %')
plt.ylabel('Number of US counties')

# demo__pct_asian: 
plt.subplot(3, 2, 4)
plt.hist(df_EDA.demo__pct_asian, color='purple', bins=20)
plt.title('Distribution of Asian %')
plt.xlabel('Asian %')
plt.ylabel('Number of US counties')

# demo__pct_american_indian_or_alaskan_native: 
plt.subplot(3, 2, 5)
plt.hist(df_EDA.demo__pct_american_indian_or_alaskan_native, color='darkgreen', bins=20)
plt.title('Distribution of American Indian/Native %')
plt.xlabel('American Indian/Native %')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Demographic Indicators [Ethnicity] **
# 1. Caucasian: showed distribution skewed to left. In majority of US counties, more than 70% of Caucasian.
# 2. African American: showed distribution skewed to right. In majority of US counties, less than 5% of African American.
# 3. Hispanic: showed distribution skewed to right. In majority of US counties, less than 5% of Hispanic.
# 4. Asian: showed distribution skewed to right. In majority of US counties, less than 5% of Asian
# 5. American Indian: showed distiribution skewed to right. In majority of US counties, less than 5% of American Indian.

# %% [markdown]
# ** Histogram Analyses: Demographic Indicators [Death/Birth] **

# %%
# health__motor_vehicle_crash_deaths_per_100k:
plt.figure(figsize=(8,8))
plt.subplots_adjust(hspace=0.7, wspace=0.5)
plt.subplot(3, 1, 1)
plt.hist(df_EDA.health__motor_vehicle_crash_deaths_per_100k, color='red', bins=30)
plt.title('Distribution of Car Accident Deaths per 100k')
plt.xlabel('Motor Vehicle Crash Deaths per 100k')
plt.ylabel('Number of US counties')

# demo__death_rate_per_1k: 
plt.subplot(3, 1, 2)
plt.hist(df_EDA.demo__death_rate_per_1k, color='blue', bins=20)
plt.title('Distribution of Death Rate per 1k')
plt.xlabel('Death Rate per 1k')
plt.ylabel('Number of US counties')

# demo__birth_rate_per_1k: 
plt.subplot(3, 1, 3)
plt.hist(df_EDA.demo__birth_rate_per_1k, color='purple', bins=20)
plt.title('Distribution of Birth Rate per 1k')
plt.xlabel('Birth Rate per 1k')
plt.ylabel('Number of US counties')
plt.show()

# %% [markdown]
# ** Summary: Demographic Indicators [Birth/Death Rate] **
# 1. Car accident deaths: showed distribution skewed to right. In majority of US counties, less than 20 vehicle crashes per 100k.
# 2. Death rate: showed distribution skewed to right. In majority of US counties, less than 12.5 death rate per 1k.
# 3. Birth rate: showed distribution skewed to right. In majority of US counties, less than 12.5 birth rate per 1k.

# %% [markdown]
# ** B2. Univariate Analysis: categorical features **
#
# Let's create some bar charts/box plots using economoic typology and urban_rural influenial factors.

# %%
# Visualization: categorical and scale #
########################################
# economic typology:
plt.figure(figsize = (12, 6))
plt.title('US poverty rate by economic typology')
sns.boxplot(x = 'econ__economic_typology', y = 'poverty_rate',  data = df_EDA,
           order = ['Federal/State government-dependent','Nonspecialized','Mining-dependent',
                   'Manufacturing-dependent','Recreation','Farm-dependent'])
xt = plt.xticks(rotation=0, fontsize=8.5)
plt.show()

# Write a function to groupby and plot:
def grp_by_plot(x,y):
    df_grp = df_EDA.groupby(x)[y].mean().sort_values(ascending=False)
    df_grp.plot(kind='bar').set_xlabel(x)
    plt.xticks(rotation=320, fontsize=8.5)
    plt.ylabel('mean poverty rate %')
    return None

# Urban influence: population size
plt.figure()
grp_by_plot('area__urban_influence','poverty_rate')
plt.title('Mean poverty rate by urban population size')
plt.show()

# Rural Urban Continuum Code:
plt.figure()
grp_by_plot('area__rucc','poverty_rate')
plt.title('Mean poverty rate by rural urban classification code')
plt.show()

# Year: 
#plt.figure()
#grp_by_plot('yr','poverty_rate')
#plt.title('Mean poverty rate by year')
#plt.show()

# %% [markdown]
# ** Summary: **
# Based on a boxplot and bar charts plotted by different categorical factors, following trends were observed:
# 1. Economic typology: federal state dependent counties showed the highest poverty rate (19.5%). On contrary, farming dependent counties had the lowest poverty rate (14%).
# 2. Urbanization degree: with increased in population size from small micropolitan to large metropolitan counties, poverty rates were decreased.
# 3. Urban rural classification: from non-metro to metro counties, the poverty rates were going down (17.5% vs. 12.5%).

# %% [markdown]
# ** B3. Bivariate Analyses: cross tabulation **
#
# To explore relationships between two categorical features

# %%
# Test Cross Tablulation:
ct = pd.crosstab(df_EDA.area__rucc, df_EDA.econ__economic_typology)
ct
# Out:
# econ__economic_typology                             Farm-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...               3
# Metro - Counties in metro areas of 250,000 to 1...               8
# Metro - Counties in metro areas of fewer than 2...              25
# Nonmetro - Completely rural or less than 2,500 ...             300
# Nonmetro - Urban population of 2,500 to 19,999,...             100
# Nonmetro - Urban population of 20,000 or more, ...               2
#
# econ__economic_typology                             Federal/State government-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...                                  36
# Metro - Counties in metro areas of 250,000 to 1...                                  45
# Metro - Counties in metro areas of fewer than 2...                                  60
# Nonmetro - Completely rural or less than 2,500 ...                                  62
# Nonmetro - Urban population of 2,500 to 19,999,...                                 102
# Nonmetro - Urban population of 20,000 or more, ...                                  48
#
# econ__economic_typology                             Manufacturing-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...                       36
# Metro - Counties in metro areas of 250,000 to 1...                       47
# Metro - Counties in metro areas of fewer than 2...                       38
# Nonmetro - Completely rural or less than 2,500 ...                       59
# Nonmetro - Urban population of 2,500 to 19,999,...                      192
# Nonmetro - Urban population of 20,000 or more, ...                       67
#
# econ__economic_typology                             Mining-dependent  \
# area__rucc
# Metro - Counties in metro areas of 1 million po...                12
# Metro - Counties in metro areas of 250,000 to 1...                12
# Metro - Counties in metro areas of fewer than 2...                19
# Nonmetro - Completely rural or less than 2,500 ...                65
# Nonmetro - Urban population of 2,500 to 19,999,...               108
# Nonmetro - Urban population of 20,000 or more, ...                16
#
# econ__economic_typology                             Nonspecialized  Recreation
# area__rucc
# Metro - Counties in metro areas of 1 million po...             277          41
# Metro - Counties in metro areas of 250,000 to 1...             190          32
# Metro - Counties in metro areas of fewer than 2...             127          20
# Nonmetro - Completely rural or less than 2,500 ...              92          68
# Nonmetro - Urban population of 2,500 to 19,999,...             360          93
# Nonmetro - Urban population of 20,000 or more, ...             146          42

# %% [markdown]
# ** Summary: ** Based on a cross tab between economic typology and rural-urban classification, following trends were observed:
# 1. With respect to non-specialized: the largest number of counties were non-specialized and non-metro with population of 2,500 to 19,999. Followed by non-specialized and metro counties with population over 1 million.
# 2. With respect to farm-dependent: most of counties were dependent on farming industries in non-metro with less than 2,500 population (rural area).
# 3. In mid-size non-metro with population of 2,500 to 19,999, most of counties were dependent on manufacturing and mining.
# 4. In small size non-metro with population of 2,500 to 19,999 were mostly dependent on federal/state government funding.

# %% [markdown]
# ** B4. Bivariate Analyses: scatter plots **
#
# To explore relationships between numerical features

# %%
## Write a plot function: scatter sub-plots ##
def scatter_plot(x1,x2,y,
                 var1,var2,c1,c2):
    plt.figure(figsize=(8,8))
    plt.subplots_adjust(hspace=0.4, wspace=0.9)
    plt.subplot(2,1,1)
    plt.scatter(x1, y, color=c1)
    plt.title('Relationship between'+var1+ 'and Poverty Rate')
    plt.xlabel(var1)
    plt.ylabel('Poverty Rate')

    plt.subplot(2,1,2)
    plt.scatter(x2, y, color=c2)
    plt.title('Relationship between'+var2+ 'and Poverty Rate')
    plt.xlabel(var2)
    plt.ylabel('Poverty Rate')
    return None

# %% [markdown]
# ### B4A. Economic Indicators on poverty rate: ###

# %%
# Plot 1: econ__pct_uninsured_adults, vs. poverty_rate
# Plot 2: pct_uninsured_adults vs. poverty_rate
scatter_plot(df_EDA.econ__pct_civilian_labor, 
             df_EDA.econ__pct_uninsured_adults, df_EDA.poverty_rate, 
             ' civilian labor %', ' uninsured_adults %', c1='red', c2='blue')
plt.show()

# %% [markdown]
# ** Summary: Relationshp between economic indicators vs. poverty rate. **
# 1. % civilian labor: A strong trend of increased in labor power, decreased in poverty rate was observed.
# 2. % uninsured adults: A trend of increased in uninsured adults, decreased in poverty rate was observed.

# %% [markdown]
# ### B4B. Health Indicators on poverty rate: ###

# %%
# Plot 3: health__pct_excessive_drinking vs. poverty_rate
# Plot 4: health__pct_low_birthweight vs. poverty_rate
scatter_plot(df_EDA.health__pct_excessive_drinking, 
             df_EDA.health__pct_low_birthweight, df_EDA.poverty_rate, 
             ' % excessive drinking ', ' % low birthweight ', c1='orange', c2='darkgreen')
plt.show()

# %% [markdown]
# ** Summary: Relationshp between health indicators vs. poverty rate. **
# 1. % excessive drinking: higher the excessive drinking %, slight decreased in poverty rates were observed.
# 2. % low birthweight: higher the low birthweight %, increased in poverty rates were observed.

# %% [markdown]
# ### B4C. Education Demographic Indicators on poverty rate: ###

# %%
# Plot 5: demo__pct_adults_less_than_a_high_school_diploma vs. poverty_rate
# Plot 6: demo__pct_adults_bachelors_or_higher, vs. poverty_rate
scatter_plot(df_EDA.demo__pct_adults_bachelors_or_higher, 
             df_EDA.demo__pct_adults_less_than_a_high_school_diploma, df_EDA.poverty_rate, 
             ' % university degree ', ' % no highschool diploma ', c1='springgreen', c2='crimson')
plt.show()

# %% [markdown]
# ** Summary: Relationshp between education level indicators vs. poverty rate. **
# 1. % university education: increased in university degree %, lower poverty rates were observed.
# 2. % no highschool diploma: increased in % of no highschool diploma, higher poverty rates were observed.

# %% [markdown]
# ### B4D. Ethnicity Demographic Indicators on poverty rate: ###

# %%
# Plot 7: demo__pct_non_hispanic_white vs. poverty_rate
# Plot 8: demo__pct_non_hispanic_african_american, vs. poverty_rate
scatter_plot(df_EDA.demo__pct_non_hispanic_white, 
             df_EDA.demo__pct_non_hispanic_african_american, df_EDA.poverty_rate, 
             ' Caucasian % ', ' African American % ', c1='turquoise', c2='gray')
plt.show()

# %% [markdown]
# ** Summary: Relationshp between ethnicity demographic indicators vs. poverty rate. **
# 1. % Caucasian: increased in Caucasian population, lower poverty rates were observed.
# 2. % African American: increased in African American population, higher poverty rates were observed.

# %% [markdown]
# ### B4E. Age Demographic Indicators on poverty rate: ###

# %%
# Plot 9: demo__pct_below_18_years_of_age vs. poverty_rate
# Plot 10: demo__pct_aged_65_years_and_older, vs. poverty_rate
scatter_plot(df_EDA.demo__pct_below_18_years_of_age, 
             df_EDA.demo__pct_aged_65_years_and_older, df_EDA.poverty_rate, 
             ' adolescents % ', ' seniors % ', c1='cyan', c2='purple')
plt.show()

# %% [markdown]
# ** Summary: Relationshp between age demographic indicators vs. poverty rate. **
# 1. % adolescents: no clear trends were observed with increased in % adolescents and poverty rate.
# 2. % seniors: no clear trends were observed with increased in % seniors and poverty rate.

# %% [markdown]
# ** B5. Multi-Faceted Relationships: scatter plots **
#
# To explore relationships between numerical features conditioned by a categorical feature.

# %%
# Prepare dataframes filtered by Nonmetro and Metro counties:
df_non_metro = df_EDA[df_EDA['county_class'] == 'Nonmetro']
df_metro = df_EDA[df_EDA['county_class'] == 'Metro']

# Write a function for multi-dimensional scatter plots #
def multi_sct_plots(x1,x2,y):
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
    plt.subplots_adjust(hspace=0.2, wspace=0.2)
    plt.tight_layout(pad=0.4, w_pad=1.5, h_pad=1.0)
    ax1.scatter(df_non_metro[x1], df_non_metro[y], label='Nonmetro')
    ax1.scatter(df_metro[x1], df_metro[y], label='Metro')
    ax1.legend(loc='upper right')
    ax1.set_xlabel(x1, fontsize=9)
    ax1.set_ylabel(y)
    ax2.scatter(df_non_metro[x2], df_non_metro[y], label='Nonmetro')
    ax2.scatter(df_metro[x2], df_metro[y], label='Metro')
    ax2.legend(loc='upper right')
    ax2.set_xlabel(x2, fontsize=9)
    plt.show()

# Multi-faceted plot: % civilian labor and % low birthweight vs. poverty rate    
multi_sct_plots('econ__pct_civilian_labor',
              'health__pct_low_birthweight','poverty_rate')

# Multi-faceted plot: % Caucasian and % no highschool diploma vs. poverty rate    
multi_sct_plots('demo__pct_non_hispanic_white',
              'demo__pct_adults_less_than_a_high_school_diploma','poverty_rate')

# %% [markdown]
# ** Summary: Relationships between scoio-economic factors and poverty rate conditioned by urbanization degree **
#
# Firstly, US poverty rates were tend to be lower in metro vs nonmetro area counties. Secondly, the distribution or sparsity of scatter plots is higher in nonmetro than metro area counties. In general, poverty rates variance was lower in metro area counties.

# %% [markdown]
# ** B6. Multi-Faceted Relationships: scatter plots **
#
# To explore relationships between numerical features colored by target variable.

# %%
# Write a function: scatter plot colored by poverty_rate #
def plot_color_sct_x(x1, xlab1, x2, xlab2,
                   y, ylab, z, zlab):
    f, (ax1, ax2) = plt.subplots(1, 2, sharey=True, figsize=(10,4))
    # Scatter plot: subplot 1
    s1 = ax1.scatter(df_EDA[x1], df_EDA[y], c=df_EDA[z],
               cmap = plt.cm.coolwarm)
    ax1.set_xlabel(xlab1, fontsize=12)
    ax1.set_ylabel(ylab, fontsize=12)
#    cb1 = plt.colorbar(s1, ax=ax1, orientation='horizontal', pad=0.12)
#    cb1.set_label(zlab)
    # Scatter plot: subplot 2
    s2 = ax2.scatter(df_EDA[x2], df_EDA[y], c=df_EDA[z],
               cmap = plt.cm.coolwarm)
    ax2.set_xlabel(xlab2, fontsize=12)
    # Plot color bar:
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
    cax = plt.axes([0.85, 0.1, 0.05, 0.8])
    cb = f.colorbar(s1, cax=cax)
    cb.set_label(zlab)

# Plot a color scaled scatter plot by poverty rate:
plot_color_sct_x('demo__pct_adults_less_than_a_high_school_diploma', '% no highschool diploma',
               'demo__pct_adults_bachelors_or_higher', '% university degree',
               'econ__pct_civilian_labor', '% civlian labor',
               'poverty_rate', '% poverty rate')
plt.show()

# Plot a color scaled scatter plot by poverty rate:
plot_color_sct_x('demo__pct_non_hispanic_white', '% Caucasian',
               'demo__pct_non_hispanic_african_american', '% African American',
               'demo__pct_adults_less_than_a_high_school_diploma', '% no highschool diploma',
               'poverty_rate', '% poverty rate')
plt.show()

# %% [markdown]
# ** Summary: Relationships between scoio-economic factors color scaled by level of poverty rate **
#
# 1. % no high school diploma vs. % university degree: these top two plots showed that higher the education level of population, increased in % of civilian labor. Thus, poverty rates were found to be lower.
#
# 2. % Caucasian vs. African American: these bottom two plots showed that counties with higher % of Caucasian, less % of population found with no high school diploma. Conversely, exact opposite trend was found in counties with high % of African American population.

# %%
# Write a function: scatter plot colored by poverty_rate #
def plot_color_sct_y(x, xlab, y1, ylab1,
                   y2, ylab2, z, zlab):
    f, (ax1, ax2) = plt.subplots(1, 2, sharex=True, figsize=(10,4))
    plt.subplots_adjust(wspace=0.4)
    # Scatter plot: subplot 1
    s1 = ax1.scatter(df_EDA[x], df_EDA[y1], c=df_EDA[z],
               cmap = plt.cm.coolwarm)
    ax1.set_xlabel(xlab, fontsize=12)
    ax1.set_ylabel(ylab1, fontsize=12)
    # Scatter plot: subplot 2
    s2 = ax2.scatter(df_EDA[x], df_EDA[y2], c=df_EDA[z],
               cmap = plt.cm.coolwarm)
    ax2.set_xlabel(xlab, fontsize=12)
    ax2.set_ylabel(ylab2, fontsize=12)
    # Plot color bar:
    plt.subplots_adjust(bottom=0.1, right=0.8, top=0.9)
    cax = plt.axes([0.85, 0.1, 0.05, 0.8])
    cb = f.colorbar(s1, cax=cax)
    cb.set_label(zlab)

# Plot a color scaled scatter plot by poverty rate:
plot_color_sct_y('demo__pct_non_hispanic_african_american', '% African American',
               'econ__pct_unemployment', '% unemployment rate',
               'health__pct_low_birthweight', '% low birthweight',
               'poverty_rate', '% poverty rate')
plt.show()

# Plot a color scaled scatter plot by poverty rate:
plot_color_sct_y('demo__pct_non_hispanic_white', '% Caucasian',
               'econ__pct_unemployment', '% unemployment rate',
               'health__pct_low_birthweight', '% low birthweight',
               'poverty_rate', '% poverty rate')
plt.show()

# %% [markdown]
# ** Summary: Relationships between scoio-economic factors color scaled by level of poverty rate **
#
# 1. % unemployment rate & % low birthweight vs. African American: these bottom two plots showed that counties with higher % of African American, both increased in % of unemployment rate and % low birthweight. Overall, higher poverty rates were observed.
#
# 2. % unemployment rate & % low birthweight vs. Caucasian: these bottom two plots showed that counties with higher % of Caucasian, both decreased in % of unemployment rate and % low birthweight. Overall, lower poverty rates were observed.

# %% [markdown]
# ## Part C. Machine Learning: Regression Analysis ##
# Here,
# Y  = boston housing prices (called "target" data in python, and referred to as the dependent variable or response variable) and
# X  = all the other features (or independent variables, predictors or explanatory variables)
#
# which we will use to fit a linear regression model and predict Boston housing prices. We will use the least-squares method to estimate the coefficients.
#
# We will compare different types of regression modeling available on scikit-learn and statsmodel OLS:
# * Linear Regression
# * Multiple Linear Regression
# * Polynomial Regression
# * DecisionTree Regression
# * RandomForest Regression
# * XGBoost Regression

# %% [markdown]
# ### Dummy Variable Encoding: nominal features  ###
# Dummy variable encoding on nominal feature allows to create a separate column on each feature and its value are only encoded "0" or "1". This dummy indicator get interpreted well to the ML models for making accurate prediction. Also to reduce any potential biases of having multi-colinearity, each feature's first encoded dummy variable must be dropped to avoid dummy variable trap (i.e., where independent variables are highly inter-correlated with each other as one predictor can be predicted from other of similar variables: econ_farm_depmendent vs. econ_mining vs. etc.).

# %%
# Perform dummy variable encoding on nominal features #
###############################################################################
# Drop first dummy variable to avoid dummy variable trap on each converted feature!
df2 = pd.get_dummies(df_cleaned[['row_id', 'area__rucc', 'area__urban_influence', 'econ__economic_typology', 
                                 'econ__pct_civilian_labor', 'econ__pct_unemployment',
                                 'econ__pct_uninsured_adults', 'econ__pct_uninsured_children',
                                 'demo__pct_female', 'demo__pct_below_18_years_of_age', 
                                 'demo__pct_aged_65_years_and_older', 'demo__pct_hispanic', 
                                 'demo__pct_non_hispanic_african_american', 'demo__pct_non_hispanic_white',
                                 'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
                                 'demo__pct_adults_less_than_a_high_school_diploma', 'demo__pct_adults_with_high_school_diploma',
                                 'demo__pct_adults_with_some_college', 'demo__pct_adults_bachelors_or_higher', 
                                 'demo__birth_rate_per_1k', 'demo__death_rate_per_1k', 'health__pct_adult_obesity',
                                 'health__pct_adult_smoking', 'health__pct_diabetes', 'health__pct_low_birthweight',
                                 'health__pct_excessive_drinking', 'health__pct_physical_inacticity',
                                 'health__air_pollution_particulate_matter', 'health__motor_vehicle_crash_deaths_per_100k',
                                 'health__pop_per_dentist', 'health__pop_per_primary_care_physician', 'yr','poverty_rate']],
                                  drop_first=True)

# List total number of encoded inputs and output:
df2.isnull().sum()

# new downsampled df column names:
_ = df2.columns
print(_)

# Reset index: from 0 to 2949
df2 = df2.reset_index(drop=True)
# Out:
# Index(['row_id', 'econ__pct_civilian_labor', 'econ__pct_unemployment',
#        'econ__pct_uninsured_adults', 'econ__pct_uninsured_children',
#        'demo__pct_female', 'demo__pct_below_18_years_of_age',
#        'demo__pct_aged_65_years_and_older', 'demo__pct_hispanic',
#        'demo__pct_non_hispanic_african_american',
#        'demo__pct_non_hispanic_white',
#        'demo__pct_american_indian_or_alaskan_native', 'demo__pct_asian',
#        'demo__pct_adults_less_than_a_high_school_diploma',
#        'demo__pct_adults_with_high_school_diploma',
#        'demo__pct_adults_with_some_college',
#        'demo__pct_adults_bachelors_or_higher', 'demo__birth_rate_per_1k',
#        'demo__death_rate_per_1k', 'health__pct_adult_obesity',
#        'health__pct_adult_smoking', 'health__pct_diabetes',
#        'health__pct_low_birthweight', 'health__pct_excessive_drinking',
#        'health__pct_physical_inacticity',
#        'health__air_pollution_particulate_matter',
#        'health__motor_vehicle_crash_deaths_per_100k',
#        'health__pop_per_dentist', 'health__pop_per_primary_care_physician',
#        'poverty_rate', 'area__rucc_2', 'area__rucc_3', 'area__rucc_4',
#        'area__rucc_5', 'area__rucc_6', 'area__urban_influence_2.0',
#        'area__urban_influence_3.0', 'area__urban_influence_4.0',
#        'area__urban_influence_5.0', 'area__urban_influence_6.0',
#        'area__urban_influence_7.0', 'area__urban_influence_8.0',
#        'area__urban_influence_9.0', 'area__urban_influence_10.0',
#        'area__urban_influence_11.0',
#        'econ__economic_typology_Federal/State government-dependent',
#        'econ__economic_typology_Manufacturing-dependent',
#        'econ__economic_typology_Mining-dependent',
#        'econ__economic_typology_Nonspecialized',
#        'econ__economic_typology_Recreation', 'yr_year 2'],
#       dtype='object')

# %% [markdown]
# ### Split on input features and target variable  ###
# For US poverty rate regression problem, following set of regressors were tested which included linear regression, multi-linear, polynomial, decision tree, random forest and gradient boosting (XGBoost).
#
# After each model construction, RandomizedSearchCV module was applied to tune hyperparameters (i.e., C, n_estimators, etc.) on each model. This boosted model helps us to achieve the best desired performance for making predictions on housing price with least RMSE and max R^2 values.
#
# ### Data Partition ###
# Next step is data partition. It is an absolute requirement procedure in which split original data into training and test sets. Thus, it aims to separate data for model training and model perfomance evaluation.

# %%
# Split input features and output (target) variable:
X, y = df2.drop(['row_id','poverty_rate'], axis=1), df2['poverty_rate']

# Data Partition & Feature Scaling #
####################################
# Split training set and test set:
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                   test_size=1/4, random_state=123)

# %% [markdown]
# ### Feature Selection: using L1 regularization (LASSO) ###

# %%
# Feature Selection: L1 Regularization (LASSO) #
###############################################################################
# Fit L1 regularization to figure out non-zero coefficients:
lr_L1 = Lasso(alpha=0.01)
lr_L1.fit(X_train,y_train)

# Print estimated intercept coefficient:
print('Est. coefficient: {}'.format(lr_L1.intercept_))
# Feature selection dataframe: using L1 fitted coefficients
df_L1 = pd.DataFrame({'features':X.columns, 'EstCoef':lr_L1.coef_})[['features','EstCoef']]
df_L1_selected = df_L1.sort_values(by='EstCoef',ascending=False)
df_L1_selected
# Out:
# Est. coefficient: 21.910967313102418
#                                              features    EstCoef
# 12   demo__pct_adults_less_than_a_high_school_diploma  30.664829
# 10        demo__pct_american_indian_or_alaskan_native  11.107816
# 8             demo__pct_non_hispanic_african_american  10.899662
# 2                          econ__pct_uninsured_adults   9.347931
# 1                              econ__pct_unemployment   8.211622
# 19                          health__pct_adult_smoking   4.891268
# 43  econ__economic_typology_Federal/State governme...   1.306740
# 34                          area__urban_influence_3.0   0.783539
# 13          demo__pct_adults_with_high_school_diploma   0.720512
# 33                          area__urban_influence_2.0   0.403678
# 48                                          yr_year 2   0.402915
# 46             econ__economic_typology_Nonspecialized   0.279529
# 38                          area__urban_influence_7.0   0.255815
# 17                            demo__death_rate_per_1k   0.077681
# 24           health__air_pollution_particulate_matter   0.061468
# 25        health__motor_vehicle_crash_deaths_per_100k   0.038062
# 26                            health__pop_per_dentist   0.000041
# 36                          area__urban_influence_5.0  -0.000000
# 35                          area__urban_influence_4.0  -0.000000
# 6                   demo__pct_aged_65_years_and_older  -0.000000
# 7                                  demo__pct_hispanic  -0.000000
# 40                          area__urban_influence_9.0  -0.000000
# 41                         area__urban_influence_10.0  -0.000000
# 29                                       area__rucc_3  -0.000000
# 30                                       area__rucc_4  -0.000000
# 23                    health__pct_physical_inacticity   0.000000
# 22                     health__pct_excessive_drinking  -0.000000
# 21                        health__pct_low_birthweight   0.000000
# 20                               health__pct_diabetes   0.000000
# 11                                    demo__pct_asian  -0.000000
# 18                          health__pct_adult_obesity   0.000000
# 4                                    demo__pct_female   0.000000
# 27             health__pop_per_primary_care_physician  -0.000442
# 42                         area__urban_influence_11.0  -0.002129
# 39                          area__urban_influence_8.0  -0.041241
# 16                            demo__birth_rate_per_1k  -0.056338
# 28                                       area__rucc_2  -0.159745
# 47                 econ__economic_typology_Recreation  -0.459701
# 15               demo__pct_adults_bachelors_or_higher  -0.587038
# 45           econ__economic_typology_Mining-dependent  -0.758603
# 31                                       area__rucc_5  -0.914465
# 44    econ__economic_typology_Manufacturing-dependent  -1.033117
# 37                          area__urban_influence_6.0  -1.110033
# 9                        demo__pct_non_hispanic_white  -1.907733
# 14                 demo__pct_adults_with_some_college  -2.168645
# 32                                       area__rucc_6  -2.774770
# 5                     demo__pct_below_18_years_of_age  -6.633681
# 3                        econ__pct_uninsured_children -13.203098
# 0                            econ__pct_civilian_labor -22.331705

# %% [markdown]
# ### Feature Selection: using L2 regularization (Ridge) ###

# %%
# Feature Selection: L2 Regularization (Ridge) #
###############################################################################
# Fit L2 regularization to figure out non-zero coefficients:
lr_L2 = Ridge(alpha=0.01)
lr_L2.fit(X_train,y_train)

# Print estimated intercept coefficient:
print('Est. coefficient: {}'.format(lr_L2.intercept_))
# Feature selection dataframe: using L1 fitted coefficients
df_L2 = pd.DataFrame({'features':X.columns, 'EstCoef':lr_L2.coef_})[['features','EstCoef']]
df_L2_selected = df_L2.sort_values(by='EstCoef',ascending=False)
df_L2_selected
# Out:
# Est. coefficient: 27.189564906566318
#                                              features    EstCoef
# 1                              econ__pct_unemployment  30.391101
# 21                        health__pct_low_birthweight  23.560460
# 2                          econ__pct_uninsured_adults  21.825856
# 12   demo__pct_adults_less_than_a_high_school_diploma  20.510557
# 10        demo__pct_american_indian_or_alaskan_native  19.556212
# 4                                    demo__pct_female  18.088753
# 8             demo__pct_non_hispanic_african_american  13.165932
# 7                                  demo__pct_hispanic   6.300696
# 9                        demo__pct_non_hispanic_white   4.867980
# 23                    health__pct_physical_inacticity   1.588893
# 19                          health__pct_adult_smoking   1.340678
# 34                          area__urban_influence_3.0   1.085779
# 33                          area__urban_influence_2.0   0.384303
# 48                                          yr_year 2   0.186006
# 41                         area__urban_influence_10.0   0.138305
# 17                            demo__death_rate_per_1k   0.100731
# 16                            demo__birth_rate_per_1k   0.036422
# 25        health__motor_vehicle_crash_deaths_per_100k   0.023600
# 43  econ__economic_typology_Federal/State governme...   0.012709
# 26                            health__pop_per_dentist   0.000026
# 27             health__pop_per_primary_care_physician  -0.000470
# 36                          area__urban_influence_5.0  -0.041165
# 38                          area__urban_influence_7.0  -0.092693
# 24           health__air_pollution_particulate_matter  -0.147012
# 35                          area__urban_influence_4.0  -0.375026
# 40                          area__urban_influence_9.0  -0.474095
# 46             econ__economic_typology_Nonspecialized  -0.530256
# 39                          area__urban_influence_8.0  -0.722488
# 28                                       area__rucc_2  -0.767916
# 29                                       area__rucc_3  -0.785032
# 37                          area__urban_influence_6.0  -1.158032
# 47                 econ__economic_typology_Recreation  -1.230930
# 30                                       area__rucc_4  -1.599728
# 44    econ__economic_typology_Manufacturing-dependent  -1.793685
# 42                         area__urban_influence_11.0  -1.845211
# 32                                       area__rucc_6  -1.845211
# 45           econ__economic_typology_Mining-dependent  -1.879616
# 11                                    demo__pct_asian  -1.937277
# 18                          health__pct_adult_obesity  -2.032333
# 31                                       area__rucc_5  -2.226259
# 22                     health__pct_excessive_drinking  -2.526316
# 13          demo__pct_adults_with_high_school_diploma  -3.188764
# 20                               health__pct_diabetes  -5.137670
# 14                 demo__pct_adults_with_some_college  -7.965796
# 15               demo__pct_adults_bachelors_or_higher  -9.356010
# 0                            econ__pct_civilian_labor -19.844446
# 3                        econ__pct_uninsured_children -30.289618
# 6                   demo__pct_aged_65_years_and_older -33.335659
# 5                     demo__pct_below_18_years_of_age -46.351150

# %% [markdown]
# ### Feature Selection: using Feature Importance module ###
# FIP module is available on DecisionTree, RandomForest and XGBoost regressors.

# %%
# Feature Selection: Feature Importance #
#########################################
# Write a function F.I.P plot #
def fip_plot(model):
    model = model
    model.fit(X_train, y_train)
    feat_labels = X_train.columns[0:]
    importances = model.feature_importances_
    indices = np.argsort(importances)[::-1][0:10]

    #for f in range(10):
        #print("%2d) %-*s %f" % (f + 1, 30, 
                            #feat_labels[indices[f]],
                            #importances[indices[f]]))

    plt.bar(range(10), importances[indices], align='center')
    plt.xticks(range(10), feat_labels[indices], rotation=90)
    plt.xlim(-1, 10)
    
# Using a Decision Tree: Top 10 features:
fip_plot(DecisionTreeRegressor(random_state=0))
plt.title('Feature Importance: Decision Tree')
plt.show()

# Feature Selection: Feature Importance #
#########################################
# Using a RandomForest: Top 10 features:
fip_plot(RandomForestRegressor(random_state=0))
plt.title('Feature Importance: Random Forest')
plt.show()

# Feature Selection: Feature Importance #
#########################################
# Using a XGBoost: Top 10 features:
fip_plot(XGBRegressor(random_state=0))
plt.title('Feature Importance: XGBoost')
plt.show()

# %% [markdown]
# ### Feature Scaling ###
# Feature scaling is a step in which a scaler function (i.e., min-max, logarithmic, etc.) standardize different range of features into a close proximity (i.e., ranges). This helps some regression model(s) to handle importance of features in a normalized equal weighted fashion. Feature scaling was applied before training different kinds of regression algorithms.

# %%
# Apply Feature Scaling: using StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()
y_train_std = sc_y.fit_transform(y_train[:,np.newaxis]).flatten()
y_test_std = sc_y.fit_transform(y_test[:,np.newaxis]).flatten()

# %% [markdown]
# ### Visualization Test: filter outliers using RANSAC model ###

# %%
#########################################
# Viz Test: outliers using RANSAC model #
#########################################
# Feature demo__pct_adults_less_than_a_high_school_diploma without scaling:
X_train_less_hsd= X_train[['demo__pct_adults_less_than_a_high_school_diploma']].values

from sklearn.linear_model import RANSACRegressor
lr_ransac = RANSACRegressor(LinearRegression(), max_trials=100,
                            min_samples=50, loss='absolute_loss',
                            residual_threshold=5.0, random_state=123)
lr_ransac.fit(X_train_less_hsd, y_train)
inlier_mask = lr_ransac.inlier_mask_
outlier_mask = np.logical_not(inlier_mask)
line_X = np.arange(0,0.45,0.05)
line_y = lr_ransac.predict(line_X[:, np.newaxis])

plt.scatter(X_train_less_hsd[inlier_mask], y_train[inlier_mask],
            c='green', edgecolor='w',
            marker='o', label='inliers')
plt.scatter(X_train_less_hsd[outlier_mask], y_train[outlier_mask],
            c='red', edgecolor='w',
            marker='s', label='outliers')
plt.plot(line_X, line_y, c='k', lw=2)
plt.title('RANSAC: % less than high school diploma vs. poverty rate')
plt.xlabel('% less than high school diploma')
plt.ylabel('Poverty rate %')
plt.legend(loc='upper left')
plt.show()
print('Slope: %.3f' % lr_ransac.estimator_.coef_[0])
print('Intercept: %.3f' % lr_ransac.estimator_.intercept_)
# Out:
# Slope: 67.821
# Intercept: 6.340

# %% [markdown]
# #### Summary: RANSAC model ####
# Using RANSAC fitted model, we can visually inspect inliers and outliers. Outliers were present uniformly across low to high % of counties with less than high school diploma.

# %% [markdown]
# ### Model: Regression Analysis - Line of Best Fit ###

# %%
# Create a function: scatter plot + model fitted REG line
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='steelblue', edgecolor='w', s=70) # (x, y, c, edgecolor, s)
    plt.plot(X, model.predict(X), color='black', lw=2) #(x, predict, color, lw)
    return None

# Define input features: 1 predictor (pct_less_than_high_school_diploma)
X_train_less_hsd_std = sc_x.fit_transform(X_train[['demo__pct_adults_less_than_a_high_school_diploma']]) 
X_test_less_hsd_std = sc_x.fit_transform(X_test[['demo__pct_adults_less_than_a_high_school_diploma']])

# Fit Linear Regressor()
####################################################################
# Fit a simple Linear Regression:
lr = LinearRegression()
lr.fit(X_train_less_hsd_std, y_train_std)

# Plot % less than high school diploma vs Poverty Rate:
####################################################################
lin_regplot(X_test_less_hsd_std, y_test_std, lr)
plt.title('LinReg: Relationship between % no high school diploma and poverty rate')
plt.xlabel('% less than high school diploma [standardized]')
plt.ylabel('Poverty rate [standardized]')
plt.show()

# Fit Polynomial Regressor()
####################################################################
# Fit a simple Linear Regression:
lr = LinearRegression()
lr.fit(X_train_less_hsd_std, y_train_std)

# Fit a quad Polynomial Linear Regression:
pr = PolynomialFeatures(degree=2)
X_train_poly_std = pr.fit_transform(X_train_less_hsd_std)
X_test_poly_std = pr.fit_transform(X_test_less_hsd_std)
lr_2 = LinearRegression()
lr_2.fit(X_train_poly_std, y_train_std)
            
# Plot: Linear vs. Polynomial Regression Comparision
####################################################################
plt.scatter(X_test_less_hsd_std, y_test_std, label='test set')
plt.plot(X_test_less_hsd_std, lr.predict(X_test_less_hsd_std),
        label='linear fit', color='black', lw=3)
plt.plot(X_test_less_hsd_std, lr_2.predict(X_test_poly_std),
        label='quadratic fit', color='green', lw=3)
plt.title('LinReg vs. PolyReg: % no high school diploma vs poverty rate')
plt.xlabel('% less than high school diploma [standardized]')
plt.ylabel('Predicted poverty rate [standardized]')
plt.legend(loc='upper left')
plt.show()

# Sort index for test set: for non-linear regressor models #
sort_idx = X_test_less_hsd_std.flatten().argsort()

# Fit DecisionTree Regressor():
####################################################################
tree = DecisionTreeRegressor()
tree.fit(X_train_less_hsd_std, y_train_std)
plt.figure()
lin_regplot(X_test_less_hsd_std[sort_idx], y_test_std[sort_idx], tree)
plt.title('DTReg: % no high school diploma vs poverty rate')
plt.xlabel('% less than high school diploma [standardized]')
plt.ylabel('Predicted poverty rate [standardized]')
plt.show()

# Fit RandomForest Regressor():
####################################################################
forest = RandomForestRegressor()
forest.fit(X_train_less_hsd_std, y_train_std)
plt.figure()
lin_regplot(X_test_less_hsd_std[sort_idx], y_test_std[sort_idx], forest)
plt.title('RFReg: % no high school diploma vs poverty rate')
plt.xlabel('% less than high school diploma [standardized]')
plt.ylabel('Predicted poverty rate [standardized]')
plt.show()

# Fit XGBoost Regressor():
####################################################################
xgb = XGBRegressor()
xgb.fit(X_train_less_hsd_std, y_train_std)
plt.figure()
lin_regplot(X_test_less_hsd_std[sort_idx], y_test_std[sort_idx], xgb)
plt.title('XGBReg: % no high school diploma vs poverty rate')
plt.xlabel('% less than high school diploma [standardized]')
plt.ylabel('Predicted poverty rate [standardized]')
plt.show()

# %% [markdown]
# ** Summary: regression analyses on regression models **
#
# Visually, we can see that linear and polynomial regression fits are quite descent and well fitted. However, over-fittings are visually inspected from decision tree and random forest models. Since the regression lines were trying so hard to fit most of data points as much as possible.

# %% [markdown]
# ### K-fold Cross Validation ###
# Using L1 selected features, k-fold cross validation approached will be used for model training and optimize model hyperparameters. Firstly, earlier training set from data partition step was used to divde data into multiple folds. In each iteration, one fold was used as validation for optimizing model parameters and remaining folds were used for training model(s). Note that this procedure will be repeated "k" times as we specified where each validation fold shuffled between iterations. Finally, overal model performance would be average across all iterations to provide the best model hyperparameters.

# %%
# K-fold Cross Validation #
###########################
# L1 regularized: 13 features
[5,6,1,3,12,21,2,0,10,4,8,7,13]
# FIP from DTRegressor: 10 features
#[0,8,19,12,9,3,15,43,7,14] 
# FIP from RFRegressor: 10 features
#[0,20,5,12,9,7,23,21,6,8]
# FIP from XGBRegressor: 10 features
#[15,12,6,5,0,9,27,2,1,24]

# Define input features: reference to "X" input features dataframe
X_train_std = sc_x.fit_transform(X_train.iloc[:, [5,6,1,3,12,21,2,0,10,4,8,7,13]])
X_test_std = sc_x.fit_transform(X_test.iloc[:, [5,6,1,3,12,21,2,0,10,4,8,7,13]])

# Apply cross-validation: with K-Fold to divide "K" groups of samples for optimize model hyperparameters
kf = KFold(n_splits=10, random_state=123)
for train_idx, validate_idx in kf.split(X_train_std):
    X_train_kf, X_validate_kf = X_train_std[train_idx], X_train_std[validate_idx]
    y_train_kf, y_validate_kf = y_train_std[train_idx], y_train_std[validate_idx]

# %% [markdown]
# ### Model Fitting: using L1 selected features ###
# Following choices of models were selected for predicting poverty rate in US counties:
# * Linear Regression
# * Multiple Linear Regression
# * Polynomial Regression
# * DecisionTree Regression
# * RandomForest Regression
# * XGBoost Regression

# %%
###############################
# Model 1. LinearRegression() #
###############################
# Apply LinearRegression: 
lr = LinearRegression()
lr.fit(X_train_kf, y_train_kf)

# Make prediction: feature scaled inputs
y_train_pred_lr = lr.predict(X_train_kf)
y_test_pred_lr = lr.predict(X_test_std)

# %%
###############################
# Model 2. PolyLinRegression  #
###############################
# Re-fit PolyRegression: 
X_train_poly = pr.fit_transform(X_train_kf)
X_test_poly = pr.fit_transform(X_test_std)
lr_2 = LinearRegression()
lr_2.fit(X_train_poly, y_train_kf)

# Make prediction: PolyReg.
y_train_pred_pr = lr_2.predict(X_train_poly)
y_test_pred_pr = lr_2.predict(X_test_poly)

# %%
##########################
# Model 3. DTRegression  #
##########################
# Re-fit DTRegression: 
tree = DecisionTreeRegressor()
tree.fit(X_train_kf, y_train_kf)
sort_idx = X_train_kf.flatten().argsort()

# RandomizedSearchCV: DTRegressor
# Create hyperparameter list:
param_dist_dt = {'max_depth':sp.randint(2,10),
                 'max_leaf_nodes':sp.randint(2,10),
                 'min_samples_split':sp.randint(2,10),
                 'min_samples_leaf':sp.randint(2,10),
                 'criterion': ['mse','mae']}
random_search = RandomizedSearchCV(estimator=tree, param_distributions=param_dist_dt,
                                   random_state=123, n_iter=100, cv=4)
random_search_dt = random_search.fit(X_validate_kf, y_validate_kf)

# View best hyperparameters
print('Best max_depth:', random_search_dt.best_estimator_.get_params()['max_depth'])
print('Best min_samples_split:', random_search_dt.best_estimator_.get_params()['min_samples_split'])
print('Best min_samples_leaf:', random_search_dt.best_estimator_.get_params()['min_samples_leaf'])

# Make prediction: DTReg.
y_train_pred_dt = random_search_dt.predict(X_train_kf)
y_test_pred_dt = random_search_dt.predict(X_test_std)
# Out:
# Best max_depth: 8
# Best min_samples_split: 3
# Best min_samples_leaf: 9

# %%
##########################
# Model 4. RFRegression  #
##########################
# Re-fit RFRegression: 
forest = RandomForestRegressor(n_estimators=100, criterion='mse',
                               random_state=123, n_jobs=-1)
forest.fit(X_train_kf, y_train_kf)

# RandomizedSearchCV: RFRegressor
# Create hyperparameter list:
param_dist_rf = {'n_estimators':sp.randint(2,100), 
                  'max_depth':sp.randint(2,10),
                  'min_samples_split':sp.randint(2,10),
                  'min_samples_leaf':sp.randint(2,10),
                  'bootstrap': [True, False],
                  'criterion': ['mse','mae']}
random_search = RandomizedSearchCV(estimator=forest, param_distributions=param_dist_rf,
                                   random_state=123, n_iter=100)
random_search_rf = random_search.fit(X_validate_kf, y_validate_kf)

# View best hyperparameters
print('Best n_estimators:', random_search_rf.best_estimator_.get_params()['n_estimators'])
print('Best max_depth:', random_search_rf.best_estimator_.get_params()['max_depth'])
print('Best min_samples_split:', random_search_rf.best_estimator_.get_params()['min_samples_split'])
print('Best min_samples_leaf:', random_search_rf.best_estimator_.get_params()['min_samples_leaf'])

# Make prediction: RFReg.
y_train_pred_rf = random_search_rf.predict(X_train_kf)
y_test_pred_rf = random_search_rf.predict(X_test_std)
# Out:
# Best n_estimators: 85
# Best max_depth: 6
# Best min_samples_split: 8
# Best min_samples_leaf: 3

# %%
##########################
# Model 5. XGBRegression #
##########################
# Re-fit XGBRegression: 
XGB = XGBRegressor()
XGB.fit(X_train_kf, y_train_kf)

# RandomizedSearchCV: XGBRegressor
# Create hyperparameter list:
param_dist_xgb = {'n_estimators':sp.randint(2,100), 
                  'max_depth':sp.randint(2,10),
                  'learning_rate':np.random.uniform(0,1,10),
                  'objective':['reg:linear']}
random_search = RandomizedSearchCV(estimator=XGB, param_distributions=param_dist_xgb,
                                   random_state=123, n_iter=100)
random_search_xgb = random_search.fit(X_validate_kf, y_validate_kf)

# View best hyperparameters
print('Best n_estimators:', random_search_xgb.best_estimator_.get_params()['n_estimators'])
print('Best max_depth:', random_search_xgb.best_estimator_.get_params()['max_depth'])
print('Best learning_rate:', random_search_xgb.best_estimator_.get_params()['learning_rate'])
print('Best objective:', random_search_xgb.best_estimator_.get_params()['objective'])

# Make prediction: XGBReg.
y_train_pred_xgb = random_search_xgb.predict(X_train_kf)
y_test_pred_xgb = random_search_xgb.predict(X_test_std)
# Out:
# Best n_estimators: 48
# Best max_depth: 2
# Best learning_rate: 0.241675550102
# Best objective: reg:linear

# %% [markdown]
# ### Model Evaluation: compute RMSE and R^2 ###
# Note: before compute RMSE and R^2, we must transformed back to original scale on our original and predicted values.

# %%
# Test: inverse transform [original scale] 
###############################################################################   
# Original poverty_rates:
y_train_act = sc_y.inverse_transform(y_train_kf)
y_test_act = sc_y.inverse_transform(y_test_std)

# Predicted poverty_rates:
y_train_lr_pred = sc_y.inverse_transform(y_train_pred_lr)
y_test_lr_pred = sc_y.inverse_transform(y_test_pred_lr)

y_train_pr_pred = sc_y.inverse_transform(y_train_pred_pr)
y_test_pr_pred = sc_y.inverse_transform(y_test_pred_pr)

y_train_dt_pred = sc_y.inverse_transform(y_train_pred_dt)
y_test_dt_pred = sc_y.inverse_transform(y_test_pred_dt)

y_train_rf_pred = sc_y.inverse_transform(y_train_pred_rf)
y_test_rf_pred = sc_y.inverse_transform(y_test_pred_rf)

y_train_xgb_pred = sc_y.inverse_transform(y_train_pred_xgb)
y_test_xgb_pred = sc_y.inverse_transform(y_test_pred_xgb)

# Write a function to compute RMSE:
def RMSE(y_train, y_train_pred,
         y_test, y_test_pred, text):
    print(text %(
        np.sqrt(skm.mean_squared_error(y_train, y_train_pred)),
        np.sqrt(skm.mean_squared_error(y_test, y_test_pred))))

# Write a function to compute R^2:
def R_2(y_train, y_train_pred,
         y_test, y_test_pred, text):
    print(text %(
        skm.r2_score(y_train, y_train_pred),
        skm.r2_score(y_test, y_test_pred)))
    
# Compute RMSE & R^2: training & test set #
# Linear Regression():
RMSE(y_train_act, y_train_lr_pred,
    y_test_act, y_test_lr_pred,
    'LinReg: RMSE train:%.3f, test:%.3f')

R_2(y_train_act, y_train_lr_pred,
    y_test_act, y_test_lr_pred,
    'LinReg: R^2 train:%.3f, test:%.3f')

# Poly Regression():
RMSE(y_train_act, y_train_pr_pred,
    y_test_act, y_test_pr_pred,
    'PolyReg: RMSE train:%.3f, test:%.3f')

R_2(y_train_act, y_train_pr_pred,
    y_test_act, y_test_pr_pred,
    'PolyReg: R^2 train:%.3f, test:%.3f')

# DT Regression():
RMSE(y_train_act, y_train_dt_pred,
    y_test_act, y_test_dt_pred,
    'DTReg: RMSE train:%.3f, test:%.3f')

R_2(y_train_act, y_train_dt_pred,
    y_test_act, y_test_dt_pred,
    'DTReg: R^2 train:%.3f, test:%.3f')

# RF Regression():
RMSE(y_train_act, y_train_rf_pred,
    y_test_act, y_test_rf_pred,
    'RFReg: RMSE train:%.3f, test:%.3f')

R_2(y_train_act, y_train_rf_pred,
    y_test_act, y_test_rf_pred,
    'RFReg: R^2 train:%.3f, test:%.3f')

# XGB Regression():
RMSE(y_train_act, y_train_xgb_pred,
    y_test_act, y_test_xgb_pred,
    'XGBReg: RMSE train:%.3f, test:%.3f')

R_2(y_train_act, y_train_xgb_pred,
    y_test_act, y_test_xgb_pred,
    'XGBReg: R^2 train:%.3f, test:%.3f')
# Out:
# LinReg: RMSE train:3.376, test:3.630
# LinReg: R^2 train:0.747, test:0.702
# PolyReg: RMSE train:2.635, test:2.988
# PolyReg: R^2 train:0.846, test:0.798
# DTReg: RMSE train:4.774, test:4.774
# DTReg: R^2 train:0.493, test:0.485
# RFReg: RMSE train:3.788, test:3.994
# RFReg: R^2 train:0.681, test:0.639
# XGBReg: RMSE train:3.694, test:3.970
# XGBReg: R^2 train:0.697, test:0.644

# %% [markdown]
# ### Summary: RMSE and R^2 of regression models  ###
# Using L1 regularized selected features, Each regression model was carefully evaluated using R-squared value and RMSE (root mean squared error) metrics. Here is a summarized result of all five tested regression models.
#
# #### 1) Linear Regression: ###
# * RMSE training: 3.38 < RMSE test: 3.63
# * R^2 training: 0.747, R^2 test: 0.702
#
# #### 2) Polynomial Regression: ###
# * RMSE training: 2.64 < RMSE test: 2.98
# * R^2 training: 0.846, R^2 test: 0.798
#
# #### 3) DecisionTree Regression: ###
# * RMSE training: 4.774 < RMSE test: 4.774
# * R^2 training: 0.493, R^2 test: 0.485
#
# #### 4) RandomForest Regression: ###
# * RMSE training: 3.79 < RMSE test: 3.99
# * R^2 training: 0.681, R^2 test: 0.639
#
# #### 5) XGBoost Regression: ###
# * RMSE training: 3.74 < RMSE test: 4.01
# * R^2 training: 0.689, R^2 test: 0.636
#
# Thus, polynomial regression model was the best model with least RMSE value (2.98) and largest R^2 value (0.798) on test set. Some models were slightly overfitted (RMSE train << RMSE test).

# %% [markdown]
# ### Model Evaluation: original vs. predicted and residuals scatter plots  ###
# Let us plot two scatter plots for the best model.
# 1. original vs. predicted poverty rate
# 2. residual vs. predicted poverty rate

# %%
# Write a function: predicted vs. original plot
def plot_comp(y_train_pred, y_train,
             y_test_pred, y_test):
    plt.figure()
    plt.scatter(y_train_pred, y_train,
            c='blue', edgecolor='w',
            marker='o', label='training set')
    plt.scatter(y_test_pred, y_test,
            c='green', edgecolor='w',
            marker='s', label='test set')
    plt.xlabel('Predicted poverty rate')
    plt.ylabel('Original poverty rate')
    plt.legend(loc='upper left')

# Write a function: predicted vs. residual plot
def plot_resd(y_train_pred, y_train,
             y_test_pred, y_test):
    plt.figure()
    plt.scatter(y_train_pred, y_train_pred - y_train,
            c='blue', edgecolor='w',
            marker='o', label='training set')
    plt.scatter(y_test_pred, y_test_pred - y_test,
            c='green', edgecolor='w',
            marker='s', label='test set')
    plt.hlines(y=0, xmin=0, xmax=50, colors='k', lw=3)
    plt.xlim([0,50])
    plt.xlabel('Predicted poverty rate')
    plt.ylabel('Residual poverty rate')
    plt.legend(loc='upper left')
    
# PolyReg: predicted vs original plot    
###########################################################################
plot_comp(y_train_pr_pred, y_train_act,
          y_test_pr_pred, y_test_act)
plt.title('[PolyReg] relationship of predicted vs. original poverty rate')
plt.show()

# PolyReg: predicted vs residual plot    
plot_resd(y_train_pr_pred, y_train_act,
          y_test_pr_pred, y_test_act)
plt.title('[PolyReg] relationship of predicted vs. residual poverty rate')
plt.show()
###########################################################################

# %% [markdown]
# ### OLS Stats Model: Multi-Linear Regression ###

# %%
##############################################
# Test: statsmodel Multiple LinearRegression # 
##############################################
# Compute linear regression: health__pct_low_birthweight
lm = ols('poverty_rate ~ health__pct_low_birthweight', df2).fit()
print(lm.summary())

# Compute multi-linear regression: 3 features
lm_3 = ols('poverty_rate ~ health__pct_low_birthweight + demo__pct_adults_less_than_a_high_school_diploma + econ__pct_unemployment', df2).fit()
print(lm_3.summary())

# Compute multi-linear regression: 5 features
lm_5 = ols('poverty_rate ~ health__pct_low_birthweight + demo__pct_adults_less_than_a_high_school_diploma + econ__pct_unemployment + demo__pct_below_18_years_of_age + demo__pct_aged_65_years_and_older', df2).fit()
print(lm_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           poverty_rate   R-squared:                       0.291
# Model:                            OLS   Adj. R-squared:                  0.290
# Method:                 Least Squares   F-statistic:                     1208.
# Date:                Tue, 04 Sep 2018   Prob (F-statistic):          4.20e-222
# Time:                        20:55:39   Log-Likelihood:                -9255.7
# No. Observations:                2950   AIC:                         1.852e+04
# Df Residuals:                    2948   BIC:                         1.853e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       2.8703      0.409      7.011      0.000       2.068       3.673
# health__pct_low_birthweight   165.7182      4.768     34.753      0.000     156.368     175.068
# ==============================================================================
# Omnibus:                      523.514   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1445.384
# Skew:                           0.940   Prob(JB):                         0.00
# Kurtosis:                       5.868   Cond. No.                         46.7
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           poverty_rate   R-squared:                       0.617
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                     1579.
# Date:                Tue, 04 Sep 2018   Prob (F-statistic):               0.00
# Time:                        20:55:39   Log-Likelihood:                -8348.5
# No. Observations:                2950   AIC:                         1.670e+04
# Df Residuals:                    2946   BIC:                         1.673e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                           -1.3376      0.318     -4.208      0.000      -1.961      -0.714
# health__pct_low_birthweight                         74.0512      3.963     18.686      0.000      66.281      81.822
# demo__pct_adults_less_than_a_high_school_diploma    42.8499      1.328     32.256      0.000      40.245      45.455
# econ__pct_unemployment                              94.6143      3.684     25.681      0.000      87.390     101.838
# ==============================================================================
# Omnibus:                      828.735   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5140.345
# Skew:                           1.183   Prob(JB):                         0.00
# Kurtosis:                       9.018   Cond. No.                         56.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           poverty_rate   R-squared:                       0.619
# Model:                            OLS   Adj. R-squared:                  0.619
# Method:                 Least Squares   F-statistic:                     957.3
# Date:                Tue, 04 Sep 2018   Prob (F-statistic):               0.00
# Time:                        20:55:39   Log-Likelihood:                -8338.3
# No. Observations:                2950   AIC:                         1.669e+04
# Df Residuals:                    2944   BIC:                         1.672e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            2.5069      0.954      2.627      0.009       0.636       4.378
# health__pct_low_birthweight                         71.1858      4.001     17.791      0.000      63.340      79.031
# demo__pct_adults_less_than_a_high_school_diploma    44.4061      1.378     32.236      0.000      41.705      47.107
# econ__pct_unemployment                              93.1991      3.686     25.284      0.000      85.972     100.427
# demo__pct_below_18_years_of_age                    -12.3701      2.739     -4.516      0.000     -17.741      -6.999
# demo__pct_aged_65_years_and_older                   -5.4868      2.082     -2.635      0.008      -9.569      -1.405
# ==============================================================================
# Omnibus:                      885.753   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6089.353
# Skew:                           1.244   Prob(JB):                         0.00
# Kurtosis:                       9.584   Cond. No.                         59.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### Summary: using OLS model to compare regression models ####
# The aim of this section is to compare model performance across all 3 OLS models that we built. 1st model was built using only lowbirthweight. 2nd model was built using 3 predictors (i.e., low birthweight, less than high school, unemployment). Finally, 3rd model was built using 5 predictors (i.e., added age demographic features).
#
# Overall, the 3rd model provided the best adjusted R-squared value of 0.619 and the least AIC value of 1.669e+04 as well.

# %% [markdown]
# ### OLS Stats Model: Scatter Plots ###

# %%
##############################
# Evaluation 0: Scatter Plot #
##############################
# Plot: Predicted vs original poverty_rate
plt.figure()
_ = plt.scatter(lm_5.fittedvalues, df2.poverty_rate,
            c='blue', edgecolor='w', marker='o')
_ = plt.title('Relationship between predicted vs. original poverty rate [OLS]')
_ = plt.xlabel('Predicted poverty rate')
_ = plt.ylabel('Original poverty rate')
_ = plt.legend(loc='upper left')
_ = plt.show()

###############################
# Evaluation 1: Residual Plot #
###############################
# Plot: Residuals vs. predicted poverty_rate
plt.figure()
_ = plt.scatter(lm_5.fittedvalues, lm_5.fittedvalues - df2.poverty_rate,
            c='blue', edgecolor='w', marker='o')
_ = plt.title('Relationship between residuals vs. original poverty rate [OLS]')
_ = plt.xlabel('Predicted poverty rate')
_ = plt.ylabel('Residuals poverty rate')
_ = plt.legend(loc='upper left')
_ = plt.hlines(y=0, xmin=5, xmax=42, colors='k', lw=3)
_ = plt.xlim([5,42])
_ = plt.ylim([-35,20])
_ = plt.show()

# %% [markdown]
# #### Summary: scatter plots of OLS models ####
# First scatter plot showed that there were quite a lot of outliers present in lower and upper range of poverty rates.
#
# Second scatter plot showed difference in original - predicted poverty rates. It showed more clear representation to presence of more outliers in lower and upper range of poverty rates with respect to predicted poverty rate.

# %% [markdown]
# ### Model Assessment: with presence of outliers ###
# * Plotting: sns.residuals, scipy quantile plot, sns.distribution, sm.influence_plot

# %%
# Define input features: 3 predictors
X_train_std = sc_x.fit_transform(X_train[['health__pct_low_birthweight','demo__pct_adults_less_than_a_high_school_diploma','econ__pct_unemployment']])

# Fit LinReg():
lr = LinearRegression()
lr.fit(X_train_std, y_train_std)

# Plot: sns.residuals plot using LinReg model
plt.figure()
ax=sns.residplot(lr.predict(X_train_std), y_train_std, lowess=True,
                color='blue',scatter_kws={'alpha':0.3}, line_kws={'color':'green'})
plt.title('Residual plot: predicted vs. original poverty rate with outliers')
plt.xlabel('Predicted poverty rate [standardized]')
plt.ylabel('Original poverty rate [standardized]')
plt.show()

# Plot: quantile plot of residuals using LinReg model
plt.figure()
sp.probplot(lr.predict(X_train_std), dist='norm', plot=pylab)
pylab.show()

# Plot: distribution plot of residuals - 3 predictors with outliers
plt.figure()
plt.title('Distribution plot of residuals with outliers')
sns.distplot(lm_3.resid, kde=False)
plt.show()

# Plot: leverage plot to identify high leverage points in the model.
fig, ax = plt.subplots(figsize=(16,15))
fig = sm.graphics.influence_plot(lm_3,alpha=0.01,ax=ax,criterion="cooks",plot_alpha=0.9)
plt.show()

# %% [markdown]
# #### Summary: checking presence of outliers  ####
# Plot 1: seaborn residual plot showed that there were quite number of residuals centralized in low to mid range of predicted poverty rate. Thus, it indicated the fact that model was doing relatively poor job than high poverty rate counties.
#
# Plot 2: this probablisitc quantile plot provided a clue that distribution of residuals were quite noraml in mid range.
# However, still low and high range of distribution were not aligned well with a straight linear regression fit.
#
# Plot 3: this residual histogram did confirm that the distribution was quite normal with presence of some outliers on the lower and upper end of tails.
#
# Plot 4: identified high leverage and some influence = index 2742 and low leverage and high influence data points = indexes 451, 1059 and etc.

# %%
# Filter and print rows with low and high leverage with influences:
# High leverage, some influence: 115, 2530, 2851
# Low leverage, high influence: 415, 876, 2282
df2[['health__pct_low_birthweight','demo__pct_adults_less_than_a_high_school_diploma','econ__pct_unemployment','poverty_rate']][df2.index.isin([115,415,976,2282,2530,2851])]
# Out:
#       health__pct_low_birthweight  \
# 115                      0.062000
# 415                      0.083114
# 976                      0.062000
# 2282                     0.071000
# 2530                     0.049000
# 2851                     0.232000
#
#       demo__pct_adults_less_than_a_high_school_diploma  \
# 115                                           0.333667
# 415                                           0.128358
# 976                                           0.180377
# 2282                                          0.139581
# 2530                                          0.340681
# 2851                                          0.123370
#
#       econ__pct_unemployment  poverty_rate
# 115                    0.231          24.2
# 415                    0.054          44.3
# 976                    0.055          47.0
# 2282                   0.053          46.3
# 2530                   0.240          23.9
# 2851                   0.038          14.1

# %% [markdown]
# ** Interpretation:**
# The model was constructed using three features % low birthweight, % no high school diploma and % unemployment rate. There are presence of outliers due to somewhat outstanding value occurred in these three features.
#
# Here are some examples of interpreted outliers:
# * 2851: high % of low birthweight and low % of unemployment rate but relatively lower poverty rate as an outlier.
# * 2530: higher % of no high school diploma and unemployment rate indicated middle poverty rate
# * 415 & 976: low % of unemployment rate and no high school diploma but these standout as exceptions with higher poverty rate.

# %% [markdown]
# ### Model Assessment: without outliers ###
# * Plotting: sns.residuals, scipy quantile plot, sns.distribution, sm.influence_plot

# %%
## Remove Outliers ##
df_cleaned = df2.drop(df2.index[[115,415,976,2282,2530,2851]])
X_new, y_new = df_cleaned.drop(['poverty_rate'], axis=1), df_cleaned['poverty_rate']

# Data Partition: cleansed dataframe with outliers removal
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X_new,y_new,
                                                   test_size=1/4, random_state=123)
y_train_new_std = sc_y.fit_transform(y_train_new[:,np.newaxis]).flatten()
y_test_new_std = sc_y.fit_transform(y_test_new[:,np.newaxis]).flatten()

# Statsmodel ols: post outliers removal
lr_ols_cleaned = ols('poverty_rate ~ health__pct_low_birthweight + demo__pct_adults_less_than_a_high_school_diploma + econ__pct_unemployment',df_cleaned).fit()
print(lr_ols_cleaned)

# Define input features: 3 predictors - post outliers removal
X_train_new_std = sc_x.fit_transform(X_train_new[['health__pct_low_birthweight','demo__pct_adults_less_than_a_high_school_diploma','econ__pct_unemployment']])

# Re-fit: LinearRegression
lr_cleaned = LinearRegression()
lr_cleaned.fit(X_train_new_std, y_train_new_std)

# Plot: sns.residuals plot [post outliers removal]
plt.figure()
ax = sns.residplot(lr_cleaned.predict(X_train_new_std), y_train_new_std, lowess=True,
                  color='blue',scatter_kws={'alpha':0.3},line_kws={'color':'green'})
plt.title('Residual plot: predicted vs original with NO outliers')
plt.xlabel('Predicted poverty rate [standardized]')
plt.ylabel('Original poverty rate [standardized]')
plt.show()

# Plot: quantile plot of residuals [post outliers removal]
plt.figure()
sp.probplot(lr_cleaned.predict(X_train_new_std), dist="norm", plot=pylab)
pylab.show()

# Plot: distribution plot of residuals - 3 predictors with NO outliers
plt.figure()
plt.title('Distribution plot of residuals with NO outliers')
sns.distplot(lr_ols_cleaned.resid, kde=False)
plt.show()
# Out:
# <statsmodels.regression.linear_model.RegressionResultsWrapper object at 0x0000021F750EA160>

# %% [markdown]
#  ** Summary: post outliers removal **
#
# Plot 1: seaborn residual plot showed that there were still quite number of residuals centralized in low and high range of predicted poverty rate.
#
# Plot 2: this probablisitc quantile plot provided a clue that distribution of residuals were quite normal in mid range.
# However, still low and high range of poverty rates were not perfectly aligned with a linear regression fit.
#
# Plot 3: this residual histogram did confirm a normal distribution shape due to removal of outliers. However, still outliers are present and showing near the upper end of tails.
